# %% [markdown]
# # **Project Hint - Reading the Data from Database**

# %%
import sqlite3
import pandas as pd

# %% [markdown]
# ## **Step 1 - Reading the Tables from Database file**

# %%
# Read the code below and write your observation in the next cell

conn = sqlite3.connect('eng_subtitles_database.db')
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table'")
print(cursor.fetchall())
# Out:
# [('zipfiles',)]

# %% [markdown]
# **In the above cell, I am able to read the table inside the database. As mentioned earlier, table name is `zipfiles`. We also know from README.txt that this table contains three columns: 'num', 'name' and 'content'.**

# %% [markdown]
# ## **Step 2 - Reading the columns of Table**

# %%
cursor.execute("PRAGMA table_info('zipfiles')")
cols = cursor.fetchall()
for col in cols:
    print(col[1])
# Out:
# num
# name
# content

# %% [markdown]
# **The above code helps in checking the column names in the database table.**
#
# **Let's now use `SELECT * FROM zipfiles` to read all the data into a `df` variable.**

# %% [markdown]
# ## **Step 3 - Loading the Database Table inside a Pandas DataFrame**

# %%
df = pd.read_sql_query("""SELECT * FROM zipfiles""", conn)
df.head()
# Out:
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                              content
# 0  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x1c\xa9\x...
# 1  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x17\xb9\x...
# 2  b'PK\x03\x04\x14\x00\x00\x00\x08\x00L\xb9\x99V...
# 3  b'PK\x03\x04\x14\x00\x00\x00\x08\x00U\xa9\x99V...
# 4  b'PK\x03\x04\x14\x00\x00\x00\x08\x001\xa9\x99V...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82498 entries, 0 to 82497
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   num      82498 non-null  int64
#  1   name     82498 non-null  object
#  2   content  82498 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.9+ MB

# %% [markdown]
# **Looks like the `content` column donot contain the subtitles text. Instead as mentioned in README.txt, it might be latin-1 encoded.**

# %% [markdown]
# ## **Step 4 - Printing `content` of 0th Row**

# %%
b_data = df.iloc[0, 2]

# here 2 represent the index of content column
# 0 represents the row number

# %%
print(b_data)
# Out:
# b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x1c\xa9\x99V\x9fx\x96\xf0\x8c\x9e\x00\x00\x86\x9b\x01\x00;\x00\x00\x00The.Message.1976.REMASTERED.1080p.BluRay.x264-PiGNUS.EN.srt\xad\xbdm\x93\xdc\xc6\x91.\xfa\x9d\x11\xfc\x0f-}\xe1=\x11-\x9d\x06P\x85\x17\x9d\x8d\xd5%%[\xa4-Y>&u\x15>\xdf\xd0\xd3\x98\x19x\xfae\x0cts<\xfe\xf57\x9f\'\xb3\n\xd9\xa4\xbc\xbb\xf7\xc6Fl\xacELW\xa2\xaa\x90\x95\x95\xafO\x16/_l6\xdf\xe0\xff\xea\xf5f\xb3Y}\xf5\xd5\xbf\xaf\xf4AQ\xae7Mx\xf9\xe2\xd7\xfe|s\xbf\xea\x8f\xcf\xab\x8f\xe3n8\xadN\xc7\xfdx\x1cVO\xe3\xf9~\xf5\xf3\xe3p\xfc\xea\xfd/o>\xbc\xfb\xf0\xe3\xef\xde\xbf|\xf1\xfbi\x18Vo\xa6\xd3\xd3<L\xab\xe1\x1f\xe7\xe18\x8f\xa7\xe37\xab\xd3\xbc\xdb~-\xc3\x1e\xfe\xa7<|\xf9\xe2\xe5\x8bR_[~S\xd6\xeb\xa2k\xf3k\xe5A\xb7\xeeb\xf5\xf2\xc5\xbb\xe3\xea|?\xac\x8e\xfdaX\x9dnW?\x9cvk>8\x9c\xe6\xf3\xean\xeao\xc6\xd3ev\x8f~\x1a\xa6\x9b\xf1\xf6\xb2\xff\x1a\xe4\xabD\xbe*d\x11\xa5#_U\xeb\xaa\xd9`\xa6\xa7\xc3\xea\xa7\xcb}\x7f8\xf4F\xf9\xa7a\x9e\x87\xe3\x9d\xcc\\\xdf\x07B!\x13\xaa\xd61n<!\xd9\xaf\xd0\xbc|q>\xad\xde\x0e2\x9d\xfd\x98\xa63\x1c\x1e\x87\xe9D*o\x9e\xff\xd9\x1f\xcf\xe3\xe5\xc0Y\xc5L\xac^\x87M\xe3\x89u\xebP\xcb\xbb\xeed\xff\xce\xe3\xf1n^\t\xd9\xfb\xf1\xb0z\xba?\xad\xc6\x19d_\xbe\xb8=\xed\xf7\xa7\'\x9d\xde4\xde\xdd\x9f\x07\xd9\x81\xd5\xdde\xdc\xf5\xc7\x9b\x81o\xa8\xf3\x1b\xbau\xd3V\xee\r\xa1\\\xc7\xae\x90m]m\xc7\xdd\xea\xf9t\xe1\x1b\x86~\xe2\x94w\xe3G|\xd3\x9b~\xaf\xfb\xd7$:\xa1Z\x17\xb5_v\x88\xeb\xb6h@\xa7?\xe8\xe6\x7f\xb2k\xa0\x8b\xe7\x8f\xc3\xe9q?\xfc/Pk3\xb5z]U~\xdd\xa1\x95i\xca\xba\xfb\x9b\x9b\xe1\xf1\xbcz7\xef\x85\xea\xad\xec\x9dLpZ\xcd\xfd\xfec\x7f\x16\x06\xe2\x9c\xbaD%\x96\xeb\xb2*\x1c\x95\x18\xd6\xcdF\xfe\xfcvX\xcd\x8fC\xff0c*\xfd\xea8<\xad\x1e\xa7\xd3\xe3\xfdp^\x8d\xc7\xd5\xeb\xa9\xdf\x8e=I\x15\x9bL+\xae7\xb5g\xbf\xd8\xac\xdb2\x82\xeb\xe7\xd5x^\xed\xc7\x87A\x96#\x9f\xe0\xe9~8\xae\xfep\xba?\xeaG~\xd3?\x9e\xc7Yx\xf9\x06\x0c*k~\x90\xcf\x06NP\xbe)\x8a\xfc\x86v]\x84\x98\xdfP}\xb3)\xd6e#\xfc\x7f\xba\x9c1On\xff \xe7\xe5\xbc^\xddL\xcf\xa0\xd2o\xf1\xb7\xbc\xfaoI\xd0NL\xc5\x13S\xd5\x8e`\xd9\xae\xbb\x8dp\xfc\x87\x930\xf4\xdf\xfb\xa7\xbf\x8f\xc2\x88\x7f\xee\xcf\xd3\xd8Orr\xe5\x1d\xaf\xf7\xc3?\xfa\xe3nJ\xcb\xaf\x12-\xe1\x8a\xe0\x0e\xbd<\x08\xeb\xba\x92\xef\xf5\xc7q\x9e\xfa\xb5g\xe5?\x0f\xd3\x9c\xc6\x87<^v>6~|\xb3\x0e\x9dl_:Yd\xa9\x99\xfcF\x81\x81\xd5\xe2\x911\x8b\x92\x8b\x99\\\xb3n\x8a\xe0\xc8\xc5\x8d\x9c:\xd9\xca\xd7\xff\t\x7f|\xad\x84\xeaDH\xc6\xb5\x9d_\x97\xf0L\x08\xc2"\xc3a+guPJ:\xa8\xc9\x83\xc2\xba\xac\xfdb\xe4\xd35\xa5\xec\xfb_e\xf67\'\xc8\xa1\xcf>\xd9\xcb\x17\xf3a\xd8\xef\xf1\xd5\xe4\x0f\xe0\x85\xbd\x88\xca\xdd\xea\xee\xd4\x9f\x95|\x9b\xc9\x83\xd7\x17Q\x14D\xc6\xcaQ\xda\xf0\xbb\x9d\x85\x86\xed0\x18m\x1a\xe4h\xae\xe6\xfb\xd3e\xbf[=\x1c\x87a\xaf<`G@\x86vr\x90<\xad\xa2X\xd7\x9b\xcd\xb2\xef\xeb\xcf\xa4\x19gSn\x12\x85\xa2Z\xd7\xa1\xf5\x14\xe2\xba\xda\xc8\x06\xfe*\x12\xe7\xae\xff8P\xfc\x90\xf3\xfb\xcb\xf9\xfe4\x8d\xe7gN\xa2,2\x89(\x0b\x8a\x9e\x84\xac0\xc8~A\n\xc8\xbb\xcfY\xbe\xca\x01\x172"*\xa6\x9bg\x9c\x95C\x7f\x94\xe3bS2\xc6\x8e\x98R\xe5\x98)~SF9)\xc2k\x1fd3\xde\xdf\xdc\x9f\xf6\xfd4sw\xdf\xca\xc9\x93\x19\xf5G\x9et\xe5\x8a\xaf\xf4w\xbf\x1c\xc7\x8f\xd8\xc7\xf3\xb32\xfeW\xaf\xffy/BN\xce\xffw\xfd8\x9d\xf4GoEz\xea\xb0\xf1f\xf5\xdd\xe9(bw\x9e\xd3\x97}\x7f?\xf6\x14\x18?\x0e\xdb\xfex:r\x92U\x9a$N\xdf\xa6r\x93\x94\x8b\xa1\tQ\xe9\x1e\xfa\x07y\xb7\x12\x92\x8d\xbb\x1d\xf7\x87\xd5\xfd\xe9\x08^\x05\xe5\xf4\xc6\xf3\xd4\xefF\xf0\xed\xcb\x17O\xf7\xa3\x1cQY\xda\x0eB^\xde\xcb\xdf\xe1\xd4\xcd\xa7#y;M\xeb\xcf*\xc9Dn\xdc\xde\x0eG\xf9y\x7f\xd7\x8f\xc7YG\xcc\x8f\xa3|\xa0K\xbf\xb7u\xe3\xed\x10\xcc\xfd\x9d\xde\x0beH\xf3\xc7t\xddG\x8b\x10\xe8U\xab\x9b<\rr\xb4\x86\xb5\x89o\xcc\x00\xb4~:\xa5\x8f\xf84\n\x97\x1eO\xe7\xd5\x96\xcc\xf9\xa4r\xb9\x8c\x89\xb6\x9c\xba\xcd\xa6s\xb4c%w\xa4\xf0\xd4\xbf\x8d\xff.\xdc\xb9z\x1e\xf8\x01o\xcf\xc2\x94\xdf\xddO\xf2\x11\xe5\xe2\x19v\xeb\x7f\xfb\x9f\xe3\xbf\x93R\x9d)U\xeb2\xd4\x9eRT\xd6\x12J\x14\xc4\xbf\xbb\xc8v\x88\x12"|5_\x8e\x0f\xf8\\<\x95\xfd\xf4 \x1b3\xcc\x99d\x93I\xca\xc5\xb5)=\xc9v]7\x1dI\x82\xa7\x06a\x9bg={\xa0$_Dd\xbb\\\x8b\x ...

# %% [markdown]
# **From the content, it appears to start with the bytes "PK\x03\......", which suggests that it might be a ZIP archive file. How do I know it? Experience! I have worked with something similar earlier.**

# %% [markdown]
# ## **Step 5 - Unzipping the content of 385th row and decoding using `latin-1`**

# %%
import zipfile
import io

# Assuming 'content' is the binary data from your database
binary_data = df.iloc[385, 2]

# Decompress the binary data using the zipfile module
with io.BytesIO(binary_data) as f:
    with zipfile.ZipFile(f, 'r') as zip_file:
        # Reading only one file in the ZIP archive
        subtitle_content = zip_file.read(zip_file.namelist()[0])

# Now 'subtitle_content' should contain the extracted subtitle content
print(subtitle_content.decode('latin-1'))  # Assuming the content is latin-1 encoded text
# Out:
# 1
# 00:00:06,000 --> 00:00:12,074
# Watch any video online with Open-SUBTITLES
# Free Browser extension: osdb.link/ext
#
# 2
# 00:00:15,370 --> 00:00:16,506
# You lose everything, my girl.
#
# 3
# 00:00:16,530 --> 00:00:19,360
# So you've said - four times.
#
# 4
# 00:00:20,330 --> 00:00:22,120
# I definitely had
# it on yesterday.
#
# 5
# 00:00:22,465 --> 00:00:25,785
# Your gloves, your keys, that
# handkerchief I embroidered for you
#
# 6
# 00:00:25,809 --> 00:00:26,168
# Everything!
#
# 7
# 00:00:26,192 --> 00:00:27,280
# Five times.
#
# 8
# 00:00:31,610 --> 00:00:32,920
# Miss Scarlet?
# - Yes.
#
# 9
# 00:00:36,390 --> 00:00:37,390
# I'm Miss Scarlet.
#
# 10
# 00:00:37,872 --> 00:00:40,880
# May I inquire if
# you've lost something?
#
# 11
# 00:00:41,350 --> 00:00:42,530
# Some jewellery perhaps?
#
# 12
# 00:00:42,870 --> 00:00:45,130
# Yes, my mother's wedding ring.
#
# 13
# 00:00:45,220 --> 00:00:45,840
# Have you found it?
#
# 14
# 00:00:45,950 --> 00:00:47,656
# Does your ring have
# an inscription?
#
# 15
# 00:00:48,650 --> 00:00:51,720
# From my father to my mother 'For
# my beloved, Livinia Scarlet'
#
# 16
# 00:00:52,370 --> 00:00:53,370
# Then it is yours.
#
# 17
# 00:00:53,630 --> 00:00:56,760
# I told you so many times to get
# it resized, but does she listen?
#
# 18
# 00:00:57,350 --> 00:01:00,392
# It was found last night in the
# city mortuary by a Mr Potts.
#
# 19
# 00:01:00,532 --> 00:01:01,798
# Is she the one that calls you
#
# 20
# 00:01:01,821 --> 00:01:04,235
# an unchristian woman the
# morals of an alley cat.
#
# 21
# 00:01:04,490 --> 00:01:05,490
# Yes, that's the one.
#
# 22
# 00:01:07,320 --> 00:01:08,330
# You're under arrest.
#
# 23
# 00:01:08,678 --> 00:01:10,709
# What? Why?
#
# 24
# 00:01:10,826 --> 00:01:13,180
# For breaking and entering
# the city mortuary.
#
# 25
# 00:01:14,810 --> 00:01:15,940
# Find Inspector Wellington.
#
# 26
# 00:01:28,060 --> 00:01:29,900
# Duke, the door.
#
# 27
# 00:01:32,280 --> 00:01:33,280
# Hmm.
#
# 28
# 00:01:34,420 --> 00:01:35,420
# Duke.
#
# 29
# 00:01:36,540 --> 00:01:38,730
# It's your house, you get it.
#
# 30
# 00:01:51,500 --> 00:01:52,640
# Sorry to bother you,
#
# 31
# 00:01:52,720 --> 00:01:55,090
# but I wondered if Inspector
# Wellington was there.
#
# 32
# 00:01:57,850 --> 00:01:58,850
# You've got a visitor.
#
# 33
# 00:01:59,279 --> 00:02:00,959
# Inspector Wellington!
#
# 34
# 00:02:01,730 --> 00:02:02,780
# I need your help.
#
# 35
# 00:02:04,840 --> 00:02:05,840
# It's Eliza.
#
# 36
# 00:02:06,778 --> 00:02:08,166
# She's been arrested.
#
# 37
# 00:02:08,190 --> 00:02:10,550
# Tell her it's my day off.
#
# 38
# 00:02:13,980 --> 00:02:15,060
# Who is this Eliza?
#
# 39
# 00:02:25,180 --> 00:02:26,350
# She's not my wife.
#
# 40
# 00:02:31,940 --> 00:02:32,940
# Ready inspector?
#
# 41
# 00:02:34,000 --> 00:02:35,830
# Miss Scarlet really
# does need your help.
#
# 42
# 00:03:20,936 --> 00:03:23,430
# There's clearly been a
# misunderstanding Detective Phelps.
#
# 43
# 00:03:23,570 --> 00:03:25,530
# Not that I wish to tell
# you how to do your job.
#
# 44
# 00:03:25,720 --> 00:03:28,870
# You being an extremely
# experienced, well regarded officer,
#
# 45
# 00:03:29,420 --> 00:03:31,180
# I'm simply perplexed as
# to what has happened.
#
# 46
# 00:03:32,240 --> 00:03:33,940
# Well, let me enlighten
# you, Miss Scarlet.
#
# 47
# 00:03:37,310 --> 00:03:42,290
# Last night someone smashed the window
# of the city mortuary and broke in.
#
# 48
# 00:03:43,270 --> 00:03:45,740
# They then gained access
# to the clerical office
#
# 49
# 00:03:45,820 --> 00:03:50,350
# inside and stole some
# highly confidential files.
#
# 50
# 00:03:51,780 --> 00:03:52,520
# Well, if that is true
#
# 51
# 00:03:52,600 --> 00:03:54,276
# then it's both deplorable
# and a disgrace.
#
# 52
# 00:03:54,345 --> 00:03:56,923
# Words shared by the clerk
# of the mortuary, Mr Potts,
#
# 53
# 00:03:56,960 --> 00:04:00,670
# although in his case he used them to
# describe you rather than the situation.
#
# 54
# 00:04:00,710 --> 00:04:02,246
# I know that man's opinion of me.
#
# 55
# 00:04:02,271 --> 00:04:04,122
# 'An unscrupulous woman'
#
# 56
# 00:04:04,260 --> 00:04:07,030
# 'who is as trustworthy
# as a bag of snakes'.
#
# 57
# 00:04:07,780 --> 00:04:09,680
# The fact is, I'm no thief.
#
# 58
# 00:04:10,040 --> 00:04:12,020
# So glad you brought up
# facts, Miss Scarlet,
#
# 59
# 00:04:12,100 --> 00:04:14,420
# because the fact
# remains that your ring
#
# 60
# 00:04:14,500 --> 00:04:15,810
# was found at the crime scene.
#
# 61
# 00:04:23,510 --> 00:04:25,500
# Well, I have no idea
# how it got there.
#
# 62
# 00:04:26,490 --> 00:04:29,220
# Women aren't even allowed in
# the mortuary - quite right too.
#
# 63
# 00:04:29,310 --> 00:04:30,820
# It's no place for a lady.
#
# 64
# 00:04:33,580 --> 00:04:34,580
# Morning to you.
#
# 65
# 00:04:36,875 --> 00:04:38,960
# I'll take you from
# here Detective Phelps.
#
# 66
# 00:04:39,830 --> 00:04:40,830
# Thank God for that.
#
# 67
# 00:04:43,950 --> 00:04:45,606
# I'm sorry to have dragged
# you into this, William.
#
# 68
# 00:04:45,630 --> 00:04:47,100
# On my day off.
#
# 69
# 00:04:47,880 --> 00:04:49,970
# Oh. Were you doing
# something nice?
#
# 70
# 00:04:52,350 --> 00:04:55,070
# I have no idea how my mother's ring
# found its way to the crime scene.
#
# 71
# 00:04:55,760 --> 00:04:56,679
# It's a puzzle indeed.
#
# 72
# 00:04:56,757 --> 00:04:58,957
# Do you think I was
# born yesterday?
#
# 73
# 00:05:00,200 --> 00:05:00,950
# I'm warning you, Eliza.
#
# 74
# 00:05:01,000 --> 00:05:03,340
# The next words out of your
# mouth better be the truth
#
# 75
# 00:05:03,420 --> 00:05:05,130
# or I'll take you down
# to the cells myself.
#
# 76
# 00:05:07,334 --> 00:05:09,720
# All right. I did go to
# the mortuary yesterday.
#
# 77
# 00:05:10,130 --> 00:05:12,530
# I have numerous outstanding
# cases which I could progress with
#
# 78
# 00:05:12,590 --> 00:05:14,750
# if Mr Potts would share some
# basic information with me.
#
# 79
# 00:05:14,810 --> 00:05:16,726
# But he refuses to treat me
# like a fellow professional.
#
# 80
# 00:05:16,750 --> 00:05:19,160
# So I have no choice but to
# break in like a common criminal
#
# 81
# 00:05:19,240 --> 00:05:20,440
# and check the files myself.
#
# 82
# 00:05:20,790 --> 00:05:22,496
# I must have dropped my
# mother's ring whilst there,
#
# 83
# 00:05:22,520 --> 00:05:23,890
# hence this misunderstanding.
#
# 84
# 00:05:24,350 --> 00:05:25,385
# So let me get this straight..
#
# 85
# 00:05:25,409 --> 00:05:26,954
# Last night you broke
# into the city mortuary
#
# 86
# 00:05:26,978 --> 00:05:29,186
# and stole files
# from Potts' office.
#
# 87
# 00:05:29,210 --> 00:05:31,290
# Where exactly is the
# misunderstanding?
#
# 88
# 00:05:31,380 --> 00:05:32,450
# I never stole anything.
#
# 89
# 00:05:33,100 --> 00:05:35,007
# I looked at the files
# and put them back.
#
# 90
# 00:05:35,367 --> 00:05:37,159
# And it wasn't last night,
# it was yesterday afternoon
#
# 91
# 00:05:37,183 --> 00:05:38,628
# when Mr Potts was out for lunch.
#
# 92
# 00:05:38,785 --> 00:05:40,416
# And I didn't break in.
#
# 93
# 00:05:40,440 --> 00:05:41,680
# Why would I want to have a key?
#
# 94
# 00:05:43,378 --> 00:05:45,760
# You duplicated a key
# for the city mortuary?
#
# 95
# 00:05:45,800 --> 00:05:46,800
# What choice do I have?
#
# 96
# 00:05:49,270 --> 00:05:51,830
# Someone else broke into the mortuary
# last night and it wasn't me.
#
# 97
# 00:05:52,382 --> 00:05:53,765
# I wouldn't lie to you, William.
#
# 98
# 00:05:53,796 --> 00:05:55,460
# That's a blatant lie in itself.
#
# 99
# 00:05:59,840 --> 00:06:01,780
# Miss Scarlet.
# - Detective Fitzroy.
#
# 100
# 00:06:03,020 --> 00:06:04,020
# New haircut?
#
# 101
# 00:06:04,450 --> 00:06:05,450
# Very smart.
#
# 102
# 00:06:07,540 --> 00:06:09,570
# Sir, I have a message for you.
#
# 103
# 00:06:09,840 --> 00:06:12,390
# I thought I told you I wasn't
# here. I'm on my day off.
#
# 104
# 00:06:12,660 --> 00:06:14,620
# Yes Sir, but the Superintendent
# has asked for you.
#
# 105
# 00:06:14,800 --> 00:06:15,800
# He says it's urgent.
#
# 106
# 00:06:20,920 --> 00:06:23,290
# Do not move.
#
# 107
# 00:06:25,110 --> 00:06:26,110
# William.
#
# 108
# 00:06:26,700 --> 00:06:27,700
# William..
#
# 109
# 00:06:30,480 --> 00:06:31,640
# You do believe me, don't you?
#
# 110
# 00:06:32,060 --> 00:06:34,530
# This is an extremely serious
# offence that you're accused of.
#
# 111
# 00:06:34,900 --> 00:06:36,910
# It's going to be damn hard
# to prove it wasn't you.
#
# 112
# 00:06:40,270 --> 00:06:41,270
# Come in!
#
# 113
# 00:06:43,170 --> 00:06:45,080
# Ah, Wellington. This
# is Mr Thackeray.
#
# 114
# 00:06:46,130 --> 00:06:47,130
# Good morning, sir.
#
# 115
# 00:06:47,250 --> 00:06:48,140
# I hope it is a good
# morning, Inspector..
#
# 116
# 00:06:48,220 --> 00:06:49,620
# It's been a bloody awful night,
#
# 117
# 00:06:49,700 --> 00:06:50,700
# that's for sure.
#
# 118
# 00:06:51,350 --> 00:06:52,880
# Mr Thackery is
# the chief coroner.
#
# 119
# 00:06:54,550 --> 00:06:55,898
# The break in at city mortuary?
#
# 120
# 00:06:55,961 --> 00:06:56,961
# Break ins.
#
# 121
# 00:06:57,710 --> 00:07:00,169
# Plural. We've just had word that
# the mortuaries in Kentish Town
#
# 122
# 00:07:00,193 --> 00:07:02,580
# and Swiss Cottage were
# broken into last night.
#
# 123
# 00:07:02,817 --> 00:07:04,727
# Confidential files
# stolen from each.
#
# 124
# 00:07:04,809 --> 00:07:06,620
# I believe you have the
# perpetrator in custody.
#
# 125
# 00:07:07,010 --> 00:07:08,010
# We do indeed, Edmund.
#
# 126
# 00:07:08,870 --> 00:07:10,890
# That woman has a history
# of breaking the law.
#
# 127
# 00:07:11,370 --> 00:07:14,050
# My man in the city has had to
# deal with her time and time again,
#
# 128
# 00:07:14,130 --> 00:07:15,560
# but this time
# she's gone too far.
#
# 129
# 00:07:16,170 --> 00:07:17,640
# The lady detective..
#
# 130
# 00:07:18,271 --> 00:07:19,271
# What nonsense.
#
# 131
# 00:07:19,590 --> 00:07:22,990
# So Miss Scarlet has had some
# minor grievances with the clerk
#
# 132
# 00:07:23,070 --> 00:07:24,456
# who runs the city
# mortuary service.
#
# 133
# 00:07:24,480 --> 00:07:26,326
# There was evidence found
# at one of the crime scenes
#
# 134
# 00:07:26,350 --> 00:07:27,401
# that places her there.
#
# 135
# 00:07:27,441 --> 00:07:28,948
# Surely you are working
# under the assumption
#
# 136
# 00:07:28,972 --> 00:07:31,340
# that whoever did one break in
# must have done the other two.
#
# 137
# 00:07:31,490 --> 00:07:33,105
# Yes, that would be
# the assumption, sir.
#
# 138
# 00:07:33,130 --> 00:07:34,901
# I want that woman
# charged without delay.
#
# 139
# 00:07:35,129 --> 00:07:36,129
# It's all in hand.
#
# 140
# 00:07:37,465 --> 00:07:39,892
# Take Miss Scarlet directly to
# Holloway. She can be kept there whilst
#
# 141
# 00:07:39,916 --> 00:07:41,438
# further investigations
# are undertaken.
#
# 142
# 00:07:41,462 --> 00:07:43,172
# Further Investgation? What
# need is there of that?
#
# 143
# 00:07:43,196 --> 00:07:44,956
# You've got all the
# evidence you need. Fergus.
#
# 144
# 00:07:46,210 --> 00:07:47,447
# Charge her.
# - But Sir..
#
# 145
# 00:07:47,471 --> 00:07:48,751
# That's an order, Inspector.
#
# 146
# 00:07:51,030 --> 00:07:52,030
# Yes, Sir.
#
# 147
# 00:08:04,360 --> 00:08:05,360
# Sorry, Eliza.
#
# 148
# 00:08:13,880 --> 00:08:14,430
# Where is she?
#
# 149
# 00:08:14,580 --> 00:08:17,410
# I wish I knew so I could
# give her a piece of my mind.
#
# 150
# 00:08:17,580 --> 00:08:20,110
# She does nothing but
# worry the life out of me.
#
# 151
# 00:08:20,360 --> 00:08:21,730
# Not only is she now a fugitive,
#
# 152
# 00:08:21,810 --> 00:08:25,700
# but she's also made a
# complete fool out of me again.
#
# 153
# 00:08:26,680 --> 00:08:28,390
# I'm as frantic to
# find her as you are.
#
# 154
# 00:08:28,520 --> 00:08:29,790
# God knows where she is.
#
# 155
# 00:08:29,880 --> 00:08:31,850
# God knows what danger she's in.
#
# 156
# 00:08:32,020 --> 00:08:34,580
# Well, not as much danger as she'll
# be when I get my hands on her.
#
# 157
# 00:08:34,700 --> 00:08:37,230
# Please do not talk
# like that Inspector,
#
# 158
# 00:08:37,320 --> 00:08:39,020
# it's not gentlemanly.
#
# 159
# 00:08:39,520 --> 00:08:41,890
# Do you have any idea how
# much trouble she's in?
#
# 160
# 00:08:42,740 --> 00:08:43,850
# Then you must help her.
#
# 161
# 00:08:44,120 --> 00:08:45,990
# How can I when I don't
# know where she is?
#
# 162
# 00:08:50,160 --> 00:08:52,036
# There was one person who
# might know her whereabouts
#
# 163
# 00:08:52,060 --> 00:08:54,290
# and I have my men hunting
# him down as we speak.
#
# 164
# 00:08:54,680 --> 00:08:56,900
# If Moses so much as sneezes,
#
# 165
# 00:08:56,980 --> 00:08:58,700
# we will be down on him
# like a ton of bricks.
#
# 166
# 00:08:58,970 --> 00:09:01,210
# What makes you think
# Moses knows anything?
#
# 167
# 00:09:01,780 --> 00:09:03,100
# Those two are thick as thieves?
#
# 168
# 00:09:04,060 --> 00:09:06,330
# If you see her or
# you hear from her,
#
# 169
# 00:09:06,440 --> 00:09:08,490
# then you send for
# me Ivy, immediately.
#
# 170
# 00:09:20,720 --> 00:09:22,040
# Are you sure you
# weren't followed?
#
# 171
# 00:09:26,990 --> 00:09:29,190
# Why do people
# always ask me that?
#
# 172
# 00:09:30,270 --> 00:09:31,550
# I'm worried about my girl.
#
# 173
# 00:09:32,940 --> 00:09:34,970
# Are you certain this is
# the right thing to do?
#
# 174
# 00:09:35,970 --> 00:09:36,970
# Just stick to the plan.
#
# 175
# 00:09:39,360 --> 00:09:40,400
# I don't think I can do it.
#
# 176
# 00:09:42,420 --> 00:09:44,590
# You just lied to the
# Detective Inspector.
#
# 177
# 00:09:45,450 --> 00:09:46,860
# You can do this.
#
# 178
# 00:09:55,500 --> 00:09:56,500
# Gone.
#
# 179
# 00:09:56,610 --> 00:09:57,438
# Gone where?
#
# 180
# 00:09:57,594 --> 00:09:58,594
# I don't know sir.
#
# 181
# 00:09:58,641 --> 00:10:02,031
# So a prime suspect who was in
# your custody has done a runner.
#
# 182
# 00:10:02,830 --> 00:10:04,860
# You're unable to
# locate her, a woman.
#
# 183
# 00:10:05,350 --> 00:10:06,590
# She's a private detective, Sir.
#
# 184
# 00:10:06,630 --> 00:10:08,460
# She has contacts..
# - Are you not one of them?
#
# 185
# 00:10:08,790 --> 00:10:10,486
# I can assure you that I've
# had no hand in this, sir.
#
# 186
# 00:10:10,510 --> 00:10:12,220
# I can also assure you
# that Eliza Scarlet
#
# 187
# 00:10:12,300 --> 00:10:14,565
# is not the perpetrator. We're
# barking up the wrong tree.
#
# 188
# 00:10:14,604 --> 00:10:15,604
# Enough!
#
# 189
# 00:10:20,340 --> 00:10:21,776
# Now it seems to me
# we have a conflict
#
# 190
# 00:10:21,800 --> 00:10:22,800
# of interest here,
#
# 191
# 00:10:23,089 --> 00:10:25,750
# so I'm going to recommend
# you'll move to another case,
#
# 192
# 00:10:25,987 --> 00:10:27,087
# With all due respect, Sir,
#
# 193
# 00:10:27,160 --> 00:10:28,020
# that would be a mistake.
#
# 194
# 00:10:28,137 --> 00:10:30,146
# The chief coroner's a man
# of connection and influence.
#
# 195
# 00:10:30,170 --> 00:10:32,330
# Whose going to make my
# life extremely difficult.
#
# 196
# 00:10:33,470 --> 00:10:34,510
# Give me one more day, sir.
#
# 197
# 00:10:37,185 --> 00:10:39,785
# Now, I have not long been in this
# job laddie and I can assure you
#
# 198
# 00:10:39,850 --> 00:10:41,980
# you do not want to be
# the reason I lose it.
#
# 199
# 00:10:43,580 --> 00:10:44,580
# You have your day.
#
# 200
# 00:10:45,990 --> 00:10:46,990
# Find her!
#
# 201
# 00:10:48,230 --> 00:10:49,230
# Yes, Sir.
#
# 202
# 00:10:56,830 --> 00:10:59,620
# What a privilege it is
# to have such a visit.
#
# 203
# 00:11:00,290 --> 00:11:02,430
# Not since Prince Albert himself
#
# 204
# 00:11:02,510 --> 00:11:04,420
# graced us to open
# our new autopsy wing
#
# 205
# 00:11:04,518 --> 00:11:06,282
# have I been so honoured.
#
# 206
# 00:11:06,344 --> 00:11:08,429
# And the honour is
# all mine, Mr. Potts.
#
# 207
# 00:11:08,610 --> 00:11:12,766
# I am merely here at the request
# of my husband, Mr Thackery.
#
# 208
# 00:11:12,961 --> 00:11:16,883
# 'Cecilia', he said. 'You
# must pay Mr Potts a visit'
#
# 209
# 00:11:16,946 --> 00:11:20,726
# 'and see is he quite well after
# such a distressing episode'.
#
# 210
# 00:11:20,781 --> 00:11:25,670
# The notion of the chief coroner
# giving an employee as lowly as myself
#
# 211
# 00:11:25,725 --> 00:11:29,020
# any thought is.. That's
# comfort indeed, Mrs Thackery.
#
# 212
# 00:11:30,270 --> 00:11:34,060
# But this business, with the break-in
# has left me feeling somewhat violated.
#
# 213
# 00:11:34,450 --> 00:11:36,640
# To think someone
# came into this, my
#
# 214
# 00:11:37,302 --> 00:11:40,820
# private sanctuary
# without authorization.
#
# 215
# 00:11:41,550 --> 00:11:45,940
# I say someone, but I know exactly
# who it was and so do the police.
#
# 216
# 00:11:46,250 --> 00:11:48,240
# Yes, my husband told
# me all about it.
#
# 217
# 00:11:48,417 --> 00:11:50,027
# Some young woman, was it not?
#
# 218
# 00:11:50,080 --> 00:11:54,500
# I hear she's a private investigator.
# What a curious job for a lady.
#
# 219
# 00:11:54,620 --> 00:11:56,380
# There's nothing of the
# lady about that woman.
#
# 220
# 00:11:57,020 --> 00:11:58,640
# What exactly was it she stole?
#
# 221
# 00:11:59,940 --> 00:12:02,986
# I thought you said your husband
# told you all about it, Mrs Thackery?
#
# 222
# 00:12:03,361 --> 00:12:05,090
# He did indeed, but..
#
# 223
# 00:12:05,790 --> 00:12:09,360
# I have quite forgotten. Ah,
# you know how us ladies are..
#
# 224
# 00:12:09,440 --> 00:12:13,880
# It's hard to retain too much
# information at any one time.
#
# 225
# 00:12:16,110 --> 00:12:17,110
# I do not believe you.
#
# 226
# 00:12:20,560 --> 00:12:23,850
# It is abundantly clear to me
# that a lady such as yourself
#
# 227
# 00:12:26,640 --> 00:12:28,950
# possesses great brains
# as well as beauty.
#
# 228
# 00:12:31,190 --> 00:12:32,190
# You're kind, Mr. Potts.
#
# 229
# 00:12:33,190 --> 00:12:37,836
# But it is nevertheless true that
# the details have quite evaded me.
#
# 230
# 00:12:38,031 --> 00:12:41,430
# Would you mind if we did
# not discuss that woman?
#
# 231
# 00:12:42,340 --> 00:12:44,410
# I have to be mindful
# of my blood pressure
#
# 232
# 00:12:44,490 --> 00:12:47,740
# and she has a habit of
# causing me great vexation.
#
# 233
# 00:12:50,726 --> 00:12:51,726
# Tea.
#
# 234
# 00:12:53,580 --> 00:12:56,450
# Goodness, I'd quite forgotten
# the reason for my visit.
#
# 235
# 00:12:56,740 --> 00:13:00,160
# My husband and I would like
# to invite you for dinner.
#
# 236
# 00:13:01,570 --> 00:13:02,570
# This evening.
#
# 237
# 00:13:03,500 --> 00:13:04,940
# At the chief coroner's house?
#
# 238
# 00:13:05,020 --> 00:13:08,130
# And I will endeavour to keep
# my questions to a minimum.
#
# 239
# 00:13:08,560 --> 00:13:11,400
# I'd hate to cause
# undue vexation.
#
# 240
# 00:13:12,026 --> 00:13:14,440
# I... Mrs Thackery, nonsense...
#
# 241
# 00:13:15,590 --> 00:13:16,920
# What is it you wish to know?
#
# 242
# 00:13:24,980 --> 00:13:28,070
# Confidential files were stolen
# from all three mortuaries.
#
# 243
# 00:13:28,260 --> 00:13:32,350
# They contained lists of unidentified
# bodies who died 25 years ago
#
# 244
# 00:13:32,490 --> 00:13:34,190
# in the August of 1857.
#
# 245
# 00:13:36,185 --> 00:13:37,300
# Anything else taken?
#
# 246
# 00:13:38,638 --> 00:13:39,950
# We should let Eliza know.
#
# 247
# 00:13:40,099 --> 00:13:41,099
# Not yet.
#
# 248
# 00:13:41,297 --> 00:13:43,531
# She must lie low until
# I've found out more.
#
# 249
# 00:13:43,875 --> 00:13:46,880
# Where exactly is this safe
# house she's holed up in?
#
# 250
# 00:13:47,210 --> 00:13:48,420
# I hope it's respectable.
#
# 251
# 00:13:48,930 --> 00:13:51,820
# It's not exactly
# Claridges, but it will do.
#
# 252
# 00:13:55,128 --> 00:13:56,128
# Oh my God.
#
# 253
# 00:13:58,932 --> 00:14:00,815
# Miss Scarlet,
# welcome to my castle.
#
# 254
# 00:14:00,980 --> 00:14:02,260
# I hope you've made
# yourself home.
#
# 255
# 00:14:02,412 --> 00:14:03,612
# Yes, yes.
#
# 256
# 00:14:04,128 --> 00:14:06,560
# Moses has shown me
# all the amenities.
#
# 257
# 00:14:07,120 --> 00:14:08,800
# Thank you for allowing
# me to shelter here.
#
# 258
# 00:14:09,200 --> 00:14:11,810
# I have allegations made against
# me that are completely false.
#
# 259
# 00:14:12,320 --> 00:14:13,320
# Aren't they always?
#
# 260
# 00:14:15,290 --> 00:14:19,000
# So what are these
# false allegations?
#
# 261
# 00:14:19,330 --> 00:14:22,020
# It's a break in at
# the city mortuary
#
# 262
# 00:14:22,059 --> 00:14:24,255
# and for your information
# the claims are false.
#
# 263
# 00:14:24,372 --> 00:14:25,614
# On Bow Lane?
#
# 264
# 00:14:25,911 --> 00:14:26,395
# Mm..
#
# 265
# 00:14:26,419 --> 00:14:28,660
# My sister Clementine
# works that steet?
#
# 266
# 00:14:29,370 --> 00:14:30,840
# Your sister's called
# Clementine, too?
#
# 267
# 00:14:30,990 --> 00:14:33,790
# All my sisters are. Made it easy for
# our mother to remember who's who..
#
# 268
# 00:14:35,760 --> 00:14:37,391
# If something happened
# on my sister's patch
#
# 269
# 00:14:37,415 --> 00:14:39,860
# she'd know about it,
# 'orrible though she is.
#
# 270
# 00:14:40,720 --> 00:14:42,220
# I could pay her a visit though.
#
# 271
# 00:14:42,980 --> 00:14:44,350
# See if she knows anything.
#
# 272
# 00:14:44,571 --> 00:14:45,868
# I'd be most grateful.
#
# 273
# 00:14:45,931 --> 00:14:46,971
# How grateful?
#
# 274
# 00:14:58,880 --> 00:15:00,650
# I take great risk
# in going to see her.
#
# 275
# 00:15:00,776 --> 00:15:03,442
# Last week she punched
# a dog in the face.
#
# 276
# 00:15:06,760 --> 00:15:08,550
# This Moses is the key.
#
# 277
# 00:15:08,680 --> 00:15:10,690
# If anyone can lead
# us to her, it's him.
#
# 278
# 00:15:10,781 --> 00:15:12,804
# Sir, I've got the information
# that you asked for.
#
# 279
# 00:15:12,930 --> 00:15:13,930
# Get to it.
#
# 280
# 00:15:18,290 --> 00:15:19,396
# Did I say something wrong, Sir?
#
# 281
# 00:15:19,420 --> 00:15:20,420
# Shut the door first, Roy.
#
# 282
# 00:15:23,860 --> 00:15:26,064
# Now, I do not believe that
# Miss Scarlet is guilty in this
#
# 283
# 00:15:26,088 --> 00:15:27,748
# but my orders are to find her,
#
# 284
# 00:15:27,835 --> 00:15:29,685
# not to go looking for
# alternative perpetrators.
#
# 285
# 00:15:29,800 --> 00:15:32,610
# So this line of inquiry is to
# remain strictly between us.
#
# 286
# 00:15:35,770 --> 00:15:37,290
# You have a problem
# with that detective?
#
# 287
# 00:15:40,580 --> 00:15:41,705
# No, Sir.
#
# 288
# 00:15:41,963 --> 00:15:43,323
# I do not have a
# problem with that.
#
# 289
# 00:15:43,378 --> 00:15:44,378
# Good.
#
# 290
# 00:15:45,370 --> 00:15:46,530
# And what have you got for me?
#
# 291
# 00:15:46,790 --> 00:15:48,766
# The files stolen from each
# of the three mortuaries
#
# 292
# 00:15:48,790 --> 00:15:51,530
# contain a list of unidentified
# bodies from August 1857.
#
# 293
# 00:15:51,680 --> 00:15:53,146
# Yes, yes, tell me
# something I don't know.
#
# 294
# 00:15:53,170 --> 00:15:54,250
# Then I searched for a link,
#
# 295
# 00:15:54,310 --> 00:15:55,830
# male, female, similar ages,
#
# 296
# 00:15:55,910 --> 00:15:56,910
# cause of death,
#
# 297
# 00:15:57,170 --> 00:16:00,361
# but unfortunately those details only exist
# in records at the cemeteries themselves,
#
# 298
# 00:16:00,385 --> 00:16:02,605
# but I managed to find
# maps of each cemetery
#
# 299
# 00:16:02,662 --> 00:16:04,006
# and where the
# graves are located.
#
# 300
# 00:16:04,061 --> 00:16:05,319
# I've marked them with an X.
#
# 301
# 00:16:07,470 --> 00:16:08,670
# How many cemeteries are there?
#
# 302
# 00:16:09,110 --> 00:16:11,800
# 14 Sir, with one
# pauper grave in each.
#
# 303
# 00:16:12,917 --> 00:16:13,807
# Shall I come with you, Sir?
#
# 304
# 00:16:13,890 --> 00:16:15,280
# No, I need to do this quietly.
#
# 305
# 00:16:15,430 --> 00:16:16,260
# Go back to your duties.
#
# 306
# 00:16:16,430 --> 00:16:17,430
# Yes, Sir.
#
# 307
# 00:16:25,900 --> 00:16:27,770
# Clementine, where have you been?
#
# 308
# 00:16:27,860 --> 00:16:29,130
# You've been gone for hours.
#
# 309
# 00:16:31,350 --> 00:16:32,350
# Did you see your sister?
#
# 310
# 00:16:32,781 --> 00:16:33,491
# What did she say?
#
# 311
# 00:16:33,593 --> 00:16:35,186
# Does she know anything
# about the break-in?
#
# 312
# 00:16:35,210 --> 00:16:37,120
# Saw her.. very nice.. well..
#
# 313
# 00:16:37,233 --> 00:16:38,233
# Whatever..
#
# 314
# 00:16:38,435 --> 00:16:41,315
# Yeah, it wasn't very good since the
# wrestling match with our grandmother.
#
# 315
# 00:16:41,420 --> 00:16:42,420
# She saw the real thief?
#
# 316
# 00:16:43,430 --> 00:16:44,430
# Clementine..
#
# 317
# 00:16:45,060 --> 00:16:46,060
# Clementine.
#
# 318
# 00:16:48,977 --> 00:16:49,977
# Oh!
#
# 319
# 00:17:21,470 --> 00:17:22,920
# You should be
# ashamed of yourself.
#
# 320
# 00:17:23,850 --> 00:17:25,060
# I'm calling the police!
#
# 321
# 00:17:28,110 --> 00:17:29,110
# Stop.
#
# 322
# 00:17:32,960 --> 00:17:34,080
# I'm a police officer, madam.
#
# 323
# 00:17:34,820 --> 00:17:35,820
# Are you all right?
#
# 324
# 00:17:36,910 --> 00:17:38,880
# Just a little shaken, my
# husband's the vicar here.
#
# 325
# 00:17:39,690 --> 00:17:40,690
# He's away on business.
#
# 326
# 00:17:40,830 --> 00:17:41,830
# I'm all alone.
#
# 327
# 00:17:44,880 --> 00:17:45,880
# Poor soul.
#
# 328
# 00:17:46,300 --> 00:17:47,300
# Those grave robbers,
#
# 329
# 00:17:47,370 --> 00:17:48,380
# they have no morals.
#
# 330
# 00:17:49,180 --> 00:17:50,380
# Do you know who's buried here?
#
# 331
# 00:17:51,890 --> 00:17:52,890
# No one knows.
#
# 332
# 00:17:53,400 --> 00:17:54,400
# Pauper grave.
#
# 333
# 00:18:07,629 --> 00:18:10,080
# I was in my parlour
# in the vicarage.
#
# 334
# 00:18:10,148 --> 00:18:12,630
# I like to carry out my
# correspondence there.
#
# 335
# 00:18:13,293 --> 00:18:14,965
# So, what alerted
# you to the robbers?
#
# 336
# 00:18:15,113 --> 00:18:18,020
# I was writing to
# my sister Agatha,
#
# 337
# 00:18:18,570 --> 00:18:20,180
# I heard a noise outside.
#
# 338
# 00:18:20,590 --> 00:18:22,940
# We weren't expecting
# any burials today.
#
# 339
# 00:18:23,070 --> 00:18:25,660
# My husband's away
# on church business,
#
# 340
# 00:18:26,230 --> 00:18:30,380
# staying with the Archbishop
# himself in Canterbury
#
# 341
# 00:18:30,830 --> 00:18:33,260
# So you heard a noise outside?
#
# 342
# 00:18:33,510 --> 00:18:35,870
# I went out to see what it
# was and instantly I knew.
#
# 343
# 00:18:36,950 --> 00:18:42,750
# Body snatchers. It's a lucrative trade
# selling corpses to the medical profession.
#
# 344
# 00:18:42,900 --> 00:18:45,140
# They supply bodies
# for anatomy classes.
#
# 345
# 00:18:46,386 --> 00:18:47,811
# Dissections.
#
# 346
# 00:18:47,874 --> 00:18:49,940
# Yes, I am aware of the practice.
#
# 347
# 00:18:50,410 --> 00:18:51,720
# I shouted at them to stop.
#
# 348
# 00:18:53,110 --> 00:18:55,760
# They was so shocked that
# someone was at the vicarage.
#
# 349
# 00:18:56,600 --> 00:18:58,170
# They must have assumed it empty.
#
# 350
# 00:18:59,760 --> 00:19:01,580
# Then they saw you, a man..
#
# 351
# 00:19:03,060 --> 00:19:04,420
# Had you not been
# there inspector..
#
# 352
# 00:19:06,640 --> 00:19:08,830
# I dread to think what
# might have happened.
#
# 353
# 00:19:09,900 --> 00:19:11,020
# You got a good look at them?
#
# 354
# 00:19:11,500 --> 00:19:14,110
# One had dark hair
# and the other was..
#
# 355
# 00:19:15,150 --> 00:19:16,150
# Fairer?
#
# 356
# 00:19:16,860 --> 00:19:17,940
# Average build, the pair.
#
# 357
# 00:19:19,190 --> 00:19:22,665
# Any scars, tattoos
# distinguishing features?
#
# 358
# 00:19:22,695 --> 00:19:25,633
# None that I saw but
# they were very grubby.
#
# 359
# 00:19:26,790 --> 00:19:29,730
# Dirt all over their
# faces, their hands.
#
# 360
# 00:19:32,420 --> 00:19:33,420
# I'm sorry.
#
# 361
# 00:19:33,920 --> 00:19:34,920
# I haven't been much help.
#
# 362
# 00:19:35,280 --> 00:19:36,660
# No, you've been most helpful.
#
# 363
# 00:19:37,890 --> 00:19:38,940
# See Mrs Ellis home.
#
# 364
# 00:19:48,597 --> 00:19:49,597
# Jake
#
# 365
# 00:19:50,026 --> 00:19:51,581
# There's been a
# sighting: the Jamaican.
#
# 366
# 00:19:51,644 --> 00:19:52,715
# Do you want me to bring him in?
#
# 367
# 00:19:52,739 --> 00:19:55,090
# No. He's mine.
#
# 368
# 00:20:03,505 --> 00:20:05,120
# And a pound of
# potatoes, please Jim.
#
# 369
# 00:20:05,210 --> 00:20:05,920
# Jim, right?
#
# 370
# 00:20:06,010 --> 00:20:07,100
# Right you are, young lady.
#
# 371
# 00:20:08,530 --> 00:20:09,540
# Mrs Thackery.
#
# 372
# 00:20:11,050 --> 00:20:12,090
# How nice to see you again.
#
# 373
# 00:20:13,580 --> 00:20:14,580
# Mr. Potts..
#
# 374
# 00:20:15,000 --> 00:20:16,900
# What a small world?
#
# 375
# 00:20:17,216 --> 00:20:20,120
# Not really. Mother is
# just around the corner.
#
# 376
# 00:20:20,200 --> 00:20:23,130
# Had to pay her visit to
# impart my most wonderful news.
#
# 377
# 00:20:24,145 --> 00:20:25,145
# Oh?
#
# 378
# 00:20:25,640 --> 00:20:28,676
# The honour of dining with yourself
# and the chief coroner this evening.
#
# 379
# 00:20:28,854 --> 00:20:31,918
# I said mother, I might just
# purchase a new tie for the occasion.
#
# 380
# 00:20:31,943 --> 00:20:32,950
# This one's so special.
#
# 381
# 00:20:34,068 --> 00:20:36,369
# Mother would so love
# to have joined us.
#
# 382
# 00:20:36,393 --> 00:20:38,659
# Well, bring her
# along if you like.
#
# 383
# 00:20:39,791 --> 00:20:42,160
# Mrs Thackery, you
# misunderstand me..
#
# 384
# 00:20:42,710 --> 00:20:43,710
# Mother is dead.
#
# 385
# 00:20:44,710 --> 00:20:46,120
# It is her grave which I visit.
#
# 386
# 00:20:46,760 --> 00:20:50,840
# I felt compelled to share the news
# of this great honor bestowed upon me.
#
# 387
# 00:20:51,258 --> 00:20:53,780
# Well, I really should be going.
#
# 388
# 00:20:53,920 --> 00:20:55,750
# Dinner will not prepare itself.
#
# 389
# 00:20:56,930 --> 00:21:00,083
# I am more than a
# little confused.
#
# 390
# 00:21:00,653 --> 00:21:05,440
# It's most unusual that a lady, such
# as yourself, does her own shopping.
#
# 391
# 00:21:07,430 --> 00:21:11,130
# Indeed, however,
# I wanted to ensure
#
# 392
# 00:21:11,210 --> 00:21:15,200
# that all the ingredients for tonight's
# dinner were of the highest quality.
#
# 393
# 00:21:17,400 --> 00:21:18,400
# I don't know what to say.
#
# 394
# 00:21:19,344 --> 00:21:20,460
# Until this evening, then.
#
# 395
# 00:21:21,368 --> 00:21:22,888
# Until this evening.
#
# 396
# 00:21:26,980 --> 00:21:28,050
# What a delightful lady.
#
# 397
# 00:21:29,200 --> 00:21:32,981
# It is a treat to be in her
# company. A treat indeed.
#
# 398
# 00:21:33,780 --> 00:21:36,330
# Yeah, Ivy is one in a million.
#
# 399
# 00:21:38,433 --> 00:21:39,433
# Ivy?
#
# 400
# 00:21:48,520 --> 00:21:49,520
# Clementine,
#
# 401
# 00:21:49,980 --> 00:21:50,980
# Clementine.
#
# 402
# 00:21:51,534 --> 00:21:53,667
# I've just had the
# loveliest dream.
#
# 403
# 00:21:53,762 --> 00:21:57,059
# Moses took me to Gilbert's, and
# my God did he look handsome.
#
# 404
# 00:21:57,210 --> 00:21:58,900
# What did your sister
# Clementine say?
#
# 405
# 00:21:59,538 --> 00:22:01,148
# Which one - there's five of us?
#
# 406
# 00:22:01,224 --> 00:22:03,497
# The one that witnessed the
# break-in in the city mortuary.
#
# 407
# 00:22:03,584 --> 00:22:07,630
# Oh. Uh.. she said it
# was raining that night
#
# 408
# 00:22:07,710 --> 00:22:10,760
# so she took shelter under
# the arches near the mortuary.
#
# 409
# 00:22:10,853 --> 00:22:12,946
# That's when she saw him him.
# - Him?
#
# 410
# 00:22:13,463 --> 00:22:14,463
# A man.
#
# 411
# 00:22:14,821 --> 00:22:17,180
# Yes, I've gathered that
# but what did he look like?
#
# 412
# 00:22:17,422 --> 00:22:20,071
# Blackest of hair,
# bluest of eyes..
#
# 413
# 00:22:20,141 --> 00:22:22,461
# A crooked smile that would
# make the devil whimper.
#
# 414
# 00:22:22,830 --> 00:22:23,960
# Did she recognise him?
#
# 415
# 00:22:27,160 --> 00:22:28,210
# It's something I suppose.
#
# 416
# 00:22:28,895 --> 00:22:31,082
# Man, black hair, blue eyes.
#
# 417
# 00:22:32,015 --> 00:22:33,695
# You said she was
# sheltering from the rain.
#
# 418
# 00:22:34,175 --> 00:22:35,231
# It wasn't raining that night.
#
# 419
# 00:22:35,255 --> 00:22:37,695
# In fact, it hasn't rained
# for weeks and if it was dark,
#
# 420
# 00:22:37,775 --> 00:22:39,345
# how did she see
# he had blue eyes?
#
# 421
# 00:22:39,795 --> 00:22:41,165
# She's got good eyesight.
#
# 422
# 00:22:41,515 --> 00:22:42,995
# You said she had
# only one working eye.
#
# 423
# 00:22:45,477 --> 00:22:46,777
# You didn't go and see
# your sister, did you?
#
# 424
# 00:22:46,797 --> 00:22:47,836
# You drank my money.
#
# 425
# 00:22:47,852 --> 00:22:49,008
# She's terrifying
#
# 426
# 00:22:49,094 --> 00:22:51,640
# When I was a girl she stole my
# pet mouse and baked it in a pot.
#
# 427
# 00:22:51,657 --> 00:22:53,367
# I want my money back now.
#
# 428
# 00:22:53,517 --> 00:22:55,823
# I'd love to stay and chat
# but I've got to get to work.
#
# 429
# 00:23:12,514 --> 00:23:13,514
# Where is she?
#
# 430
# 00:23:14,154 --> 00:23:16,071
# Grave robbers drink here.
#
# 431
# 00:23:16,571 --> 00:23:18,171
# I said where is she?
#
# 432
# 00:23:18,427 --> 00:23:21,009
# Let me go in, ask around,
#
# 433
# 00:23:21,100 --> 00:23:24,044
# see about those two who
# were running from you.
#
# 434
# 00:23:24,158 --> 00:23:24,897
# How do you know about that?
#
# 435
# 00:23:24,987 --> 00:23:26,359
# You've been following me.
#
# 436
# 00:23:26,390 --> 00:23:30,567
# You're going... forget it, they
# will smell police a mile away.
#
# 437
# 00:23:32,097 --> 00:23:33,457
# And why would you
# want to help me?
#
# 438
# 00:23:33,767 --> 00:23:35,251
# We both know she's innocent
#
# 439
# 00:23:35,259 --> 00:23:38,523
# and those body snatchers
# will lead to the real thief.
#
# 440
# 00:23:38,617 --> 00:23:42,487
# So I will help you help her.
#
# 441
# 00:23:45,427 --> 00:23:46,777
# For a fee, of course.
#
# 442
# 00:23:48,417 --> 00:23:49,537
# I don't work with criminals.
#
# 443
# 00:23:52,007 --> 00:23:53,997
# Shame Miss Scarlet
# doesn't follow my example.
#
# 444
# 00:23:55,757 --> 00:23:56,757
# Good luck.
#
# 445
# 00:24:02,377 --> 00:24:03,887
# You're gonna need it.
#
# 446
# 00:24:16,527 --> 00:24:17,527
# Whiskey.
#
# 447
# 00:24:21,787 --> 00:24:22,787
# There you go.
#
# 448
# 00:24:23,927 --> 00:24:24,927
# Inspector.
#
# 449
# 00:24:39,697 --> 00:24:40,697
# Eliza
#
# 450
# 00:24:47,957 --> 00:24:50,597
# Mr Potts..
# - Do not bother Miss Woods.
#
# 451
# 00:24:52,457 --> 00:24:53,737
# It's your real name, is it not?
#
# 452
# 00:24:54,757 --> 00:24:56,387
# Miss Ivy Woods.
#
# 453
# 00:24:56,951 --> 00:24:59,427
# Yes. Yes it is.
#
# 454
# 00:25:01,132 --> 00:25:02,982
# And I'm so sorry to
# have deceived you.
#
# 455
# 00:25:03,847 --> 00:25:05,037
# It was for a good reason.
#
# 456
# 00:25:05,227 --> 00:25:08,287
# That's never a good reason
# to deceive, Miss Woods.
#
# 457
# 00:25:09,127 --> 00:25:10,545
# It comes as no surprise to me
#
# 458
# 00:25:10,585 --> 00:25:11,945
# that the lady who runs
# the house with that woman
#
# 459
# 00:25:11,969 --> 00:25:15,293
# should herself be
# unchristian in her ways.
#
# 460
# 00:25:15,887 --> 00:25:18,270
# I can assure you I don't
# make a habit of lying.
#
# 461
# 00:25:18,727 --> 00:25:22,043
# I love that girl and I
# do anything to help her.
#
# 462
# 00:25:22,857 --> 00:25:26,117
# I should never have believed
# that the chief coroner
#
# 463
# 00:25:26,197 --> 00:25:29,607
# would even consider inviting
# someone like me for dinner.
#
# 464
# 00:25:29,977 --> 00:25:33,447
# He'd think I'd know my
# place in the world by now.
#
# 465
# 00:25:34,040 --> 00:25:35,467
# And you haven't
# learned Barnabas..
#
# 466
# 00:25:35,617 --> 00:25:37,431
# I really am very sorry Mr Potts.
#
# 467
# 00:25:38,577 --> 00:25:40,759
# I've never done anything
# like this before.
#
# 468
# 00:25:40,939 --> 00:25:41,939
# Hah!
#
# 469
# 00:25:42,797 --> 00:25:43,797
# Take heart, Miss Woods.
#
# 470
# 00:25:45,017 --> 00:25:46,400
# Because you had me fooled.
#
# 471
# 00:25:47,117 --> 00:25:48,117
# Good day.
#
# 472
# 00:25:53,452 --> 00:25:57,014
# Mr Potts, did you spend
# money on a new tie?
#
# 473
# 00:26:08,677 --> 00:26:10,327
# Come on, cough up.
#
# 474
# 00:26:12,247 --> 00:26:14,047
# I think I'll take a lady
# out with my winnings.
#
# 475
# 00:26:16,067 --> 00:26:17,207
# How about..
#
# 476
# 00:26:18,287 --> 00:26:19,287
# Your mum?
#
# 477
# 00:26:24,677 --> 00:26:25,677
# Who's there?
#
# 478
# 00:26:27,067 --> 00:26:28,901
# I'm looking for a
# man about a job.
#
# 479
# 00:26:35,957 --> 00:26:38,551
# The kind that can make
# you serious money.
#
# 480
# 00:26:41,557 --> 00:26:42,557
# Is business good?
#
# 481
# 00:26:43,097 --> 00:26:46,307
# Booming, mate. Be even better if
# I weren't stuck with this ingrate.
#
# 482
# 00:26:47,597 --> 00:26:48,627
# Get on with you.
#
# 483
# 00:27:08,907 --> 00:27:10,707
# Take them to the cells.
# Keep them separate.
#
# 484
# 00:27:10,973 --> 00:27:12,452
# I'll question this one first.
#
# 485
# 00:27:12,477 --> 00:27:13,312
# I've done nothing!
#
# 486
# 00:27:13,344 --> 00:27:14,500
# Shut your mouth!
#
# 487
# 00:27:19,287 --> 00:27:20,755
# I do not like to be manhandled.
#
# 488
# 00:27:21,837 --> 00:27:23,677
# Best part of my
# day, arresting you.
#
# 489
# 00:27:24,647 --> 00:27:25,787
# We need it to look real.
#
# 490
# 00:27:27,357 --> 00:27:28,407
# This was your idea.
#
# 491
# 00:27:30,037 --> 00:27:32,941
# I got you your thief.
# Now it's your turn.
#
# 492
# 00:27:33,677 --> 00:27:35,778
# Well, I'd like to say it was a
# pleasure doing business with you,
#
# 493
# 00:27:35,802 --> 00:27:36,847
# but you know I'd be lying.
#
# 494
# 00:27:38,727 --> 00:27:41,247
# More where that came from, if you
# tell me where Miss Scarlet is.
#
# 495
# 00:27:45,647 --> 00:27:46,777
# I'll be watching you.
#
# 496
# 00:27:48,217 --> 00:27:51,529
# I'd expect nothing
# less, Inspector.
#
# 497
# 00:27:55,327 --> 00:27:57,637
# Why is this Miss Scarlet
# not in prison as we speak?
#
# 498
# 00:27:57,887 --> 00:28:00,497
# How has she evaded the entire
# Metropolitan Police force?
#
# 499
# 00:28:00,727 --> 00:28:02,156
# I know it's not
# ideal, but trust me.
#
# 500
# 00:28:02,180 --> 00:28:03,133
# You had this woman here
#
# 501
# 00:28:03,157 --> 00:28:04,597
# and she slipped
# through your fingers.
#
# 502
# 00:28:04,674 --> 00:28:06,514
# Well, I've had enough of
# this nonsense, Fergus.
#
# 503
# 00:28:06,667 --> 00:28:08,187
# I'm taking this up
# with your superiors.
#
# 504
# 00:28:08,927 --> 00:28:10,996
# Edmund..
# - Out of my way.
#
# 505
# 00:28:13,567 --> 00:28:15,887
# Sir, we have a
# development in the case.
#
# 506
# 00:28:15,981 --> 00:28:17,949
# You have the woman
# back in custody?
#
# 507
# 00:28:18,167 --> 00:28:20,184
# No, Sir, I have
# something better.
#
# 508
# 00:28:23,377 --> 00:28:27,257
# So just to confirm, this is not the
# woman who hired you to rob the grave
#
# 509
# 00:28:27,352 --> 00:28:28,352
# at Highgate Cemetery?
#
# 510
# 00:28:28,577 --> 00:28:29,894
# She was much older.
#
# 511
# 00:28:30,145 --> 00:28:31,843
# And this older woman is the same
#
# 512
# 00:28:31,867 --> 00:28:34,907
# as who you believe broke into
# the three burgled mortuaries.
#
# 513
# 00:28:40,937 --> 00:28:42,177
# How do you know this?
#
# 514
# 00:28:43,837 --> 00:28:46,547
# Because these nicked files
# that you keep banging on about
#
# 515
# 00:28:46,674 --> 00:28:49,293
# - she had them. Paid us to
# dig up every name on there.
#
# 516
# 00:28:49,333 --> 00:28:51,514
# When I say name the
# graves didn't have any.
#
# 517
# 00:28:51,767 --> 00:28:53,005
# All of them pauper graves.
#
# 518
# 00:28:55,227 --> 00:28:56,585
# And what was she looking for?
#
# 519
# 00:28:57,317 --> 00:28:58,632
# Not a bleeding clue.
#
# 520
# 00:28:59,537 --> 00:29:00,547
# But whatever it was
#
# 521
# 00:29:01,377 --> 00:29:03,662
# all she found were
# bags of bones.
#
# 522
# 00:29:04,077 --> 00:29:05,077
# So, what happened?
#
# 523
# 00:29:05,527 --> 00:29:07,037
# Tell me about this woman.
#
# 524
# 00:29:07,817 --> 00:29:10,237
# Name, age, appearance.
#
# 525
# 00:29:10,617 --> 00:29:11,686
# I don't know her name.
#
# 526
# 00:29:12,927 --> 00:29:14,209
# Only that they call her
#
# 527
# 00:29:14,647 --> 00:29:15,709
# Bloody Mary.
#
# 528
# 00:29:16,217 --> 00:29:17,560
# Been inside for years.
#
# 529
# 00:29:18,397 --> 00:29:19,521
# Newgate, I think.
#
# 530
# 00:29:19,977 --> 00:29:23,151
# And as for what she looked like,
# well, you should know - you met her.
#
# 531
# 00:29:23,517 --> 00:29:24,517
# What?
#
# 532
# 00:29:24,597 --> 00:29:26,213
# When me and Watts did
# a runner at Highgate
#
# 533
# 00:29:26,237 --> 00:29:29,603
# We thought she was done for but the silly
# tart couldn't run away in a dress, could she?
#
# 534
# 00:29:29,627 --> 00:29:31,671
# No, the only person I
# met was the vicar's wife,
#
# 535
# 00:29:31,737 --> 00:29:33,258
# a Mrs Ellis.
#
# 536
# 00:29:33,321 --> 00:29:35,254
# That was no vicar's wife mate.
#
# 537
# 00:29:36,577 --> 00:29:37,657
# That was Bloody Mary.
#
# 538
# 00:29:42,157 --> 00:29:44,210
# Just so I'm clear,
# crystal clear,
#
# 539
# 00:29:44,265 --> 00:29:46,263
# you had the perpetrator
# in that very room
#
# 540
# 00:29:46,295 --> 00:29:47,093
# and you let her go.
#
# 541
# 00:29:47,137 --> 00:29:47,945
# Sir, I can only apolo..
#
# 542
# 00:29:47,970 --> 00:29:49,371
# This is very
# disappointing laddie..
#
# 543
# 00:29:49,937 --> 00:29:50,787
# Clearly I should have stuck
#
# 544
# 00:29:50,837 --> 00:29:52,817
# with first instinct. I will
# not make that mistake again.
#
# 545
# 00:29:52,841 --> 00:29:53,504
# Sorry..
#
# 546
# 00:29:53,528 --> 00:29:55,591
# Another officer will take
# over the investigation.
#
# 547
# 00:29:55,615 --> 00:29:56,615
# Sir, that..
#
# 548
# 00:30:10,047 --> 00:30:11,160
# What happened here?
#
# 549
# 00:30:11,824 --> 00:30:13,120
# Went to see my sister.
#
# 550
# 00:30:13,191 --> 00:30:14,691
# What, she did that?
#
# 551
# 00:30:14,722 --> 00:30:17,754
# I gave as good as I got. Actually
# I think she came off worse.
#
# 552
# 00:30:18,117 --> 00:30:19,587
# Now, I have some information.
#
# 553
# 00:30:19,709 --> 00:30:22,679
# My sister did see the thief. It was
# a woman, fair hair, black dress.
#
# 554
# 00:30:22,817 --> 00:30:24,907
# Old, very old, at least 50.
#
# 555
# 00:30:25,057 --> 00:30:25,937
# Did she recognise her?
#
# 556
# 00:30:26,037 --> 00:30:28,627
# Not a clue. Unlike the
# constable from Scotland Yard
#
# 557
# 00:30:28,722 --> 00:30:29,941
# who drinks at my local.
#
# 558
# 00:30:29,996 --> 00:30:32,065
# How he loves the chat
# when he's had a few.
#
# 559
# 00:30:32,357 --> 00:30:34,729
# Reckon I'd make a good
# lady detective myself.
#
# 560
# 00:30:35,437 --> 00:30:36,607
# Tell me everything you know.
#
# 561
# 00:30:40,077 --> 00:30:41,607
# I was just coming to get you.
#
# 562
# 00:30:41,842 --> 00:30:43,405
# She's a wily one,
# that Clementine.
#
# 563
# 00:30:43,444 --> 00:30:44,944
# Remind me to employ
# her more often.
#
# 564
# 00:30:44,981 --> 00:30:46,423
# Where are you going?
#
# 565
# 00:30:46,453 --> 00:30:47,545
# To solve the case.
#
# 566
# 00:30:47,702 --> 00:30:49,403
# But you have not been
# working the case.
#
# 567
# 00:30:49,427 --> 00:30:51,850
# I have and I have news.
#
# 568
# 00:30:51,920 --> 00:30:53,520
# You're in the clear.
#
# 569
# 00:30:56,107 --> 00:30:57,107
# Come on Moses.
#
# 570
# 00:30:57,517 --> 00:30:58,517
# We've work to do.
#
# 571
# 00:31:05,617 --> 00:31:06,617
# So.
#
# 572
# 00:31:07,237 --> 00:31:08,345
# What did the vicar say?
#
# 573
# 00:31:09,397 --> 00:31:10,400
# What I expected.
#
# 574
# 00:31:11,057 --> 00:31:12,345
# He has no wife.
#
# 575
# 00:31:13,797 --> 00:31:15,237
# Where's the information
# I requested?
#
# 576
# 00:31:17,617 --> 00:31:20,207
# Since you are officially
# off the investigation,
#
# 577
# 00:31:20,317 --> 00:31:21,672
# I thought it safer
# to memorise it
#
# 578
# 00:31:21,697 --> 00:31:23,233
# just in case I was stopped
# coming out of the yard.
#
# 579
# 00:31:23,257 --> 00:31:24,718
# Don't get carried away, man.
#
# 580
# 00:31:24,843 --> 00:31:25,993
# But you are off the case, Sir?
#
# 581
# 00:31:26,017 --> 00:31:27,203
# I don't wish to talk about it.
#
# 582
# 00:31:27,227 --> 00:31:28,353
# It's all anyone can talk about.
#
# 583
# 00:31:28,377 --> 00:31:29,377
# Good for them.
#
# 584
# 00:31:29,467 --> 00:31:31,367
# If you would kindly
# impart the information
#
# 585
# 00:31:31,447 --> 00:31:34,127
# that has been so carefully
# concealed in that brain of yours
#
# 586
# 00:31:34,217 --> 00:31:35,217
# and hurry up about it.
#
# 587
# 00:31:35,357 --> 00:31:37,547
# This bloody Mary's real
# name is Mary Dawson.
#
# 588
# 00:31:37,737 --> 00:31:40,207
# She was part of a gang of diamond
# smugglers back in the 50s.
#
# 589
# 00:31:40,457 --> 00:31:43,027
# She served 25 years at Newgate,
# was released last week.
#
# 590
# 00:31:44,427 --> 00:31:45,427
# What is it, Sir?
#
# 591
# 00:31:57,867 --> 00:32:00,338
# Who sends flowers
# to a pauper grave?
#
# 592
# 00:32:03,137 --> 00:32:06,427
# Yes, that particular grave receives
# flowers each and every month.
#
# 593
# 00:32:06,937 --> 00:32:08,613
# Write down the address
# of the sender for me.
#
# 594
# 00:32:08,637 --> 00:32:09,882
# Certainly, Inspector.
#
# 595
# 00:32:11,877 --> 00:32:12,877
# What?
#
# 596
# 00:32:13,677 --> 00:32:14,677
# Sorry Sir.
#
# 597
# 00:32:15,727 --> 00:32:17,473
# Have you ever been
# taken off a case before?
#
# 598
# 00:32:17,511 --> 00:32:19,663
# I thought I made it clear that
# I do not wish to talk about it.
#
# 599
# 00:32:19,687 --> 00:32:21,317
# You did Sir. Sorry,
# Sir. Understood.
#
# 600
# 00:32:22,967 --> 00:32:25,897
# For what it's worth, Sir, the
# officer Munro replaced you with is..
#
# 601
# 00:32:27,297 --> 00:32:29,327
# Sorry Sir, you do not
# wish to talk about it.
#
# 602
# 00:32:29,757 --> 00:32:30,757
# Thank you detective.
#
# 603
# 00:32:35,987 --> 00:32:36,987
# Who is it?
#
# 604
# 00:32:37,534 --> 00:32:38,335
# Carmichael, Sir.
#
# 605
# 00:32:38,360 --> 00:32:42,172
# Carmichael? Couldn't investigate
# a booze up in a brewery, that one.
#
# 606
# 00:32:43,147 --> 00:32:44,147
# As requested, Sir.
#
# 607
# 00:32:45,687 --> 00:32:47,237
# Address of the account holder.
#
# 608
# 00:32:47,767 --> 00:32:48,767
# Thank you.
#
# 609
# 00:32:48,857 --> 00:32:52,447
# It's a curious thing, but you're not
# the first person who has inquired
#
# 610
# 00:32:52,527 --> 00:32:54,437
# about that particular
# account today.
#
# 611
# 00:32:54,927 --> 00:32:56,677
# Who else has inquired about it?
#
# 612
# 00:32:57,307 --> 00:33:01,113
# A lady. Blond hair
# determined demeanour.
#
# 613
# 00:33:13,037 --> 00:33:14,239
# I don't know where to begin.
#
# 614
# 00:33:14,264 --> 00:33:15,147
# I can explain.
#
# 615
# 00:33:15,171 --> 00:33:16,211
# Don't bother.
#
# 616
# 00:33:19,497 --> 00:33:21,487
# See to it that Miss Scarlet
# stays in the carriage.
#
# 617
# 00:33:21,637 --> 00:33:22,098
# Yes, Sir.
#
# 618
# 00:33:22,657 --> 00:33:23,657
# Hello Miss Scarlet.
#
# 619
# 00:33:24,107 --> 00:33:26,417
# Do not converse with her or
# let her out of your sight.
#
# 620
# 00:33:26,647 --> 00:33:27,647
# I'll deal with you later.
#
# 621
# 00:33:45,217 --> 00:33:46,217
# Inspector
#
# 622
# 00:33:50,737 --> 00:33:53,127
# I thought you'd been replaced
# on the investigation.
#
# 623
# 00:33:55,340 --> 00:33:59,120
# And I thought sending flowers to
# a grave listed in the stolen files
#
# 624
# 00:33:59,147 --> 00:34:01,330
# might have been something
# that you would have mentioned.
#
# 625
# 00:34:01,354 --> 00:34:02,393
# No, it's merely a coincidence
#
# 626
# 00:34:02,417 --> 00:34:03,768
# that my connection
# with that grave
#
# 627
# 00:34:03,793 --> 00:34:06,537
# should have dovetailed
# with this investigation.
#
# 628
# 00:34:07,003 --> 00:34:08,588
# I've been in the force a
# long time, Mr. Thackery
#
# 629
# 00:34:08,612 --> 00:34:10,257
# and in my experience,
#
# 630
# 00:34:10,527 --> 00:34:12,727
# a coincidence never holds
# up to much scrutiny.
#
# 631
# 00:34:13,287 --> 00:34:14,567
# Well, in this
# case, you're wrong.
#
# 632
# 00:34:15,127 --> 00:34:17,027
# It is a simple explanation,
#
# 633
# 00:34:17,107 --> 00:34:19,103
# However it's not something
# I'm comfortable to speak of,
#
# 634
# 00:34:19,127 --> 00:34:21,037
# nor should I have to
# explain myself to you.
#
# 635
# 00:34:21,227 --> 00:34:24,457
# Well, if you prefer, you can explain
# yourself to Detective Carmichael,
#
# 636
# 00:34:24,747 --> 00:34:26,477
# who I believe
# Superintendent Munro
#
# 637
# 00:34:26,557 --> 00:34:28,577
# has now assigned to this case.
#
# 638
# 00:34:28,727 --> 00:34:31,968
# And I can assure you he will
# not be as discrete as I am.
#
# 639
# 00:34:37,187 --> 00:34:38,187
# The fact is.
#
# 640
# 00:34:39,557 --> 00:34:42,457
# I had a humble upbringing.
#
# 641
# 00:34:43,677 --> 00:34:44,677
# It was more than humble.
#
# 642
# 00:34:45,657 --> 00:34:46,777
# I was born in the workhouse.
#
# 643
# 00:34:47,787 --> 00:34:49,427
# It's something I don't
# like to talk about.
#
# 644
# 00:34:50,417 --> 00:34:54,107
# And rarely reveal, particularly
# being a man of such status,
#
# 645
# 00:34:54,437 --> 00:34:56,305
# but from a young age I was.
#
# 646
# 00:34:56,757 --> 00:34:58,787
# Utterly determined to
# make something of myself,
#
# 647
# 00:34:59,117 --> 00:35:00,133
# and as you can see.
#
# 648
# 00:35:00,767 --> 00:35:01,852
# I was successful.
#
# 649
# 00:35:03,397 --> 00:35:05,517
# There were many people who
# helped me along the way.
#
# 650
# 00:35:06,367 --> 00:35:07,407
# Not least of all, my wife.
#
# 651
# 00:35:08,747 --> 00:35:10,107
# And for that I'm
# forever grateful.
#
# 652
# 00:35:14,287 --> 00:35:15,287
# So in short,
#
# 653
# 00:35:16,357 --> 00:35:18,037
# my fate could have been
# somewhat different.
#
# 654
# 00:35:19,037 --> 00:35:22,966
# And as a Christian man, and in
# my position as chief coroner
#
# 655
# 00:35:23,397 --> 00:35:26,267
# whenever I happen upon a pauper
# grave, I like to send flowers.
#
# 656
# 00:35:26,597 --> 00:35:27,907
# It is a small kindness
#
# 657
# 00:35:29,697 --> 00:35:30,697
# and it helps me remember.
#
# 658
# 00:35:31,737 --> 00:35:32,737
# Remember?
#
# 659
# 00:35:33,197 --> 00:35:35,196
# There, but for the grace of God,
#
# 660
# 00:35:36,727 --> 00:35:37,727
# Go I.
#
# 661
# 00:35:41,547 --> 00:35:42,547
# So.
#
# 662
# 00:35:45,637 --> 00:35:47,317
# Well, I appreciate
# your candor, Sir,
#
# 663
# 00:35:47,397 --> 00:35:51,647
# but I'm afraid there's still some questions
# that I need to ask regarding the case.
#
# 664
# 00:35:51,877 --> 00:35:52,572
# What, why?
#
# 665
# 00:35:52,597 --> 00:35:53,597
# Surely we're done here?
#
# 666
# 00:35:54,077 --> 00:35:55,607
# We're done when
# I say we're done.
#
# 667
# 00:35:55,737 --> 00:35:56,737
# Mr Thackery.
#
# 668
# 00:36:15,337 --> 00:36:16,597
# How did you know I was here?
#
# 669
# 00:36:17,214 --> 00:36:20,534
# Inspector Wellington specifically ordered
# me not to converse with you, Miss Scarlet.
#
# 670
# 00:36:21,497 --> 00:36:22,497
# Very well.
#
# 671
# 00:36:23,237 --> 00:36:25,636
# Although I'm surprised that a
# gentleman with impeccable manners,
#
# 672
# 00:36:25,660 --> 00:36:27,363
# such as yourself,
# would be so rude,
#
# 673
# 00:36:27,461 --> 00:36:28,687
# I'm only following orders.
#
# 674
# 00:36:29,537 --> 00:36:31,967
# Please forgive me, I do hold
# you in the highest regard.
#
# 675
# 00:36:34,147 --> 00:36:36,425
# I don't wish to get you
# into trouble Detective.
#
# 676
# 00:36:37,277 --> 00:36:39,839
# By answering one simple question,
# can you really do any harm?
#
# 677
# 00:36:42,402 --> 00:36:46,253
# The florist advised that you'd been asking
# who sent the flowers to the pauper grave?
#
# 678
# 00:36:47,227 --> 00:36:48,941
# But I didn't speak
# to the florist.
#
# 679
# 00:36:49,667 --> 00:36:51,197
# Moses got that
# information to me.
#
# 680
# 00:36:51,672 --> 00:36:53,833
# Well then, who was the blond
# lady the florist spoke of?
#
# 681
# 00:36:56,037 --> 00:36:58,445
# No, I do not know this
# Mary Dawson or Bloody Mary,
#
# 682
# 00:36:58,470 --> 00:36:59,693
# or whatever the
# devil she's called.
#
# 683
# 00:36:59,717 --> 00:37:01,413
# I'm as anxious as you to get
# this criminal into custody
#
# 684
# 00:37:01,437 --> 00:37:02,773
# and find out what
# the hell is going on.
#
# 685
# 00:37:02,797 --> 00:37:04,857
# And I've answered all
# your questions inspector.
#
# 686
# 00:37:04,951 --> 00:37:07,112
# My wife and the maid will be
# back from my errands soon.
#
# 687
# 00:37:07,527 --> 00:37:09,240
# I'd like you gone
# before they return.
#
# 688
# 00:37:12,122 --> 00:37:15,794
# You seem extremely keen to
# get rid of me, Mr. Thackery.
#
# 689
# 00:37:16,487 --> 00:37:18,497
# Well, a reputation can be
# undone by such a visit.
#
# 690
# 00:37:19,497 --> 00:37:21,587
# I do not want to be the
# topic of idle gossip.
#
# 691
# 00:37:27,647 --> 00:37:28,647
# I thought you were alone.
#
# 692
# 00:37:30,827 --> 00:37:32,655
# No, that'll just be the maid.
#
# 693
# 00:37:34,087 --> 00:37:36,237
# The maid who's running
# errands with your wife?
#
# 694
# 00:37:40,897 --> 00:37:43,267
# No, do not open
# that door. Please!
#
# 695
# 00:37:50,457 --> 00:37:52,237
# Nice to see you
# again, Inspector.
#
# 696
# 00:37:52,354 --> 00:37:54,167
# Put the revolver down Mary.
#
# 697
# 00:37:55,057 --> 00:37:56,417
# I was about to say
# the same to you.
#
# 698
# 00:37:57,797 --> 00:37:58,797
# And if you don't,
#
# 699
# 00:37:58,877 --> 00:38:00,687
# I will shoot Mrs
# Thackery in the head.
#
# 700
# 00:38:01,017 --> 00:38:02,764
# No, Mary, please,
# please do not do this.
#
# 701
# 00:38:02,795 --> 00:38:03,795
# Shut up.
#
# 702
# 00:38:04,987 --> 00:38:05,987
# I'll deal with you later.
#
# 703
# 00:38:10,567 --> 00:38:11,567
# I said
#
# 704
# 00:38:11,937 --> 00:38:14,300
# put it down.
#
# 705
# 00:38:28,347 --> 00:38:29,347
# Kick it towards me.
#
# 706
# 00:38:32,399 --> 00:38:33,399
# Good.
#
# 707
# 00:38:36,337 --> 00:38:40,155
# But on second thoughts, I think
# I'm gonna kill her anyway.
#
# 708
# 00:38:42,867 --> 00:38:44,663
# I would recommend
# that you do not.
#
# 709
# 00:39:01,757 --> 00:39:04,447
# You know that using a
# policeman's weapon is an offence.
#
# 710
# 00:39:05,217 --> 00:39:08,217
# Would you have preferred if I
# had dispatched Detective Fitzroy?
#
# 711
# 00:39:21,667 --> 00:39:24,595
# My real name is Alfie Frampton.
#
# 712
# 00:39:26,024 --> 00:39:28,134
# Mary Dawson was my fiancée.
#
# 713
# 00:39:29,047 --> 00:39:30,247
# We were small time crooks
#
# 714
# 00:39:30,327 --> 00:39:32,595
# but we managed to pull
# off a diamond heist.
#
# 715
# 00:39:36,727 --> 00:39:37,517
# When can I see my wife?
#
# 716
# 00:39:37,607 --> 00:39:38,927
# She knows nothing
# of any of this.
#
# 717
# 00:39:39,637 --> 00:39:40,715
# Get on with it.
#
# 718
# 00:39:43,897 --> 00:39:45,127
# I took the diamonds and ran.
#
# 719
# 00:39:46,089 --> 00:39:47,089
# But Mary tracked me down.
#
# 720
# 00:39:47,182 --> 00:39:48,182
# She's like a..
#
# 721
# 00:39:48,370 --> 00:39:49,370
# Like a mad woman.
#
# 722
# 00:39:49,797 --> 00:39:51,245
# She was attacking
# me. She was..
#
# 723
# 00:39:51,917 --> 00:39:53,117
# Desperate to get hold of them.
#
# 724
# 00:39:54,237 --> 00:39:55,380
# So I swallowed them.
#
# 725
# 00:39:56,327 --> 00:39:57,606
# You swallowed the diamonds?
#
# 726
# 00:39:58,327 --> 00:39:59,841
# And in return she gave me this.
#
# 727
# 00:40:04,647 --> 00:40:07,132
# The police turned up after
# a tip-off and arrested Mary.
#
# 728
# 00:40:08,417 --> 00:40:09,703
# But I managed to escape.
#
# 729
# 00:40:11,387 --> 00:40:12,387
# And with her inside.
#
# 730
# 00:40:13,557 --> 00:40:14,557
# I saw a way out.
#
# 731
# 00:40:15,547 --> 00:40:16,703
# To leave her behind.
#
# 732
# 00:40:17,837 --> 00:40:19,321
# To leave my past behind.
#
# 733
# 00:40:21,427 --> 00:40:22,899
# So I faked my own death.
#
# 734
# 00:40:23,617 --> 00:40:25,962
# You used the corpse from the
# pauper's grave in Highgate.
#
# 735
# 00:40:26,557 --> 00:40:28,735
# That's why you sent
# flowers to it each month.
#
# 736
# 00:40:29,507 --> 00:40:30,507
# Poor soul..
#
# 737
# 00:40:32,267 --> 00:40:33,507
# Whoever he was
#
# 738
# 00:40:35,707 --> 00:40:36,890
# gave me a new life.
#
# 739
# 00:40:41,237 --> 00:40:43,574
# Frampton took the body
# to one of their hideouts,
#
# 740
# 00:40:43,590 --> 00:40:44,573
# changed clothes with the man,
#
# 741
# 00:40:44,597 --> 00:40:46,053
# and then gave him a
# cut down his cheek,
#
# 742
# 00:40:46,077 --> 00:40:47,667
# just like Dawson
# had done to him.
#
# 743
# 00:40:48,377 --> 00:40:51,491
# I'm pretty sure he always told you that
# he got that scar from the Crimea, Sir.
#
# 744
# 00:40:51,592 --> 00:40:52,933
# I'm not the only one
# who believed him.
#
# 745
# 00:40:52,957 --> 00:40:54,163
# He told everyone that.
#
# 746
# 00:40:57,647 --> 00:40:59,247
# I wasn't questioning
# your judgment, Sir.
#
# 747
# 00:41:00,767 --> 00:41:01,707
# From her prison cell,
#
# 748
# 00:41:01,787 --> 00:41:03,027
# Mary Dawson read about the body
#
# 749
# 00:41:03,087 --> 00:41:05,647
# in the papers and assumed
# it was that of her fiancé.
#
# 750
# 00:41:06,010 --> 00:41:07,647
# And then when she'd
# served her time,
#
# 751
# 00:41:07,727 --> 00:41:09,437
# she went about tracking
# down his grave.
#
# 752
# 00:41:11,197 --> 00:41:12,197
# Come.
#
# 753
# 00:41:14,097 --> 00:41:16,449
# Detective Phelps
# come and take a seat.
#
# 754
# 00:41:26,777 --> 00:41:27,777
# Continue.
#
# 755
# 00:41:28,279 --> 00:41:30,703
# Dawson believed that she
# would find the diamonds
#
# 756
# 00:41:30,807 --> 00:41:32,807
# that Frampton had swallowed
# in one of those graves.
#
# 757
# 00:41:33,157 --> 00:41:36,217
# But what she didn't know was that
# he'd sold them to reinvent himself.
#
# 758
# 00:41:36,307 --> 00:41:37,937
# He put himself through
# medical school,
#
# 759
# 00:41:38,027 --> 00:41:39,357
# he changed his whole life.
#
# 760
# 00:41:39,855 --> 00:41:41,417
# Whiskey, detective Phelps.
#
# 761
# 00:41:44,497 --> 00:41:45,497
# Thank you Sir.
#
# 762
# 00:41:47,727 --> 00:41:49,517
# What of your friend,
# Miss Scarlet?
#
# 763
# 00:41:49,834 --> 00:41:52,152
# Thackery wanted to pin this on
# her at the earliest opportunity
#
# 764
# 00:41:52,176 --> 00:41:54,971
# in the hope that the trail
# would end there and then.
#
# 765
# 00:41:54,996 --> 00:41:58,121
# If Dawson did find him, then
# he would cut a deal with him.
#
# 766
# 00:41:59,567 --> 00:42:01,883
# Well, I think I'm fully briefed.
#
# 767
# 00:42:01,953 --> 00:42:04,086
# That will be all,
# Inspector Wellington.
#
# 768
# 00:42:05,317 --> 00:42:08,547
# Sir, I know that I disobeyed
# orders by continuing with the case.
#
# 769
# 00:42:08,637 --> 00:42:10,297
# That will be all Inspector.
#
# 770
# 00:42:13,137 --> 00:42:14,137
# Yes, Sir.
#
# 771
# 00:42:15,527 --> 00:42:17,101
# Well, detective Phelps.
#
# 772
# 00:42:17,923 --> 00:42:19,881
# I've heard nothing but
# good reports about you.
#
# 773
# 00:42:19,929 --> 00:42:21,483
# Tell me more about yourself.
#
# 774
# 00:42:22,014 --> 00:42:24,467
# We're always on the look
# out for a good loyal man.
#
# 775
# 00:42:24,697 --> 00:42:25,697
# Yes, Sir.
#
# 776
# 00:42:27,727 --> 00:42:28,727
# Thank you, Sir.
#
# 777
# 00:42:36,507 --> 00:42:37,507
# How childish men are.
#
# 778
# 00:42:38,655 --> 00:42:40,667
# Still, he'll get over it.
#
# 779
# 00:42:41,277 --> 00:42:42,307
# No, he won't.
#
# 780
# 00:42:42,357 --> 00:42:44,314
# Loyalty is everything
# to men like Munro,
#
# 781
# 00:42:44,417 --> 00:42:45,607
# and I disobeyed an order.
#
# 782
# 00:42:46,437 --> 00:42:47,674
# Oh, so this is my fault?
#
# 783
# 00:42:48,937 --> 00:42:49,963
# Actually, yes.
#
# 784
# 00:42:51,047 --> 00:42:53,537
# I was the one who saved
# Mrs Thackey's life
#
# 785
# 00:42:53,627 --> 00:42:55,287
# and most probably yours, too.
#
# 786
# 00:42:59,607 --> 00:43:01,955
# So I hear you and Moses
# made quite the partnership.
#
# 787
# 00:43:03,627 --> 00:43:04,627
# First of many.
#
# 788
# 00:43:07,207 --> 00:43:08,988
# I'm just teasing you, William.
#
# 789
# 00:43:09,137 --> 00:43:10,949
# But I don't - you know
# - I don't like him.
#
# 790
# 00:43:15,207 --> 00:43:16,749
# Now, I should get back to work.
#
# 791
# 00:43:17,867 --> 00:43:19,421
# It's probably a good idea,
#
# 792
# 00:43:19,500 --> 00:43:23,020
# trying to get back into the
# superintendent's good books.
#
# 793
# 00:43:23,047 --> 00:43:25,393
# Eliza, will you at least pretend
# that you say that for my sake,
#
# 794
# 00:43:25,417 --> 00:43:26,797
# rather than your own benefit?
#
# 795
# 00:43:27,207 --> 00:43:29,861
# William, you really do have a
# low opinion of me sometimes.
#
# 796
# 00:43:30,057 --> 00:43:31,080
# Only sometimes?
#
# 797
# 00:43:38,917 --> 00:43:40,407
# So any plans for this evening?
#
# 798
# 00:43:40,792 --> 00:43:42,232
# Well, I did have
#
# 799
# 00:43:42,387 --> 00:43:43,745
# till Ivy buggered them up.
#
# 800
# 00:43:44,247 --> 00:43:46,327
# Oh yes, Betsy wasn't it?
#
# 801
# 00:43:47,497 --> 00:43:48,497
# Sorry about that.
#
# 802
# 00:43:55,707 --> 00:43:57,010
# Miss Scarlet.
#
# 803
# 00:43:57,667 --> 00:43:58,807
# Inspector Wellington.
#
# 804
# 00:44:00,815 --> 00:44:01,815
# I'll leave you to it.
#
# 805
# 00:44:05,593 --> 00:44:09,317
# Mr Potts, before you say
# anything, please let me apologise.
#
# 806
# 00:44:09,343 --> 00:44:11,405
# I'm not here to see
# you Miss Scarlet.
#
# 807
# 00:44:12,163 --> 00:44:15,123
# Mr Potts, you
# received my message
#
# 808
# 00:44:15,452 --> 00:44:18,061
# and I would be delighted to
# take you up on your offer
#
# 809
# 00:44:18,092 --> 00:44:20,467
# of that homemade steamed
# pudding, Miss Woods.
#
# 810
# 00:44:20,557 --> 00:44:21,917
# Prince Albert's favorite,
#
# 811
# 00:44:21,997 --> 00:44:23,637
# and I've added
# some extra raisins.
#
# 812
# 00:44:24,967 --> 00:44:25,967
# Come on in.
#
# 813
# 00:44:37,098 --> 00:44:41,645
# You can go on another adventure
# with Eliza in a Victorian London.
#
# 814
# 00:44:41,730 --> 00:44:47,810
# Miss Scarlet and the Duke continues new and
# exclusive to alibi on Tuesday night at 9:00.
#
# 815
# 00:44:47,934 --> 00:44:50,794
# Next..Frankie Drake mysteries.
#
# 816
# 00:45:01,137 --> 00:45:02,137
# Oh
#
# 817
# 00:45:03,305 --> 00:46:03,315
# Advertise your product or brand here
# contact www.OpenSubtitles.org today

# %% [markdown]
# **Look's like it worked.**

# %% [markdown]
# ## **Step 6 - Applying the above Function on the Entire Data**

# %%
import zipfile
import io

count = 0

def decode_method(binary_data):
    global count
    # Decompress the binary data using the zipfile module
    # print(count, end=" ")
    count += 1
    with io.BytesIO(binary_data) as f:
        with zipfile.ZipFile(f, 'r') as zip_file:
            # Assuming there's only one file in the ZIP archive
            subtitle_content = zip_file.read(zip_file.namelist()[0])
    
    # Now 'subtitle_content' should contain the extracted subtitle content
    return subtitle_content.decode('latin-1')  # Assuming the content is UTF-8 encoded text

# %%
df['file_content'] = df['content'].apply(decode_method)

df.head()
# Out:
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                              content  \
# 0  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x1c\xa9\x...
# 1  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x17\xb9\x...
# 2  b'PK\x03\x04\x14\x00\x00\x00\x08\x00L\xb9\x99V...
# 3  b'PK\x03\x04\x14\x00\x00\x00\x08\x00U\xa9\x99V...
# 4  b'PK\x03\x04\x14\x00\x00\x00\x08\x001\xa9\x99V...
#
#                                         file_content
# 0  1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch an...
# 1  1\r\n00:00:29,359 --> 00:00:32,048\r\nAh! Ther...
# 2  1\r\n00:00:53,200 --> 00:00:56,030\r\n<i>Yumi'...
# 3  1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch an...
# 4  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82498 entries, 0 to 82497
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   num           82498 non-null  int64
#  1   name          82498 non-null  object
#  2   content       82498 non-null  object
#  3   file_content  82498 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 2.5+ MB

# %%
df
# Out:
#            num                                               name  \
# 0      9180533                         the.message.(1976).eng.1cd
# 1      9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2      9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3      9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4      9180600                              broker.(2022).eng.1cd
# ...        ...                                                ...
# 82493  9521935                   the.prophets.game.(2000).eng.1cd
# 82494  9521937                         west.beirut.(1998).eng.1cd
# 82495  9521938         frankenstein.the.true.story.(1973).eng.1cd
# 82496  9521940         frankenstein.the.true.story.(1973).eng.1cd
# 82497  9521941              zombie.island.massacre.(1984).eng.1cd
#
#                                                  content  \
# 0      b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x1c\xa9\x...
# 1      b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x17\xb9\x...
# 2      b'PK\x03\x04\x14\x00\x00\x00\x08\x00L\xb9\x99V...
# 3      b'PK\x03\x04\x14\x00\x00\x00\x08\x00U\xa9\x99V...
# 4      b'PK\x03\x04\x14\x00\x00\x00\x08\x001\xa9\x99V...
# ...                                                  ...
# 82493  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xb8\xa6\x...
# 82494  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x13\x97\x...
# 82495  b'PK\x03\x04\x14\x00\x00\x00\x08\x00$\x97\x9aV...
# 82496  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x00\x97\x...
# 82497  b'PK\x03\x04\x14\x00\x00\x00\x08\x00,\x97\x9aV...
#
#                                             file_content
# 0      1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch an...
# 1      1\r\n00:00:29,359 --> 00:00:32,048\r\nAh! Ther...
# 2      1\r\n00:00:53,200 --> 00:00:56,030\r\n<i>Yumi'...
# 3      1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch an...
# 4      ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch...
# ...                                                  ...
# 82493  ï»¿1\r\n00:01:16,284 --> 00:01:19,537\r\nGod,\...
# 82494  1\r\n00:00:06,000 --> 00:00:12,074\r\napi.Open...
# 82495  1\r\n00:00:01,001 --> 00:00:04,630\r\n(Dramati...
# 82496  1\r\n00:00:06,000 --> 00:00:12,074\r\nAdvertis...
# 82497  1\r\n00:00:01,919 --> 00:00:03,253\r\n(Sharp w...
#
# [82498 rows x 4 columns]

# %%
import nltk

# Download the punctuations
nltk.download('punkt')
# Download the stop words corpus
nltk.download('stopwords')
# Downloading wordnet before applying Lemmatizer
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Abinay
# [nltk_data]     Rachakonda\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Abinay
# [nltk_data]     Rachakonda\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Abinay
# [nltk_data]     Rachakonda\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\Abinay
# [nltk_data]     Rachakonda\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
import re
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
stemmer = PorterStemmer()
## We can also use Lemmatizer instead of Stemmer
lemmatizer = WordNetLemmatizer()

# %%
def preprocess(raw_text, flag):
    # Removing special characters and digits
    sentence = re.sub("[^a-zA-Z]", " ", str(raw_text))
    
    # change sentence to lower case
    sentence = sentence.lower()

    # tokenize into words
    tokens = sentence.split()
    
    # remove stop words                
    clean_tokens = [t for t in tokens if not t in stopwords.words("english")]
    
    # Stemming/Lemmatization
    if(flag == 'stem'):
        clean_tokens = [stemmer.stem(word) for word in clean_tokens]
    else:
        clean_tokens = [lemmatizer.lemmatize(word) for word in clean_tokens]
    
    return pd.Series([" ".join(clean_tokens), len(clean_tokens)])

# %%
df=df.sample(n=10000)

# %%
df
# Out:
#            num                                               name  \
# 13279  9236872  love.my.way.s03.e08.and.in.the.end.(2007).eng.1cd
# 44425  9364321  beverly.hills.90210.s10.e22.the.easter.bunny.(...
# 64279  9447124  csi.cyber.s01.e10.click.your.poison.(2015).eng...
# 63878  9446076      mom.s07.e02.pop.pop.and.a.puma.(2019).eng.1cd
# 39196  9341999                           dead.heat.(1988).eng.1cd
# ...        ...                                                ...
# 73303  9482761    the.brief.s02.e02.lack.of.affect.(2005).eng.1cd
# 75262  9491555                      the.turnaround.(2017).eng.1cd
# 78521  9505995             joe.90.s01.e10.big.fish.(1968).eng.1cd
# 38163  9337444  revenge.of.others.s01.e04.episode.1.4.(2022).e...
# 19232  9258576  the.daily.life.of.the.immortal.king.s02.e12.th...
#
#                                                  content  \
# 13279  b'PK\x03\x04\x14\x00\x00\x00\x08\x00U\x97\x99V...
# 44425  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x05\x0c\x...
# 64279  b'PK\x03\x04\x14\x00\x00\x00\x08\x00KH\x9aV2\x...
# 63878  b'PK\x03\x04\x14\x00\x00\x00\x08\x00JG\x9aV\xe...
# 39196  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x02\xbc\x...
# ...                                                  ...
# 73303  b'PK\x03\x04\x14\x00\x00\x00\x08\x00rv\x9aV\x7...
# 75262  b'PK\x03\x04\x14\x00\x00\x00\x08\x00-\x83\x9aV...
# 78521  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xbd\x89\x...
# 38163  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xf3\xb9\x...
# 19232  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xeb\x9b\x...
#
#                                             file_content
# 13279  ï»¿1\r\n00:00:00,640 --> 00:00:01,473\r\n- It'...
# 44425  ï»¿1\r\n00:00:03,971 --> 00:00:05,482\r\nMAN: ...
# 64279  ï»¿[Script Info]\r\nTitle: Default file\r\nScr...
# 63878  ï»¿[Script Info]\r\nTitle: Default file\r\nScr...
# 39196  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nAdver...
# ...                                                  ...
# 73303  ï»¿1\r\n00:00:00,167 --> 00:00:02,636\r\nSubti...
# 75262  ï»¿1\r\n00:00:43,112 --> 00:00:45,424\r\nAlber...
# 78521  1\r\n00:00:00,400 --> 00:00:03,000\r\n(violin ...
# 38163  ï»¿1\r\n00:00:02,335 --> 00:00:04,814\r\nDon't...
# 19232  [Script Info]\r\nTitle: English (US)\r\nOrigin...
#
# [10000 rows x 4 columns]

# %%
from tqdm import tqdm, tqdm_notebook

# %%
tqdm.pandas()

# %%
temp_df1 = df["file_content"].progress_apply(lambda x: preprocess(x, 'lemma'))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 10000/10000 [6:47:36<00:00,  2.45s/it]

# %%
temp_df1
# Out:
#                                                        0     1
# 21781  film reel clacking robert englund movie always...  3055
# 75469  got whole world hand got whole world hand got ...  3342
# 34923  cheering applause hello welcome top gear tonig...  3680
# 44434  steve course janet said ring yeah get one knee...  2571
# 25462  watch video online open subtitle free browser ...  5930
# ...                                                  ...   ...
# 56201  previously velma oh dad need believe mom kidna...  1835
# 4149   previously font color fffc real housewife atla...  3695
# 39808  watch video online open subtitle free browser ...   755
# 42199  narrator worldwide six billion camera watching...  3011
# 14208  wind chime chiming matthew yes right goal dog ...  2295
#
# [10000 rows x 2 columns]

# %%
temp_df1.columns = ['clean_text_lemma', 'text_length_lemma']

temp_df1.head()
# Out:
#                                         clean_text_lemma  text_length_lemma
# 21781  film reel clacking robert englund movie always...               3055
# 75469  got whole world hand got whole world hand got ...               3342
# 34923  cheering applause hello welcome top gear tonig...               3680
# 44434  steve course janet said ring yeah get one knee...               2571
# 25462  watch video online open subtitle free browser ...               5930

# %%
temp_df1.to_csv("subtitile.csv",index=False)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vocab2 = TfidfVectorizer()
subtitiles_tfidf1 = vocab2.fit_transform(temp_df1['clean_text_lemma'])

# %%
subtitiles_tfidf1
# Out:
# <10000x172107 sparse matrix of type '<class 'numpy.float64'>'
# 	with 8651012 stored elements in Compressed Sparse Row format>

# %%
user_query = pd.Series([input('Enter the query:')])

user_query.progress_apply(lambda x: preprocess(x,flag='lemma'))

query_vector = vocab2.transform(user_query)
# Out:
# Enter the query:here.comes.the.grump.
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 62.48it/s]

# %%
from sklearn.metrics.pairwise import cosine_similarity

cosine_similarity =  cosine_similarity(query_vector,subtitiles_tfidf1).flatten()
 
A = 10
    
top_A_indices = cosine_similarity.argsort()[-A:][::-1]
top_A_subtitles = temp_df1.iloc[top_A_indices] [:]

# %%
top_A_indices
# Out:
# array([2088, 1669, 2095, 8231, 6006, 1777, 9963, 5385, 5682, 7531],
#       dtype=int64)

# %%
top_A_subtitles
# Out:
#                                         clean_text_lemma  text_length_lemma
# 3915   api opensubtitles org deprecated please implem...                491
# 19833  api opensubtitles org deprecated please implem...                621
# 13808  meet pair friendly snowman help u snowball gru...                494
# 60548  watch video online open subtitle free browser ...               1981
# 35254  use free code joinnow www playships eu ten tin...               3376
# 16308  bird crowing cat meowing mouse squeaking eleph...                802
# 24712  previously scorpion wanna know fella hell sylv...               2733
# 81992  jeff stranger begin adventure forever change l...               3119
# 42846  api opensubtitles org deprecated please implem...               1577
# 7191   person muffled cannot leave element person per...               1245

# %%
import pandas as pd

# %%
temp_df1 = pd.read_csv(r"C:\Users\Abinay Rachakonda\Desktop\sreach_Engine\subtitile.csv")

# %%
temp_df1.dropna(inplace=True)

# %%
temp_df1
# Out:
#                                         clean_text_lemma  text_length_lemma
# 0      film reel clacking robert englund movie always...             3055.0
# 1      got whole world hand got whole world hand got ...             3342.0
# 2      cheering applause hello welcome top gear tonig...             3680.0
# 3      steve course janet said ring yeah get one knee...             2571.0
# 5      ive go forward try get depressed try say okay ...             5930.0
# ...                                                  ...                ...
# 10718  previously velma oh dad need believe mom kidna...             1835.0
# 10719  previously font color fffc real housewife atla...             3695.0
# 10720  watch video online open subtitle free browser ...              755.0
# 10721  narrator worldwide six billion camera watching...             3011.0
# 10722  wind chime chiming matthew yes right goal dog ...             2295.0
#
# [10000 rows x 2 columns]

# %%
df = pd.concat([df, temp_df1], axis=1)

df.head()
# Out:
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                              content  \
# 0  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x1c\xa9\x...
# 1  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x17\xb9\x...
# 2  b'PK\x03\x04\x14\x00\x00\x00\x08\x00L\xb9\x99V...
# 3  b'PK\x03\x04\x14\x00\x00\x00\x08\x00U\xa9\x99V...
# 4  b'PK\x03\x04\x14\x00\x00\x00\x08\x001\xa9\x99V...
#
#                                         file_content  \
# 0  1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch an...
# 1  1\r\n00:00:29,359 --> 00:00:32,048\r\nAh! Ther...
# 2  1\r\n00:00:53,200 --> 00:00:56,030\r\n<i>Yumi'...
# 3  1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch an...
# 4  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch...
#
#                                     clean_text_lemma  text_length_lemma
# 0  film reel clacking robert englund movie always...             3055.0
# 1  got whole world hand got whole world hand got ...             3342.0
# 2  cheering applause hello welcome top gear tonig...             3680.0
# 3  steve course janet said ring yeah get one knee...             2571.0
# 4                                                NaN                NaN

# %%
df.isnull().sum()
# Out:
# num                      0
# name                     0
# content                  0
# file_content             0
# clean_text_lemma     72498
# text_length_lemma    72498
# dtype: int64

# %%
df = df[['num',"name",'clean_text_lemma']]

df.head()
# Out:
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                     clean_text_lemma
# 0  film reel clacking robert englund movie always...
# 1  got whole world hand got whole world hand got ...
# 2  cheering applause hello welcome top gear tonig...
# 3  steve course janet said ring yeah get one knee...
# 4                                                NaN

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (10000, 3)

# %%
df
# Out:
#            num                                               name  \
# 0      9180533                         the.message.(1976).eng.1cd
# 1      9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2      9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3      9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 5      9180607                            the.myth.(2005).eng.1cd
# ...        ...                                                ...
# 10718  9226325            ncis.s04.e03.singled.out.(2006).eng.1cd
# 10719  9226326              ncis.s04.e04.faking.it.(2006).eng.1cd
# 10720  9226327      ncis.s04.e05.dead.and.unburied.(2006).eng.1cd
# 10721  9226328             ncis.s04.e06.witch.hunt.(2006).eng.1cd
# 10722  9226329              ncis.s04.e07.sandblast.(2006).eng.1cd
#
#                                         clean_text_lemma
# 0      film reel clacking robert englund movie always...
# 1      got whole world hand got whole world hand got ...
# 2      cheering applause hello welcome top gear tonig...
# 3      steve course janet said ring yeah get one knee...
# 5      ive go forward try get depressed try say okay ...
# ...                                                  ...
# 10718  previously velma oh dad need believe mom kidna...
# 10719  previously font color fffc real housewife atla...
# 10720  watch video online open subtitle free browser ...
# 10721  narrator worldwide six billion camera watching...
# 10722  wind chime chiming matthew yes right goal dog ...
#
# [10000 rows x 3 columns]

# %%
def chunk_document(corpous, id_col, chunk_size=300):
    data = []

    for doc,id  in zip(corpous, id_col):
        
        words = doc.split()
        for i in range(0, len(words), chunk_size):
            chunk = ' '.join(words[i:i + chunk_size])


            data.append((id,chunk))

    df = pd.DataFrame(data)

    return df

# %%
chuncked_df = chunk_document(df.clean_text_lemma,df.num)

# %%
chuncked_df
# Out:
#              0                                                  1
# 0      9180533  film reel clacking robert englund movie always...
# 1      9180533  reason romero horror film believe popularity c...
# 2      9180533  character react monstrous threat come together...
# 3      9180533  america paving way countless others follow rel...
# 4      9180533  sea still one landmark special effect film eve...
# ...        ...                                                ...
# 79468  9226329  small town oh mr wood idea small town um help ...
# 79469  9226329  pray lord bless keep adam wood keep rome man c...
# 79470  9226329  lynch mob man jean valjean steal loaf bread th...
# 79471  9226329  people miss ed lawson managed wish could stron...
# 79472  9226329  good ran ballistics get result friday print gu...
#
# [79473 rows x 2 columns]

# %%
chuncked_df.columns =['num','file_content_chunks']

# %%
chuncked_df
# Out:
#            num                                file_content_chunks
# 0      9180533  film reel clacking robert englund movie always...
# 1      9180533  reason romero horror film believe popularity c...
# 2      9180533  character react monstrous threat come together...
# 3      9180533  america paving way countless others follow rel...
# 4      9180533  sea still one landmark special effect film eve...
# ...        ...                                                ...
# 79468  9226329  small town oh mr wood idea small town um help ...
# 79469  9226329  pray lord bless keep adam wood keep rome man c...
# 79470  9226329  lynch mob man jean valjean steal loaf bread th...
# 79471  9226329  people miss ed lawson managed wish could stron...
# 79472  9226329  good ran ballistics get result friday print gu...
#
# [79473 rows x 2 columns]

# %%
merged_df = chuncked_df.merge(df,left_on="num",right_on="num",how="left")

# %%
merged_df
# Out:
#            num                                file_content_chunks  \
# 0      9180533  film reel clacking robert englund movie always...
# 1      9180533  reason romero horror film believe popularity c...
# 2      9180533  character react monstrous threat come together...
# 3      9180533  america paving way countless others follow rel...
# 4      9180533  sea still one landmark special effect film eve...
# ...        ...                                                ...
# 79468  9226329  small town oh mr wood idea small town um help ...
# 79469  9226329  pray lord bless keep adam wood keep rome man c...
# 79470  9226329  lynch mob man jean valjean steal loaf bread th...
# 79471  9226329  people miss ed lawson managed wish could stron...
# 79472  9226329  good ran ballistics get result friday print gu...
#
#                                         name  \
# 0                 the.message.(1976).eng.1cd
# 1                 the.message.(1976).eng.1cd
# 2                 the.message.(1976).eng.1cd
# 3                 the.message.(1976).eng.1cd
# 4                 the.message.(1976).eng.1cd
# ...                                      ...
# 79468  ncis.s04.e07.sandblast.(2006).eng.1cd
# 79469  ncis.s04.e07.sandblast.(2006).eng.1cd
# 79470  ncis.s04.e07.sandblast.(2006).eng.1cd
# 79471  ncis.s04.e07.sandblast.(2006).eng.1cd
# 79472  ncis.s04.e07.sandblast.(2006).eng.1cd
#
#                                         clean_text_lemma
# 0      film reel clacking robert englund movie always...
# 1      film reel clacking robert englund movie always...
# 2      film reel clacking robert englund movie always...
# 3      film reel clacking robert englund movie always...
# 4      film reel clacking robert englund movie always...
# ...                                                  ...
# 79468  wind chime chiming matthew yes right goal dog ...
# 79469  wind chime chiming matthew yes right goal dog ...
# 79470  wind chime chiming matthew yes right goal dog ...
# 79471  wind chime chiming matthew yes right goal dog ...
# 79472  wind chime chiming matthew yes right goal dog ...
#
# [79473 rows x 4 columns]

# %%
merged_df= merged_df[['num','name','file_content_chunks']]

# %%
merged_df
# Out:
#            num                                   name  \
# 0      9180533             the.message.(1976).eng.1cd
# 1      9180533             the.message.(1976).eng.1cd
# 2      9180533             the.message.(1976).eng.1cd
# 3      9180533             the.message.(1976).eng.1cd
# 4      9180533             the.message.(1976).eng.1cd
# ...        ...                                    ...
# 79468  9226329  ncis.s04.e07.sandblast.(2006).eng.1cd
# 79469  9226329  ncis.s04.e07.sandblast.(2006).eng.1cd
# 79470  9226329  ncis.s04.e07.sandblast.(2006).eng.1cd
# 79471  9226329  ncis.s04.e07.sandblast.(2006).eng.1cd
# 79472  9226329  ncis.s04.e07.sandblast.(2006).eng.1cd
#
#                                      file_content_chunks
# 0      film reel clacking robert englund movie always...
# 1      reason romero horror film believe popularity c...
# 2      character react monstrous threat come together...
# 3      america paving way countless others follow rel...
# 4      sea still one landmark special effect film eve...
# ...                                                  ...
# 79468  small town oh mr wood idea small town um help ...
# 79469  pray lord bless keep adam wood keep rome man c...
# 79470  lynch mob man jean valjean steal loaf bread th...
# 79471  people miss ed lawson managed wish could stron...
# 79472  good ran ballistics get result friday print gu...
#
# [79473 rows x 3 columns]

# %%
for id, chunk in enumerate(merged_df):
    print(chunk)
# Out:
# num
# name
# file_content_chunks

# %%
pip install -U sentence-transformers
# Out:
# Collecting sentence-transformersNote: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
#   Downloading sentence_transformers-2.7.0-py3-none-any.whl (171 kB)
#      -------------------------------------- 171.5/171.5 kB 2.1 MB/s eta 0:00:00
# Collecting transformers<5.0.0,>=4.34.0
#   Downloading transformers-4.40.0-py3-none-any.whl (9.0 MB)
#      ---------------------------------------- 9.0/9.0 MB 675.2 kB/s eta 0:00:00
# Requirement already satisfied: scipy in c:\users\abinay rachakonda\anaconda\lib\site-packages (from sentence-transformers) (1.10.0)
# Requirement already satisfied: scikit-learn in c:\users\abinay rachakonda\anaconda\lib\site-packages (from sentence-transformers) (1.1.3)
# Collecting huggingface-hub>=0.15.1
#   Downloading huggingface_hub-0.22.2-py3-none-any.whl (388 kB)
#      ------------------------------------ 388.9/388.9 kB 504.8 kB/s eta 0:00:00
# Requirement already satisfied: tqdm in c:\users\abinay rachakonda\anaconda\lib\site-packages (from sentence-transformers) (4.64.1)
# Requirement already satisfied: Pillow in c:\users\abinay rachakonda\anaconda\lib\site-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: numpy in c:\users\abinay rachakonda\anaconda\lib\site-packages (from sentence-transformers) (1.23.5)
# Requirement already satisfied: torch>=1.11.0 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from sentence-transformers) (1.12.1)
# Requirement already satisfied: filelock in c:\users\abinay rachakonda\anaconda\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.9.0)
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2024.3.1-py3-none-any.whl (171 kB)
#      ------------------------------------ 172.0/172.0 kB 738.6 kB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0)
# Requirement already satisfied: requests in c:\users\abinay rachakonda\anaconda\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.28.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.11.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (20.9)
# Requirement already satisfied: colorama in c:\users\abinay rachakonda\anaconda\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Collecting safetensors>=0.4.1
#   Downloading safetensors-0.4.3-cp310-none-win_amd64.whl (287 kB)
#      ------------------------------------ 287.4/287.4 kB 842.6 kB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2022.7.9)
# Collecting tokenizers<0.20,>=0.19
#   Downloading tokenizers-0.19.1-cp310-none-win_amd64.whl (2.2 MB)
#      ---------------------------------------- 2.2/2.2 MB 660.8 kB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from scikit-learn->sentence-transformers) (1.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from packaging>=20.9->huggingface-hub>=0.15.1->sentence-transformers) (3.0.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2023.11.17)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.4)
# Installing collected packages: safetensors, fsspec, huggingface-hub, tokenizers, transformers, sentence-transformers
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2022.11.0
#     Uninstalling fsspec-2022.11.0:
#       Successfully uninstalled fsspec-2022.11.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.10.1
#     Uninstalling huggingface-hub-0.10.1:
#       Successfully uninstalled huggingface-hub-0.10.1
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.11.4
#     Uninstalling tokenizers-0.11.4:
#       Successfully uninstalled tokenizers-0.11.4
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.24.0
#     Uninstalling transformers-4.24.0:
#       Successfully uninstalled transformers-4.24.0
# Successfully installed fsspec-2024.3.1 huggingface-hub-0.22.2 safetensors-0.4.3 sentence-transformers-2.7.0 tokenizers-0.19.1 transformers-4.40.0

# %%
from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
pip install  chromadb
# Out:
# Collecting chromadbNote: you may need to restart the kernel to use updated packages.
#
#   Downloading chromadb-0.4.24-py3-none-any.whl (525 kB)
#      -------------------------------------- 525.5/525.5 kB 2.4 MB/s eta 0:00:00
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.24.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from chromadb) (4.11.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from chromadb) (1.23.5)
# Collecting pulsar-client>=3.1.0
#   Downloading pulsar_client-3.5.0-cp310-cp310-win_amd64.whl (3.3 MB)
#      ---------------------------------------- 3.3/3.3 MB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from chromadb) (1.59.3)
# Requirement already satisfied: pydantic>=1.9 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from chromadb) (1.10.9)
# Collecting pypika>=0.48.9
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ---------------------------------------- 67.3/67.3 kB 3.6 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting bcrypt>=4.0.1
#   Downloading bcrypt-4.1.2-cp39-abi3-win_amd64.whl (158 kB)
#      -------------------------------------- 158.3/158.3 kB 1.6 MB/s eta 0:00:00
# Collecting typer>=0.9.0
#   Downloading typer-0.12.3-py3-none-any.whl (47 kB)
#      ---------------------------------------- 47.2/47.2 kB 2.3 MB/s eta 0:00:00
# Collecting fastapi>=0.95.2
#   Downloading fastapi-0.110.2-py3-none-any.whl (91 kB)
#      ---------------------------------------- 91.9/91.9 kB 2.6 MB/s eta 0:00:00
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0
#   Downloading opentelemetry_instrumentation_fastapi-0.45b0-py3-none-any.whl (11 kB)
# Collecting onnxruntime>=1.14.1
#   Downloading onnxruntime-1.17.3-cp310-cp310-win_amd64.whl (5.6 MB)
#      ---------------------------------------- 5.6/5.6 MB 1.4 MB/s eta 0:00:00
# Collecting opentelemetry-sdk>=1.2.0
#   Downloading opentelemetry_sdk-1.24.0-py3-none-any.whl (106 kB)
#      ------------------------------------ 106.1/106.1 kB 383.6 kB/s eta 0:00:00
# Collecting kubernetes>=28.1.0
#   Downloading kubernetes-29.0.0-py2.py3-none-any.whl (1.6 MB)
#      ---------------------------------------- 1.6/1.6 MB 1.0 MB/s eta 0:00:00
# Collecting chroma-hnswlib==0.7.3
#   Downloading chroma_hnswlib-0.7.3-cp310-cp310-win_amd64.whl (150 kB)
#      -------------------------------------- 150.6/150.6 kB 1.3 MB/s eta 0:00:00
# Collecting uvicorn[standard]>=0.18.3
#   Downloading uvicorn-0.29.0-py3-none-any.whl (60 kB)
#      ---------------------------------------- 60.8/60.8 kB 1.1 MB/s eta 0:00:00
# Collecting build>=1.0.3
#   Downloading build-1.2.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: requests>=2.28 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from chromadb) (2.28.1)
# Collecting orjson>=3.9.12
#   Downloading orjson-3.10.1-cp310-none-win_amd64.whl (139 kB)
#      -------------------------------------- 139.1/139.1 kB 1.4 MB/s eta 0:00:00
# Collecting opentelemetry-api>=1.2.0
#   Downloading opentelemetry_api-1.24.0-py3-none-any.whl (60 kB)
#      ---------------------------------------- 60.1/60.1 kB 1.1 MB/s eta 0:00:00
# Collecting importlib-resources
#   Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from chromadb) (6.0)
# Collecting posthog>=2.4.0
#   Downloading posthog-3.5.0-py2.py3-none-any.whl (41 kB)
#      ---------------------------------------- 41.3/41.3 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from chromadb) (0.19.1)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from chromadb) (8.2.3)
# Collecting overrides>=7.3.1
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Collecting mmh3>=4.0.1
#   Downloading mmh3-4.1.0-cp310-cp310-win_amd64.whl (31 kB)
# Collecting tqdm>=4.65.0
#   Using cached tqdm-4.66.2-py3-none-any.whl (78 kB)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from build>=1.0.3->chromadb) (2.0.1)
# Requirement already satisfied: packaging>=19.1 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from build>=1.0.3->chromadb) (20.9)
# Collecting pyproject_hooks
#   Downloading pyproject_hooks-1.0.0-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: colorama in c:\users\abinay rachakonda\anaconda\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Collecting starlette<0.38.0,>=0.37.2
#   Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#      ---------------------------------------- 71.9/71.9 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.26.14)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2023.11.17)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Requirement already satisfied: requests-oauthlib in c:\users\abinay rachakonda\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.24.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: flatbuffers in c:\users\abinay rachakonda\anaconda\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Requirement already satisfied: protobuf in c:\users\abinay rachakonda\anaconda\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (4.23.3)
# Requirement already satisfied: sympy in c:\users\abinay rachakonda\anaconda\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.11.1)
# Requirement already satisfied: coloredlogs in c:\users\abinay rachakonda\anaconda\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Collecting deprecated>=1.2.6
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting importlib-metadata<=7.0,>=6.0
#   Downloading importlib_metadata-7.0.0-py3-none-any.whl (23 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.24.0
#   Downloading opentelemetry_exporter_otlp_proto_common-1.24.0-py3-none-any.whl (17 kB)
# Collecting opentelemetry-proto==1.24.0
#   Downloading opentelemetry_proto-1.24.0-py3-none-any.whl (50 kB)
#      -------------------------------------- 50.8/50.8 kB 862.1 kB/s eta 0:00:00
# Collecting googleapis-common-protos~=1.52
#   Downloading googleapis_common_protos-1.63.0-py2.py3-none-any.whl (229 kB)
#      ------------------------------------ 229.1/229.1 kB 935.5 kB/s eta 0:00:00
# Collecting opentelemetry-semantic-conventions==0.45b0
#   Downloading opentelemetry_semantic_conventions-0.45b0-py3-none-any.whl (36 kB)
# Collecting opentelemetry-instrumentation-asgi==0.45b0
#   Downloading opentelemetry_instrumentation_asgi-0.45b0-py3-none-any.whl (14 kB)
# Collecting opentelemetry-instrumentation==0.45b0
#   Downloading opentelemetry_instrumentation-0.45b0-py3-none-any.whl (28 kB)
# Collecting opentelemetry-util-http==0.45b0
#   Downloading opentelemetry_util_http-0.45b0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: setuptools>=16.0 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (65.6.3)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Collecting asgiref~=3.0
#   Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Collecting backoff>=1.10.0
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting monotonic>=1.5
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from requests>=2.28->chromadb) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from requests>=2.28->chromadb) (2.0.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.22.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from typer>=0.9.0->chromadb) (8.0.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from typer>=0.9.0->chromadb) (13.7.1)
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: h11>=0.8 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Collecting watchfiles>=0.13
#   Downloading watchfiles-0.21.0-cp310-none-win_amd64.whl (279 kB)
#      -------------------------------------- 279.7/279.7 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: websockets>=10.4 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (10.4)
# Collecting python-dotenv>=0.13
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.3.1)
# Requirement already satisfied: filelock in c:\users\abinay rachakonda\anaconda\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.9.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from importlib-metadata<=7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.11.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from packaging>=19.1->build>=1.0.3->chromadb) (3.0.9)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (2.17.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from starlette<0.38.0,>=0.37.2->fastapi>=0.95.2->chromadb) (3.5.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.2.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.38.0,>=0.37.2->fastapi>=0.95.2->chromadb) (1.2.0)
# Requirement already satisfied: pyreadline3 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.4.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb) (0.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\abinay rachakonda\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml): started
#   Building wheel for pypika (pyproject.toml): finished with status 'done'
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53835 sha256=23b53ac1cff3a4df27821fcceca04d5ddee032cf1067edad28f475819105bebe
#   Stored in directory: c:\users\abinay rachakonda\appdata\local\pip\cache\wheels\c4\41\b6\f76a356f0791da799545c23894ceae842eeff054d0eb1fb626
# Successfully built pypika
# Installing collected packages: pypika, monotonic, mmh3, tqdm, shellingham, python-dotenv, pyproject_hooks, pulsar-client, overrides, orjson, opentelemetry-util-http, opentelemetry-semantic-conventions, opentelemetry-proto, importlib-resources, importlib-metadata, googleapis-common-protos, deprecated, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, uvicorn, starlette, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, build, typer, opentelemetry-sdk, opentelemetry-instrumentation, onnxruntime, kubernetes, fastapi, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.1
#     Uninstalling tqdm-4.64.1:
#       Successfully uninstalled tqdm-4.64.1
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.11.3
#     Uninstalling importlib-metadata-4.11.3:
#       Successfully uninstalled importlib-metadata-4.11.3
#   Attempting uninstall: bcrypt
#     Found existing installation: bcrypt 3.2.0
#     Uninstalling bcrypt-3.2.0:
#       Successfully uninstalled bcrypt-3.2.0
# Successfully installed asgiref-3.8.1 backoff-2.2.1 bcrypt-4.1.2 build-1.2.1 chroma-hnswlib-0.7.3 chromadb-0.4.24 deprecated-1.2.14 fastapi-0.110.2 googleapis-common-protos-1.63.0 importlib-metadata-7.0.0 importlib-resources-6.4.0 kubernetes-29.0.0 mmh3-4.1.0 monotonic-1.6 onnxruntime-1.17.3 opentelemetry-api-1.24.0 opentelemetry-exporter-otlp-proto-common-1.24.0 opentelemetry-exporter-otlp-proto-grpc-1.24.0 opentelemetry-instrumentation-0.45b0 opentelemetry-instrumentation-asgi-0.45b0 opentelemetry-instrumentation-fastapi-0.45b0 opentelemetry-proto-1.24.0 opentelemetry-sdk-1.24.0 opentelemetry-semantic-conventions-0.45b0 opentelemetry-util-http-0.45b0 orjson-3.10.1 overrides-7.7.0 posthog-3.5.0 pulsar-client-3.5.0 pypika-0.48.9 pyproject_hooks-1.0.0 python-dotenv-1.0.1 shellingham-1.5.4 starlette-0.37.2 tqdm-4.66.2 typer-0.12.3 uvicorn-0.29.0 watchfiles-0.21.0
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# rasa 3.6.15 requires prompt-toolkit<3.0.29,>=3.0, but you have prompt-toolkit 3.0.41 which is incompatible.
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\abinay rachakonda\anaconda\lib\site-packages)

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import chromadb

# %%
merged_df
# Out:
#            num                                   name  \
# 0      9180533             the.message.(1976).eng.1cd
# 1      9180533             the.message.(1976).eng.1cd
# 2      9180533             the.message.(1976).eng.1cd
# 3      9180533             the.message.(1976).eng.1cd
# 4      9180533             the.message.(1976).eng.1cd
# ...        ...                                    ...
# 79468  9226329  ncis.s04.e07.sandblast.(2006).eng.1cd
# 79469  9226329  ncis.s04.e07.sandblast.(2006).eng.1cd
# 79470  9226329  ncis.s04.e07.sandblast.(2006).eng.1cd
# 79471  9226329  ncis.s04.e07.sandblast.(2006).eng.1cd
# 79472  9226329  ncis.s04.e07.sandblast.(2006).eng.1cd
#
#                                      file_content_chunks
# 0      film reel clacking robert englund movie always...
# 1      reason romero horror film believe popularity c...
# 2      character react monstrous threat come together...
# 3      america paving way countless others follow rel...
# 4      sea still one landmark special effect film eve...
# ...                                                  ...
# 79468  small town oh mr wood idea small town um help ...
# 79469  pray lord bless keep adam wood keep rome man c...
# 79470  lynch mob man jean valjean steal loaf bread th...
# 79471  people miss ed lawson managed wish could stron...
# 79472  good ran ballistics get result friday print gu...
#
# [79473 rows x 3 columns]

# %%
df = merged_df.sample(n=8000)

# %%
df
# Out:
#            num                                               name  \
# 19461  9192535                        mommy.issues.(2021).eng.1cd
# 29590  9199194          empire.s03.e04.cupid.kills.(2016).eng.1cd
# 70465  9221632        this.is.us.s05.e15.jerry.2.0.(2021).eng.1cd
# 50661  9209861   red.rose.s01.e04.manchester.innit.(2022).eng.1cd
# 50587  9209767       fruits.basket.s03.e11.goodbye.(2021).eng.1cd
# ...        ...                                                ...
# 50344  9209734  fruits.basket.s02.e03.shall.we.go.and.get.you....
# 22868  9194963  american.horror.stories.s02.e03.drive.(2022).e...
# 36814  9202976                      doctor.of.doom.(1963).eng.1cd
# 40276  9204652   the.deuce.s02.e06.were.all.beasts.(2018).eng.1cd
# 22930  9194972  the.orville.s03.e10.future.unknown.(2022).eng.1cd
#
#                                      file_content_chunks
# 19461  place start door open good morning easy say sp...
# 29590  direct result willful preventable malpractice ...
# 70465  narrator previously beauty beast something gem...
# 50661  mother hajara married bayo refused osage offer...
# 50587  dialogue dialogue unknown po head thing right ...
# ...                                                  ...
# 50344  working gotta go spent lot money least open ba...
# 22868  deeper ever seen black side town white side to...
# 36814  tell july revolution remember date french revo...
# 40276  kidding oh oh woe life empty without joy oh go...
# 22930  along relieving hurry thanks mr sabharwal maki...
#
# [8000 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8000 entries, 19461 to 22930
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   num                  8000 non-null   int64
#  1   name                 8000 non-null   object
#  2   file_content_chunks  8000 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 250.0+ KB

# %%
from tqdm import tqdm, tqdm_notebook

# %%
tqdm.pandas()

# %%
df['doc_vector_pretrained_bert'] = df.file_content_chunks.progress_apply(model.encode)

df.head()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 8000/8000 [15:40:40<00:00,  7.06s/it]
#            num                                              name  \
# 19461  9192535                       mommy.issues.(2021).eng.1cd
# 29590  9199194         empire.s03.e04.cupid.kills.(2016).eng.1cd
# 70465  9221632       this.is.us.s05.e15.jerry.2.0.(2021).eng.1cd
# 50661  9209861  red.rose.s01.e04.manchester.innit.(2022).eng.1cd
# 50587  9209767      fruits.basket.s03.e11.goodbye.(2021).eng.1cd
#
#                                      file_content_chunks  \
# 19461  place start door open good morning easy say sp...
# 29590  direct result willful preventable malpractice ...
# 70465  narrator previously beauty beast something gem...
# 50661  mother hajara married bayo refused osage offer...
# 50587  dialogue dialogue unknown po head thing right ...
#
#                               doc_vector_pretrained_bert
# 19461  [-0.0783906, -0.11347432, -0.004569102, -0.005...
# 29590  [-0.08458218, 0.008842241, 0.08269427, 0.00555...
# 70465  [-0.07014809, -0.065490745, -0.0038970595, 0.0...
# 50661  [-0.01848804, 0.033096064, -0.04405071, -0.016...
# 50587  [0.028834488, -0.0404045, -0.0050393566, -0.06...

# %%
merged_df
# Out:
#            num                                   name  \
# 0      9180533             the.message.(1976).eng.1cd
# 1      9180533             the.message.(1976).eng.1cd
# 2      9180533             the.message.(1976).eng.1cd
# 3      9180533             the.message.(1976).eng.1cd
# 4      9180533             the.message.(1976).eng.1cd
# ...        ...                                    ...
# 79468  9226329  ncis.s04.e07.sandblast.(2006).eng.1cd
# 79469  9226329  ncis.s04.e07.sandblast.(2006).eng.1cd
# 79470  9226329  ncis.s04.e07.sandblast.(2006).eng.1cd
# 79471  9226329  ncis.s04.e07.sandblast.(2006).eng.1cd
# 79472  9226329  ncis.s04.e07.sandblast.(2006).eng.1cd
#
#                                      file_content_chunks
# 0      film reel clacking robert englund movie always...
# 1      reason romero horror film believe popularity c...
# 2      character react monstrous threat come together...
# 3      america paving way countless others follow rel...
# 4      sea still one landmark special effect film eve...
# ...                                                  ...
# 79468  small town oh mr wood idea small town um help ...
# 79469  pray lord bless keep adam wood keep rome man c...
# 79470  lynch mob man jean valjean steal loaf bread th...
# 79471  people miss ed lawson managed wish could stron...
# 79472  good ran ballistics get result friday print gu...
#
# [79473 rows x 3 columns]

# %%
df
# Out:
#            num                                               name  \
# 19461  9192535                        mommy.issues.(2021).eng.1cd
# 29590  9199194          empire.s03.e04.cupid.kills.(2016).eng.1cd
# 70465  9221632        this.is.us.s05.e15.jerry.2.0.(2021).eng.1cd
# 50661  9209861   red.rose.s01.e04.manchester.innit.(2022).eng.1cd
# 50587  9209767       fruits.basket.s03.e11.goodbye.(2021).eng.1cd
# ...        ...                                                ...
# 50344  9209734  fruits.basket.s02.e03.shall.we.go.and.get.you....
# 22868  9194963  american.horror.stories.s02.e03.drive.(2022).e...
# 36814  9202976                      doctor.of.doom.(1963).eng.1cd
# 40276  9204652   the.deuce.s02.e06.were.all.beasts.(2018).eng.1cd
# 22930  9194972  the.orville.s03.e10.future.unknown.(2022).eng.1cd
#
#                                      file_content_chunks  \
# 19461  place start door open good morning easy say sp...
# 29590  direct result willful preventable malpractice ...
# 70465  narrator previously beauty beast something gem...
# 50661  mother hajara married bayo refused osage offer...
# 50587  dialogue dialogue unknown po head thing right ...
# ...                                                  ...
# 50344  working gotta go spent lot money least open ba...
# 22868  deeper ever seen black side town white side to...
# 36814  tell july revolution remember date french revo...
# 40276  kidding oh oh woe life empty without joy oh go...
# 22930  along relieving hurry thanks mr sabharwal maki...
#
#                               doc_vector_pretrained_bert
# 19461  [-0.0783906, -0.11347432, -0.004569102, -0.005...
# 29590  [-0.08458218, 0.008842241, 0.08269427, 0.00555...
# 70465  [-0.07014809, -0.065490745, -0.0038970595, 0.0...
# 50661  [-0.01848804, 0.033096064, -0.04405071, -0.016...
# 50587  [0.028834488, -0.0404045, -0.0050393566, -0.06...
# ...                                                  ...
# 50344  [-0.10251991, -0.08886092, 0.030862536, -0.005...
# 22868  [-0.00080629764, -0.040539347, -0.06315144, 0....
# 36814  [-0.016995015, -0.07232215, 0.009061228, -0.08...
# 40276  [-0.025916412, -0.08842337, 0.033268996, -0.00...
# 22930  [-0.05258158, -0.0010668003, 0.048248313, 0.02...
#
# [8000 rows x 4 columns]

# %%
User_query = pd.Series([input("Enter a user Query " )])
# Out:
# Enter a user Query  Query  peter

# %%
User_query.progress_apply(lambda x:  preprocess(x, "lemma"))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.96s/it]
#              0  1
# 0  query peter  2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8000 entries, 19461 to 22930
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   num                         8000 non-null   int64
#  1   name                        8000 non-null   object
#  2   file_content_chunks         8000 non-null   object
#  3   doc_vector_pretrained_bert  8000 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 570.5+ KB

# %%
df['doc_vector_pretrained_bert'] = df['doc_vector_pretrained_bert'].astype(str).str.replace("[","").str.replace("]","")
# Out:
# C:\Users\Abinay Rachakonda\AppData\Local\Temp\ipykernel_15912\642312867.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['doc_vector_pretrained_bert'] = df['doc_vector_pretrained_bert'].astype(str).str.replace("[","").str.replace("]","")

# %%
df['doc_vector_pretrained_bert'] = df['doc_vector_pretrained_bert'].apply(lambda x: [float(i) for i in x.split()])

# %%
a=df['doc_vector_pretrained_bert'][:1]

# %%
len(a.loc[19461,])
# Out:
# 384

# %%
Query = User_query.progress_apply(model.encode)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.45it/s]

# %%
Query[0].shape
# Out:
# (384,)

# %%
import torch

# %%
# Convert the DataFrame column into a list of tensors
doc_vectors = [torch.tensor(vec) for vec in df['doc_vector_pretrained_bert']]

# Assuming Query[0] is also a tensor, convert it if necessary
query_tensor = torch.tensor(Query[0])

# Calculate cosine similarity
cos_similarities = [util.cos_sim(query_tensor, vec) for vec in doc_vectors]

# %%
cos_similarities
# Out:
# [tensor([[0.1163]]),
#  tensor([[0.1591]]),
#  tensor([[0.0599]]),
#  tensor([[0.1696]]),
#  tensor([[0.0965]]),
#  tensor([[0.0318]]),
#  tensor([[0.0871]]),
#  tensor([[0.0605]]),
#  tensor([[0.1196]]),
#  tensor([[0.0883]]),
#  tensor([[0.0688]]),
#  tensor([[-0.0204]]),
#  tensor([[0.1606]]),
#  tensor([[0.1209]]),
#  tensor([[0.0925]]),
#  tensor([[0.1139]]),
#  tensor([[0.0833]]),
#  tensor([[0.1320]]),
#  tensor([[0.0936]]),
#  tensor([[0.1016]]),
#  tensor([[0.2035]]),
#  tensor([[-0.0028]]),
#  tensor([[0.0860]]),
#  tensor([[0.1116]]),
#  tensor([[0.1195]]),
#  tensor([[0.0880]]),
#  tensor([[0.0618]]),
#  tensor([[0.0491]]),
#  tensor([[0.0951]]),
#  tensor([[0.1162]]),
#  tensor([[0.1488]]),
#  tensor([[0.1023]]),
#  tensor([[0.0723]]),
#  tensor([[0.0497]]),
#  tensor([[0.0708]]),
#  tensor([[0.1241]]),
#  tensor([[0.0711]]),
#  tensor([[-0.0625]]),
#  tensor([[0.0005]]),
#  tensor([[0.0518]]),
#  tensor([[0.1344]]),
#  tensor([[0.0539]]),
#  tensor([[0.0938]]),
#  tensor([[0.1045]]),
#  tensor([[0.0341]]),
#  tensor([[0.0909]]),
#  tensor([[0.0682]]),
#  tensor([[0.0777]]),
#  tensor([[0.0561]]),
#  tensor([[0.0893]]),
#  tensor([[0.0447]]),
#  tensor([[0.0664]]),
#  tensor([[0.1383]]),
#  tensor([[0.1699]]),
#  tensor([[0.1657]]),
#  tensor([[0.0462]]),
#  tensor([[0.0815]]),
#  tensor([[0.1087]]),
#  tensor([[0.0231]]),
#  tensor([[0.2231]]),
#  tensor([[0.0349]]),
#  tensor([[0.0753]]),
#  tensor([[-0.0514]]),
#  tensor([[0.0596]]),
#  tensor([[0.0907]]),
#  tensor([[0.1410]]),
#  tensor([[0.1913]]),
#  tensor([[0.1354]]),
#  tensor([[0.0442]]),
#  tensor([[0.1168]]),
#  tensor([[0.0504]]),
#  tensor([[0.0219]]),
#  tensor([[0.0711]]),
#  tensor([[0.0294]]),
#  tensor([[0.1936]]),
#  tensor([[0.0277]]),
#  tensor([[0.0457]]),
#  tensor([[0.0279]]),
#  tensor([[0.1413]]),
#  tensor([[0.1820]]),
#  tensor([[0.1312]]),
#  tensor([[0.0762]]),
#  tensor([[0.0241]]),
#  tensor([[0.1177]]),
#  tensor([[0.1367]]),
#  tensor([[0.0746]]),
#  tensor([[0.0943]]),
#  tensor([[0.0863]]),
#  tensor([[0.1765]]),
#  tensor([[0.0693]]),
#  tensor([[0.2108]]),
#  tensor([[0.0458]]),
#  tensor([[0.1057]]),
#  tensor([[0.0725]]),
#  tensor([[0.1410]]),
#  tensor([[0.0066]]),
#  tensor([[-0.0007]]),
#  tensor([[0.0977]]),
#  tensor([[0.0728]]),
#  tensor([[0.0201]]),
#  tensor([[0.1042]]),
#  tensor([[0.0755]]),
#  tensor([[0.0181]]),
#  tensor([[-0.0352]]),
#  tensor([[0.1754]]),
#  tensor([[0.0352]]),
#  tensor([[0.0445]]),
#  tensor([[0.0206]]),
#  tensor([[0.0354]]),
#  tensor([[0.0474]]),
#  tensor([[0.0844]]),
#  tensor([[0.1474]]),
#  tensor([[0.0620]]),
#  tensor([[0.0438]]),
#  tensor([[0.0660]]),
#  tensor([[0.1723]]),
#  tensor([[0.1084]]),
#  tensor([[0.1585]]),
#  tensor([[0.1138]]),
#  tensor([[0.1023]]),
#  tensor([[0.1059]]),
#  tensor([[0.0313]]),
#  tensor([[0.1252]]),
#  tensor([[0.0954]]),
#  tensor([[0.2027]]),
#  tensor([[0.0944]]),
#  tensor([[0.0358]]),
#  tensor([[0.2272]]),
#  tensor([[0.1237]]),
#  tensor([[0.1356]]),
#  tensor([[0.0420]]),
#  tensor([[0.1114]]),
#  tensor([[0.0728]]),
#  tensor([[0.0760]]),
#  tensor([[0.0760]]),
#  tensor([[0.0679]]),
#  tensor([[0.1173]]),
#  tensor([[0.0432]]),
#  tensor([[0.0201]]),
#  tensor([[0.1620]]),
#  tensor([[0.0361]]),
#  tensor([[0.1392]]),
#  tensor([[0.0595]]),
#  tensor([[0.1436]]),
#  tensor([[0.0264]]),
#  tensor([[0.1910]]),
#  tensor([[0.1102]]),
#  tensor([[0.1415]]),
#  tensor([[0.1081]]),
#  tensor([[0.0194]]),
#  tensor([[0.0768]]),
#  tensor([[0.0868]]),
#  tensor([[0.0866]]),
#  tensor([[0.0749]]),
#  tensor([[0.1243]]),
#  tensor([[0.0672]]),
#  tensor([[-0.0136]]),
#  tensor([[0.0011]]),
#  tensor([[0.0769]]),
#  tensor([[0.0485]]),
#  tensor([[0.1294]]),
#  tensor([[0.0832]]),
#  tensor([[0.0624]]),
#  tensor([[0.1127]]),
#  tensor([[0.0888]]),
#  tensor([[0.0109]]),
#  tensor([[0.0467]]),
#  tensor([[0.0253]]),
#  tensor([[0.1131]]),
#  tensor([[0.0953]]),
#  tensor([[0.1938]]),
#  tensor([[0.0322]]),
#  tensor([[0.2163]]),
#  tensor([[0.0077]]),
#  tensor([[0.1576]]),
#  tensor([[0.1017]]),
#  tensor([[0.1095]]),
#  tensor([[0.0276]]),
#  tensor([[0.1179]]),
#  tensor([[0.2060]]),
#  tensor([[0.0531]]),
#  tensor([[0.2044]]),
#  tensor([[0.1412]]),
#  tensor([[0.1499]]),
#  tensor([[0.0494]]),
#  tensor([[0.0454]]),
#  tensor([[0.0278]]),
#  tensor([[0.0697]]),
#  tensor([[0.0773]]),
#  tensor([[0.1530]]),
#  tensor([[0.0788]]),
#  tensor([[0.0882]]),
#  tensor([[0.0632]]),
#  tensor([[0.0688]]),
#  tensor([[0.1070]]),
#  tensor([[0.1298]]),
#  tensor([[0.0503]]),
#  tensor([[0.1557]]),
#  tensor([[0.1334]]),
#  tensor([[0.1523]]),
#  tensor([[0.0215]]),
#  tensor([[0.0421]]),
#  tensor([[0.0703]]),
#  tensor([[0.1647]]),
#  tensor([[0.1196]]),
#  tensor([[0.0556]]),
#  tensor([[0.0851]]),
#  tensor([[0.1648]]),
#  tensor([[0.1232]]),
#  tensor([[0.1048]]),
#  tensor([[0.0205]]),
#  tensor([[0.1401]]),
#  tensor([[0.0629]]),
#  tensor([[-0.0267]]),
#  tensor([[0.0794]]),
#  tensor([[0.0299]]),
#  tensor([[0.1692]]),
#  tensor([[0.0826]]),
#  tensor([[0.0784]]),
#  tensor([[0.0137]]),
#  tensor([[0.0936]]),
#  tensor([[0.1165]]),
#  tensor([[0.1017]]),
#  tensor([[0.1519]]),
#  tensor([[0.0452]]),
#  tensor([[0.1473]]),
#  tensor([[0.1143]]),
#  tensor([[0.0795]]),
#  tensor([[0.0713]]),
#  tensor([[0.1760]]),
#  tensor([[0.0940]]),
#  tensor([[0.1220]]),
#  tensor([[0.1059]]),
#  tensor([[0.0612]]),
#  tensor([[0.1140]]),
#  tensor([[0.1462]]),
#  tensor([[0.1095]]),
#  tensor([[0.0425]]),
#  tensor([[0.1786]]),
#  tensor([[0.0258]]),
#  tensor([[0.1066]]),
#  tensor([[0.0739]]),
#  tensor([[0.0485]]),
#  tensor([[-0.0340]]),
#  tensor([[0.2140]]),
#  tensor([[0.2246]]),
#  tensor([[0.0767]]),
#  tensor([[0.1479]]),
#  tensor([[0.0811]]),
#  tensor([[0.0600]]),
#  tensor([[0.0829]]),
#  tensor([[0.0378]]),
#  tensor([[0.1432]]),
#  tensor([[0.1305]]),
#  tensor([[0.0738]]),
#  tensor([[0.0996]]),
#  tensor([[0.1821]]),
#  tensor([[0.1946]]),
#  tensor([[0.0595]]),
#  tensor([[-0.0270]]),
#  tensor([[0.0090]]),
#  tensor([[0.2297]]),
#  tensor([[0.1028]]),
#  tensor([[0.0247]]),
#  tensor([[0.0462]]),
#  tensor([[0.0664]]),
#  tensor([[0.0805]]),
#  tensor([[0.0669]]),
#  tensor([[0.0888]]),
#  tensor([[0.0910]]),
#  tensor([[-0.0201]]),
#  tensor([[0.0717]]),
#  tensor([[0.0800]]),
#  tensor([[0.0963]]),
#  tensor([[0.1976]]),
#  tensor([[0.0284]]),
#  tensor([[0.0911]]),
#  tensor([[0.1200]]),
#  tensor([[0.1992]]),
#  tensor([[0.1501]]),
#  tensor([[0.1442]]),
#  tensor([[0.1067]]),
#  tensor([[0.1557]]),
#  tensor([[0.1176]]),
#  tensor([[0.1216]]),
#  tensor([[0.0793]]),
#  tensor([[0.0491]]),
#  tensor([[0.0857]]),
#  tensor([[0.1152]]),
#  tensor([[0.1122]]),
#  tensor([[0.1717]]),
#  tensor([[0.0971]]),
#  tensor([[0.0655]]),
#  tensor([[0.0765]]),
#  tensor([[0.1350]]),
#  tensor([[0.1981]]),
#  tensor([[0.0336]]),
#  tensor([[0.0513]]),
#  tensor([[0.1382]]),
#  tensor([[0.0086]]),
#  tensor([[0.1533]]),
#  tensor([[0.0640]]),
#  tensor([[0.1008]]),
#  tensor([[0.1094]]),
#  tensor([[0.1945]]),
#  tensor([[0.0740]]),
#  tensor([[0.1174]]),
#  tensor([[0.0475]]),
#  tensor([[0.1375]]),
#  tensor([[0.0302]]),
#  tensor([[0.1533]]),
#  tensor([[0.0109]]),
#  tensor([[0.0744]]),
#  tensor([[0.0486]]),
#  tensor([[0.0899]]),
#  tensor([[0.1006]]),
#  tensor([[0.0586]]),
#  tensor([[0.0417]]),
#  tensor([[0.1024]]),
#  tensor([[0.0508]]),
#  tensor([[0.1077]]),
#  tensor([[0.0696]]),
#  tensor([[0.1005]]),
#  tensor([[0.0844]]),
#  tensor([[0.0961]]),
#  tensor([[0.1010]]),
#  tensor([[0.2045]]),
#  tensor([[0.1078]]),
#  tensor([[0.1384]]),
#  tensor([[0.0943]]),
#  tensor([[0.1313]]),
#  tensor([[0.0160]]),
#  tensor([[-0.0161]]),
#  tensor([[0.1465]]),
#  tensor([[0.1275]]),
#  tensor([[0.1016]]),
#  tensor([[0.1649]]),
#  tensor([[0.0758]]),
#  tensor([[0.0245]]),
#  tensor([[-0.0051]]),
#  tensor([[0.0784]]),
#  tensor([[0.0809]]),
#  tensor([[0.0741]]),
#  tensor([[0.1080]]),
#  tensor([[0.0736]]),
#  tensor([[0.0809]]),
#  tensor([[0.0907]]),
#  tensor([[0.0605]]),
#  tensor([[0.1316]]),
#  tensor([[-0.0053]]),
#  tensor([[0.0832]]),
#  tensor([[0.1175]]),
#  tensor([[0.0425]]),
#  tensor([[0.0553]]),
#  tensor([[0.0853]]),
#  tensor([[0.0685]]),
#  tensor([[0.0343]]),
#  tensor([[0.0813]]),
#  tensor([[0.1143]]),
#  tensor([[0.0576]]),
#  tensor([[0.0293]]),
#  tensor([[0.0947]]),
#  tensor([[0.1121]]),
#  tensor([[0.0543]]),
#  tensor([[0.1201]]),
#  tensor([[-0.0467]]),
#  tensor([[0.0824]]),
#  tensor([[0.0218]]),
#  tensor([[0.0860]]),
#  tensor([[0.1229]]),
#  tensor([[0.1837]]),
#  tensor([[0.1390]]),
#  tensor([[0.1452]]),
#  tensor([[0.0882]]),
#  tensor([[0.0451]]),
#  tensor([[0.1745]]),
#  tensor([[0.1367]]),
#  tensor([[-0.0147]]),
#  tensor([[0.2295]]),
#  tensor([[0.1529]]),
#  tensor([[0.0565]]),
#  tensor([[0.0529]]),
#  tensor([[0.1001]]),
#  tensor([[0.0567]]),
#  tensor([[0.0290]]),
#  tensor([[0.1186]]),
#  tensor([[0.0213]]),
#  tensor([[0.1101]]),
#  tensor([[0.0586]]),
#  tensor([[0.1498]]),
#  tensor([[0.0550]]),
#  tensor([[0.0815]]),
#  tensor([[-0.0148]]),
#  tensor([[0.1586]]),
#  tensor([[0.0276]]),
#  tensor([[0.1088]]),
#  tensor([[0.0797]]),
#  tensor([[0.0469]]),
#  tensor([[0.0702]]),
#  tensor([[0.0313]]),
#  tensor([[0.1065]]),
#  tensor([[0.1157]]),
#  tensor([[0.1869]]),
#  tensor([[0.0599]]),
#  tensor([[0.0639]]),
#  tensor([[0.0559]]),
#  tensor([[0.1365]]),
#  tensor([[0.1027]]),
#  tensor([[0.1645]]),
#  tensor([[0.0634]]),
#  tensor([[0.1091]]),
#  tensor([[0.0312]]),
#  tensor([[0.0898]]),
#  tensor([[0.0992]]),
#  tensor([[0.0674]]),
#  tensor([[0.0180]]),
#  tensor([[0.2162]]),
#  tensor([[0.1668]]),
#  tensor([[0.1483]]),
#  tensor([[0.1842]]),
#  tensor([[0.1073]]),
#  tensor([[-0.0383]]),
#  tensor([[0.0549]]),
#  tensor([[0.1421]]),
#  tensor([[0.0596]]),
#  tensor([[0.1272]]),
#  tensor([[0.1234]]),
#  tensor([[0.1234]]),
#  tensor([[0.1019]]),
#  tensor([[-0.0167]]),
#  tensor([[0.0969]]),
#  tensor([[0.1101]]),
#  tensor([[0.1835]]),
#  tensor([[0.1562]]),
#  tensor([[0.1453]]),
#  tensor([[0.0988]]),
#  tensor([[0.1359]]),
#  tensor([[0.0909]]),
#  tensor([[0.0862]]),
#  tensor([[0.0835]]),
#  tensor([[0.1456]]),
#  tensor([[-0.0058]]),
#  tensor([[-0.0218]]),
#  tensor([[0.0470]]),
#  tensor([[0.0386]]),
#  tensor([[0.0835]]),
#  tensor([[0.0084]]),
#  tensor([[0.0977]]),
#  tensor([[0.1921]]),
#  tensor([[0.0265]]),
#  tensor([[0.1669]]),
#  tensor([[0.1976]]),
#  tensor([[0.1127]]),
#  tensor([[0.0650]]),
#  tensor([[0.1553]]),
#  tensor([[0.1206]]),
#  tensor([[0.0810]]),
#  tensor([[0.1415]]),
#  tensor([[0.1437]]),
#  tensor([[0.0427]]),
#  tensor([[0.0679]]),
#  tensor([[0.0675]]),
#  tensor([[0.0313]]),
#  tensor([[0.0456]]),
#  tensor([[0.0873]]),
#  tensor([[0.0794]]),
#  tensor([[0.0491]]),
#  tensor([[0.0576]]),
#  tensor([[0.0220]]),
#  tensor([[-0.0043]]),
#  tensor([[0.1880]]),
#  tensor([[0.1256]]),
#  tensor([[0.0834]]),
#  tensor([[0.0432]]),
#  tensor([[0.1106]]),
#  tensor([[0.1761]]),
#  tensor([[0.0664]]),
#  tensor([[0.1341]]),
#  tensor([[0.0787]]),
#  tensor([[0.0814]]),
#  tensor([[0.1302]]),
#  tensor([[0.2106]]),
#  tensor([[0.1024]]),
#  tensor([[0.0489]]),
#  tensor([[0.0585]]),
#  tensor([[-0.0433]]),
#  tensor([[0.1784]]),
#  tensor([[0.1159]]),
#  tensor([[0.0816]]),
#  tensor([[0.0240]]),
#  tensor([[0.0920]]),
#  tensor([[0.0754]]),
#  tensor([[0.1058]]),
#  tensor([[0.1569]]),
#  tensor([[0.0841]]),
#  tensor([[0.1305]]),
#  tensor([[0.0588]]),
#  tensor([[0.0732]]),
#  tensor([[0.2619]]),
#  tensor([[0.0099]]),
#  tensor([[0.0746]]),
#  tensor([[0.0503]]),
#  tensor([[0.1530]]),
#  tensor([[0.1424]]),
#  tensor([[0.0682]]),
#  tensor([[0.1011]]),
#  tensor([[0.1823]]),
#  tensor([[0.0453]]),
#  tensor([[0.0674]]),
#  tensor([[0.1269]]),
#  tensor([[0.1012]]),
#  tensor([[0.0684]]),
#  tensor([[0.0744]]),
#  tensor([[0.0315]]),
#  tensor([[0.1090]]),
#  tensor([[0.1315]]),
#  tensor([[0.1934]]),
#  tensor([[-0.0239]]),
#  tensor([[0.1162]]),
#  tensor([[0.0589]]),
#  tensor([[0.0710]]),
#  tensor([[0.0527]]),
#  tensor([[-0.0073]]),
#  tensor([[0.0998]]),
#  tensor([[0.1588]]),
#  tensor([[0.0712]]),
#  tensor([[0.1004]]),
#  tensor([[0.1699]]),
#  tensor([[-0.0853]]),
#  tensor([[0.0752]]),
#  tensor([[0.0504]]),
#  tensor([[-0.0110]]),
#  tensor([[0.0733]]),
#  tensor([[0.1994]]),
#  tensor([[0.0150]]),
#  tensor([[0.0936]]),
#  tensor([[0.0526]]),
#  tensor([[0.0658]]),
#  tensor([[0.0007]]),
#  tensor([[0.1174]]),
#  tensor([[0.0764]]),
#  tensor([[0.1175]]),
#  tensor([[0.0576]]),
#  tensor([[0.1413]]),
#  tensor([[0.0517]]),
#  tensor([[0.0875]]),
#  tensor([[0.0073]]),
#  tensor([[0.1111]]),
#  tensor([[0.1055]]),
#  tensor([[0.1085]]),
#  tensor([[0.1826]]),
#  tensor([[0.0279]]),
#  tensor([[0.0212]]),
#  tensor([[0.1430]]),
#  tensor([[0.0813]]),
#  tensor([[0.1202]]),
#  tensor([[0.1198]]),
#  tensor([[-0.0034]]),
#  tensor([[0.0045]]),
#  tensor([[0.0972]]),
#  tensor([[0.0583]]),
#  tensor([[0.1364]]),
#  tensor([[0.1317]]),
#  tensor([[0.0354]]),
#  tensor([[0.0688]]),
#  tensor([[0.0477]]),
#  tensor([[0.1749]]),
#  tensor([[0.0573]]),
#  tensor([[0.0109]]),
#  tensor([[0.1046]]),
#  tensor([[0.0866]]),
#  tensor([[0.0343]]),
#  tensor([[0.0878]]),
#  tensor([[0.1376]]),
#  tensor([[0.1112]]),
#  tensor([[0.0280]]),
#  tensor([[0.1171]]),
#  tensor([[0.0211]]),
#  tensor([[0.0306]]),
#  tensor([[0.0968]]),
#  tensor([[0.0168]]),
#  tensor([[0.0730]]),
#  tensor([[0.1330]]),
#  tensor([[0.0600]]),
#  tensor([[0.1181]]),
#  tensor([[-0.0012]]),
#  tensor([[0.0816]]),
#  tensor([[0.2035]]),
#  tensor([[0.2829]]),
#  tensor([[0.0134]]),
#  tensor([[0.0845]]),
#  tensor([[0.0750]]),
#  tensor([[0.0548]]),
#  tensor([[0.0756]]),
#  tensor([[0.0546]]),
#  tensor([[0.0929]]),
#  tensor([[0.0870]]),
#  tensor([[0.1276]]),
#  tensor([[0.0593]]),
#  tensor([[0.0557]]),
#  tensor([[0.0707]]),
#  tensor([[0.0062]]),
#  tensor([[0.1676]]),
#  tensor([[0.1345]]),
#  tensor([[0.1006]]),
#  tensor([[0.1226]]),
#  tensor([[0.1454]]),
#  tensor([[0.0800]]),
#  tensor([[0.2299]]),
#  tensor([[0.0826]]),
#  tensor([[0.1023]]),
#  tensor([[0.0938]]),
#  tensor([[0.0243]]),
#  tensor([[-0.0030]]),
#  tensor([[0.1029]]),
#  tensor([[0.0985]]),
#  tensor([[0.1242]]),
#  tensor([[0.0714]]),
#  tensor([[0.1434]]),
#  tensor([[0.0819]]),
#  tensor([[0.1864]]),
#  tensor([[0.1283]]),
#  tensor([[0.0940]]),
#  tensor([[0.0583]]),
#  tensor([[0.1558]]),
#  tensor([[0.0638]]),
#  tensor([[-0.0191]]),
#  tensor([[0.1299]]),
#  tensor([[0.0450]]),
#  tensor([[0.0031]]),
#  tensor([[0.0939]]),
#  tensor([[0.0578]]),
#  tensor([[0.1283]]),
#  tensor([[0.1612]]),
#  tensor([[0.0476]]),
#  tensor([[0.0978]]),
#  tensor([[0.1212]]),
#  tensor([[0.1049]]),
#  tensor([[0.1876]]),
#  tensor([[0.1468]]),
#  tensor([[0.1386]]),
#  tensor([[0.0770]]),
#  tensor([[0.1110]]),
#  tensor([[0.0379]]),
#  tensor([[0.1340]]),
#  tensor([[0.0811]]),
#  tensor([[0.1242]]),
#  tensor([[0.0635]]),
#  tensor([[0.1284]]),
#  tensor([[0.1080]]),
#  tensor([[0.0102]]),
#  tensor([[0.0773]]),
#  tensor([[0.1642]]),
#  tensor([[0.0493]]),
#  tensor([[0.0316]]),
#  tensor([[0.1150]]),
#  tensor([[0.0176]]),
#  tensor([[0.0108]]),
#  tensor([[0.0888]]),
#  tensor([[0.1417]]),
#  tensor([[0.0735]]),
#  tensor([[0.0762]]),
#  tensor([[0.1161]]),
#  tensor([[0.0842]]),
#  tensor([[0.0485]]),
#  tensor([[0.1735]]),
#  tensor([[0.1978]]),
#  tensor([[0.0167]]),
#  tensor([[0.0305]]),
#  tensor([[0.1055]]),
#  tensor([[0.0120]]),
#  tensor([[0.1153]]),
#  tensor([[0.0922]]),
#  tensor([[0.1003]]),
#  tensor([[0.0634]]),
#  tensor([[0.0658]]),
#  tensor([[0.0777]]),
#  tensor([[0.1075]]),
#  tensor([[0.0824]]),
#  tensor([[0.0522]]),
#  tensor([[0.0506]]),
#  tensor([[0.0299]]),
#  tensor([[0.0355]]),
#  tensor([[0.1559]]),
#  tensor([[0.1313]]),
#  tensor([[0.1102]]),
#  tensor([[0.1308]]),
#  tensor([[0.2098]]),
#  tensor([[0.0669]]),
#  tensor([[0.0737]]),
#  tensor([[-0.0955]]),
#  tensor([[0.1023]]),
#  tensor([[0.0371]]),
#  tensor([[0.0782]]),
#  tensor([[0.0274]]),
#  tensor([[0.0186]]),
#  tensor([[0.1363]]),
#  tensor([[0.0423]]),
#  tensor([[0.0935]]),
#  tensor([[0.1101]]),
#  tensor([[0.1030]]),
#  tensor([[0.0809]]),
#  tensor([[0.0812]]),
#  tensor([[0.1572]]),
#  tensor([[0.1396]]),
#  tensor([[0.1175]]),
#  tensor([[0.0490]]),
#  tensor([[0.1075]]),
#  tensor([[0.1011]]),
#  tensor([[0.0413]]),
#  tensor([[0.0710]]),
#  tensor([[0.1410]]),
#  tensor([[0.0978]]),
#  tensor([[0.0205]]),
#  tensor([[0.0215]]),
#  tensor([[0.0161]]),
#  tensor([[0.0811]]),
#  tensor([[0.1256]]),
#  tensor([[0.0704]]),
#  tensor([[0.0386]]),
#  tensor([[0.0594]]),
#  tensor([[0.1146]]),
#  tensor([[0.1772]]),
#  tensor([[0.2553]]),
#  tensor([[0.0404]]),
#  tensor([[0.0247]]),
#  tensor([[0.1105]]),
#  tensor([[0.2179]]),
#  tensor([[0.1069]]),
#  tensor([[0.1220]]),
#  tensor([[0.1211]]),
#  tensor([[0.0643]]),
#  tensor([[0.1269]]),
#  tensor([[0.0098]]),
#  tensor([[0.0538]]),
#  tensor([[0.0936]]),
#  tensor([[0.2228]]),
#  tensor([[0.0765]]),
#  tensor([[0.0429]]),
#  tensor([[0.2114]]),
#  tensor([[-0.0436]]),
#  tensor([[0.1448]]),
#  tensor([[0.1961]]),
#  tensor([[0.0160]]),
#  tensor([[0.0537]]),
#  tensor([[0.0866]]),
#  tensor([[0.2386]]),
#  tensor([[0.2031]]),
#  tensor([[0.1179]]),
#  tensor([[0.1899]]),
#  tensor([[0.1594]]),
#  tensor([[0.2024]]),
#  tensor([[0.0094]]),
#  tensor([[0.0281]]),
#  tensor([[0.1530]]),
#  tensor([[0.0955]]),
#  tensor([[0.0424]]),
#  tensor([[0.1857]]),
#  tensor([[0.0662]]),
#  tensor([[0.1572]]),
#  tensor([[0.0799]]),
#  tensor([[0.0734]]),
#  tensor([[0.0538]]),
#  tensor([[-0.0016]]),
#  tensor([[0.0980]]),
#  tensor([[0.1173]]),
#  tensor([[0.1064]]),
#  tensor([[0.0697]]),
#  tensor([[0.0328]]),
#  tensor([[0.0355]]),
#  tensor([[0.1902]]),
#  tensor([[0.1555]]),
#  tensor([[0.1425]]),
#  tensor([[0.0799]]),
#  tensor([[0.0923]]),
#  tensor([[0.1596]]),
#  tensor([[0.1259]]),
#  tensor([[0.1017]]),
#  tensor([[0.0257]]),
#  tensor([[0.0536]]),
#  tensor([[0.0603]]),
#  tensor([[0.1858]]),
#  tensor([[0.0643]]),
#  tensor([[0.1585]]),
#  tensor([[0.0625]]),
#  tensor([[0.1323]]),
#  tensor([[0.1033]]),
#  tensor([[0.1289]]),
#  tensor([[0.1040]]),
#  tensor([[0.0367]]),
#  tensor([[0.0413]]),
#  tensor([[0.1265]]),
#  tensor([[0.0982]]),
#  tensor([[0.0976]]),
#  tensor([[0.1076]]),
#  tensor([[0.1766]]),
#  tensor([[0.1766]]),
#  tensor([[0.0825]]),
#  tensor([[0.1244]]),
#  tensor([[0.0462]]),
#  tensor([[0.0862]]),
#  tensor([[0.0311]]),
#  tensor([[0.0464]]),
#  tensor([[0.1612]]),
#  tensor([[0.0251]]),
#  tensor([[0.0920]]),
#  tensor([[0.1127]]),
#  tensor([[0.1234]]),
#  tensor([[0.0447]]),
#  tensor([[0.0786]]),
#  tensor([[0.1074]]),
#  tensor([[0.0296]]),
#  tensor([[0.0917]]),
#  tensor([[0.1916]]),
#  tensor([[0.0701]]),
#  tensor([[0.0748]]),
#  tensor([[0.1400]]),
#  tensor([[0.0990]]),
#  tensor([[0.1693]]),
#  tensor([[0.1883]]),
#  tensor([[0.0656]]),
#  tensor([[0.1522]]),
#  tensor([[0.1000]]),
#  tensor([[0.0819]]),
#  tensor([[0.1054]]),
#  tensor([[0.1162]]),
#  tensor([[0.1253]]),
#  tensor([[0.1686]]),
#  tensor([[0.1176]]),
#  tensor([[0.1973]]),
#  tensor([[0.0070]]),
#  tensor([[0.0155]]),
#  tensor([[0.0554]]),
#  tensor([[0.0922]]),
#  tensor([[0.1637]]),
#  tensor([[0.0564]]),
#  tensor([[0.0849]]),
#  tensor([[0.1157]]),
#  tensor([[0.0753]]),
#  tensor([[0.1085]]),
#  tensor([[-0.0005]]),
#  tensor([[0.1591]]),
#  tensor([[-0.0205]]),
#  tensor([[0.1067]]),
#  tensor([[0.1020]]),
#  tensor([[0.1476]]),
#  tensor([[0.2017]]),
#  tensor([[0.1552]]),
#  tensor([[0.1254]]),
#  tensor([[0.0693]]),
#  tensor([[0.1042]]),
#  tensor([[0.0826]]),
#  tensor([[0.0792]]),
#  tensor([[0.0313]]),
#  tensor([[0.0586]]),
#  tensor([[0.0678]]),
#  tensor([[0.0979]]),
#  tensor([[0.1870]]),
#  tensor([[0.0360]]),
#  tensor([[0.1048]]),
#  tensor([[0.0060]]),
#  tensor([[0.0587]]),
#  tensor([[0.1796]]),
#  tensor([[-0.0039]]),
#  tensor([[-0.0345]]),
#  tensor([[0.0149]]),
#  tensor([[0.0487]]),
#  tensor([[-0.0159]]),
#  tensor([[0.1202]]),
#  tensor([[0.1269]]),
#  tensor([[0.0504]]),
#  tensor([[0.0702]]),
#  tensor([[0.0214]]),
#  tensor([[0.0671]]),
#  tensor([[0.1050]]),
#  tensor([[0.1056]]),
#  tensor([[0.1085]]),
#  tensor([[0.1356]]),
#  tensor([[0.0736]]),
#  tensor([[0.1475]]),
#  tensor([[-0.0257]]),
#  tensor([[0.1803]]),
#  tensor([[0.2505]]),
#  tensor([[0.2073]]),
#  tensor([[0.1038]]),
#  tensor([[0.1274]]),
#  tensor([[0.0825]]),
#  tensor([[0.0892]]),
#  tensor([[0.0974]]),
#  tensor([[0.1469]]),
#  tensor([[0.1443]]),
#  tensor([[0.1034]]),
#  tensor([[0.1246]]),
#  tensor([[0.0797]]),
#  tensor([[0.1471]]),
#  tensor([[0.0702]]),
#  tensor([[0.0339]]),
#  tensor([[0.0697]]),
#  tensor([[0.1742]]),
#  tensor([[0.0555]]),
#  tensor([[0.1422]]),
#  tensor([[0.1828]]),
#  tensor([[0.2064]]),
#  tensor([[0.0269]]),
#  tensor([[0.0612]]),
#  tensor([[0.2437]]),
#  tensor([[-0.0217]]),
#  tensor([[0.1599]]),
#  tensor([[-0.0384]]),
#  tensor([[0.0232]]),
#  tensor([[0.0248]]),
#  tensor([[0.0912]]),
#  tensor([[0.1726]]),
#  tensor([[0.0348]]),
#  tensor([[0.1036]]),
#  tensor([[0.0899]]),
#  tensor([[0.1485]]),
#  tensor([[0.0620]]),
#  tensor([[0.0629]]),
#  tensor([[0.1347]]),
#  tensor([[0.1344]]),
#  tensor([[0.0653]]),
#  tensor([[0.0514]]),
#  tensor([[0.1636]]),
#  tensor([[0.0752]]),
#  tensor([[0.1601]]),
#  tensor([[0.1449]]),
#  tensor([[0.0043]]),
#  tensor([[0.1110]]),
#  tensor([[0.0562]]),
#  tensor([[0.1630]]),
#  tensor([[0.0355]]),
#  tensor([[0.0950]]),
#  tensor([[0.0451]]),
#  tensor([[0.0668]]),
#  tensor([[0.0978]]),
#  tensor([[0.0951]]),
#  tensor([[0.0991]]),
#  tensor([[0.1584]]),
#  tensor([[0.1279]]),
#  tensor([[0.2185]]),
#  tensor([[0.0527]]),
#  tensor([[0.1865]]),
#  tensor([[0.0736]]),
#  tensor([[0.1618]]),
#  tensor([[0.1544]]),
#  tensor([[0.0831]]),
#  tensor([[0.0631]]),
#  tensor([[0.1336]]),
#  tensor([[-0.0247]]),
#  tensor([[0.1266]]),
#  tensor([[0.0527]]),
#  tensor([[0.1984]]),
#  tensor([[0.0408]]),
#  tensor([[0.1513]]),
#  tensor([[-0.0063]]),
#  tensor([[0.0182]]),
#  tensor([[-0.0009]]),
#  tensor([[0.0538]]),
#  tensor([[0.0754]]),
#  tensor([[0.1121]]),
#  tensor([[0.0902]]),
#  tensor([[0.1180]]),
#  tensor([[0.0592]]),
#  tensor([[0.0774]]),
#  tensor([[-0.0020]]),
#  tensor([[0.0598]]),
#  tensor([[0.1301]]),
#  tensor([[0.1711]]),
#  tensor([[0.0257]]),
#  tensor([[0.1543]]),
#  tensor([[0.1204]]),
#  tensor([[0.0748]]),
#  tensor([[0.1288]]),
#  tensor([[-0.0575]]),
#  tensor([[0.1440]]),
#  tensor([[0.0320]]),
#  tensor([[0.0775]]),
#  tensor([[0.0832]]),
#  tensor([[0.0814]]),
#  tensor([[0.1990]]),
#  tensor([[0.1757]]),
#  tensor([[0.0586]]),
#  tensor([[0.1082]]),
#  tensor([[0.0977]]),
#  tensor([[0.0819]]),
#  tensor([[0.1626]]),
#  tensor([[0.0337]]),
#  tensor([[0.0135]]),
#  tensor([[0.1432]]),
#  tensor([[0.0706]]),
#  tensor([[0.1026]]),
#  tensor([[0.1236]]),
#  tensor([[0.1098]]),
#  tensor([[0.0503]]),
#  tensor([[0.0668]]),
#  tensor([[0.0942]]),
#  tensor([[0.1083]]),
#  tensor([[0.0888]]),
#  tensor([[0.1419]]),
#  ...]

# %%
import numpy as np

cos_similarities_array = np.array(cos_similarities)
sorted_indices = cos_similarities_array.argsort()[::-1].tolist()
# Out:
# C:\Users\Abinay Rachakonda\AppData\Local\Temp\ipykernel_15912\1959836394.py:3: FutureWarning: The input object of type 'Tensor' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Tensor', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   cos_similarities_array = np.array(cos_similarities)
# C:\Users\Abinay Rachakonda\AppData\Local\Temp\ipykernel_15912\1959836394.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   cos_similarities_array = np.array(cos_similarities)

# %%
sorted_indices
# Out:
# [3734,
#  6302,
#  7737,
#  3216,
#  5544,
#  7505,
#  3204,
#  5727,
#  5661,
#  5000,
#  5073,
#  4814,
#  588,
#  2626,
#  7183,
#  6964,
#  5538,
#  4418,
#  3893,
#  4532,
#  7006,
#  2039,
#  5611,
#  4282,
#  5769,
#  4124,
#  4982,
#  2756,
#  4781,
#  498,
#  6822,
#  7362,
#  3111,
#  4492,
#  7325,
#  723,
#  3062,
#  7806,
#  7307,
#  1798,
#  4944,
#  1258,
#  882,
#  3436,
#  2759,
#  4448,
#  2942,
#  2999,
#  1768,
#  4291,
#  905,
#  3557,
#  2082,
#  2447,
#  3189,
#  7686,
#  4856,
#  1488,
#  4267,
#  1680,
#  1304,
#  746,
#  5723,
#  3483,
#  2908,
#  6988,
#  4225,
#  2486,
#  6494,
#  6693,
#  5068,
#  1518,
#  6825,
#  6088,
#  7007,
#  7688,
#  1473,
#  5286,
#  1067,
#  1840,
#  3407,
#  4053,
#  5535,
#  6339,
#  1532,
#  4236,
#  4190,
#  608,
#  261,
#  378,
#  6614,
#  1608,
#  6944,
#  2446,
#  4521,
#  6298,
#  1242,
#  3049,
#  6925,
#  127,
#  7815,
#  5108,
#  5944,
#  5184,
#  6595,
#  245,
#  5935,
#  4962,
#  59,
#  2206,
#  5492,
#  736,
#  7242,
#  2767,
#  2028,
#  5361,
#  6315,
#  1411,
#  3468,
#  2275,
#  7317,
#  2816,
#  6634,
#  6898,
#  4355,
#  5572,
#  7167,
#  6755,
#  6849,
#  940,
#  1109,
#  1380,
#  727,
#  3070,
#  5472,
#  4875,
#  1535,
#  2555,
#  7583,
#  172,
#  416,
#  7934,
#  3559,
#  7998,
#  7948,
#  6888,
#  4384,
#  7794,
#  6815,
#  7268,
#  2922,
#  5724,
#  2758,
#  3781,
#  3523,
#  3970,
#  6468,
#  1871,
#  7636,
#  1085,
#  6625,
#  244,
#  4178,
#  1322,
#  4076,
#  7257,
#  3443,
#  5864,
#  1215,
#  3595,
#  7012,
#  5997,
#  1474,
#  4371,
#  739,
#  2858,
#  1283,
#  6962,
#  4935,
#  1678,
#  90,
#  481,
#  5745,
#  7001,
#  6541,
#  687,
#  6326,
#  2212,
#  4136,
#  5670,
#  1593,
#  3786,
#  1146,
#  6865,
#  5001,
#  4111,
#  6968,
#  2119,
#  7704,
#  5124,
#  1782,
#  1059,
#  883,
#  2794,
#  4231,
#  5151,
#  4402,
#  1051,
#  4281,
#  4028,
#  5976,
#  902,
#  7144,
#  4720,
#  179,
#  5495,
#  5058,
#  2734,
#  4030,
#  6610,
#  5978,
#  6520,
#  4792,
#  5089,
#  2925,
#  4666,
#  1799,
#  1569,
#  326,
#  181,
#  5919,
#  3349,
#  7754,
#  2145,
#  3267,
#  1551,
#  7845,
#  20,
#  587,
#  5182,
#  5688,
#  1953,
#  4272,
#  7520,
#  2029,
#  747,
#  1082,
#  1235,
#  2227,
#  1807,
#  4734,
#  3776,
#  124,
#  5690,
#  751,
#  2970,
#  7964,
#  5525,
#  4864,
#  1694,
#  2561,
#  7130,
#  4795,
#  846,
#  3323,
#  3344,
#  6722,
#  3008,
#  6172,
#  3106,
#  7402,
#  5820,
#  7276,
#  6913,
#  6956,
#  4910,
#  1428,
#  7428,
#  7783,
#  2873,
#  6922,
#  533,
#  6354,
#  278,
#  6741,
#  2992,
#  2032,
#  980,
#  4648,
#  7435,
#  5102,
#  5511,
#  7281,
#  4186,
#  3572,
#  952,
#  3637,
#  2524,
#  295,
#  4845,
#  666,
#  274,
#  451,
#  3242,
#  3105,
#  2363,
#  829,
#  5294,
#  4051,
#  1779,
#  4347,
#  5777,
#  7177,
#  4153,
#  2501,
#  6731,
#  3603,
#  6191,
#  742,
#  2166,
#  7745,
#  4612,
#  7470,
#  7507,
#  2517,
#  5338,
#  2097,
#  2748,
#  1278,
#  5633,
#  5974,
#  2944,
#  257,
#  304,
#  4898,
#  2345,
#  2568,
#  7757,
#  6345,
#  170,
#  4716,
#  4789,
#  7652,
#  74,
#  516,
#  3661,
#  5901,
#  7468,
#  3416,
#  6324,
#  4416,
#  4080,
#  5758,
#  2491,
#  1405,
#  448,
#  4719,
#  7352,
#  1195,
#  4122,
#  6162,
#  3535,
#  4429,
#  7564,
#  5476,
#  813,
#  1794,
#  6478,
#  4183,
#  1777,
#  5563,
#  66,
#  2369,
#  1856,
#  7549,
#  6496,
#  145,
#  2980,
#  3330,
#  2950,
#  2054,
#  6409,
#  7036,
#  770,
#  4794,
#  5789,
#  6149,
#  5121,
#  749,
#  1499,
#  5645,
#  3738,
#  5889,
#  6642,
#  7273,
#  4283,
#  2021,
#  2061,
#  5867,
#  1645,
#  7658,
#  5943,
#  6082,
#  819,
#  2787,
#  5703,
#  1412,
#  470,
#  2260,
#  2879,
#  6678,
#  2661,
#  1111,
#  3886,
#  3124,
#  638,
#  3223,
#  3854,
#  4269,
#  4226,
#  6281,
#  5766,
#  1296,
#  1037,
#  857,
#  402,
#  3826,
#  5713,
#  1595,
#  5384,
#  1996,
#  2997,
#  7823,
#  2607,
#  7800,
#  3602,
#  942,
#  1256,
#  620,
#  5033,
#  4540,
#  6336,
#  2257,
#  5649,
#  1451,
#  781,
#  757,
#  3611,
#  3462,
#  2857,
#  4741,
#  5979,
#  2389,
#  2898,
#  7367,
#  2667,
#  4352,
#  1179,
#  3547,
#  4193,
#  5440,
#  6254,
#  3299,
#  5044,
#  5039,
#  3476,
#  2084,
#  3069,
#  4995,
#  1970,
#  419,
#  4210,
#  7926,
#  2668,
#  7821,
#  1888,
#  5639,
#  7716,
#  370,
#  3698,
#  432,
#  5250,
#  6991,
#  4470,
#  1775,
#  7873,
#  7852,
#  1502,
#  3882,
#  1312,
#  7159,
#  1513,
#  901,
#  7628,
#  1494,
#  1621,
#  3647,
#  550,
#  6593,
#  3579,
#  506,
#  5066,
#  256,
#  3655,
#  79,
#  1523,
#  5555,
#  6033,
#  5310,
#  4909,
#  3192,
#  5987,
#  2328,
#  4502,
#  7751,
#  5342,
#  6529,
#  4570,
#  4614,
#  6335,
#  3081,
#  1433,
#  1395,
#  3362,
#  2123,
#  881,
#  3771,
#  1746,
#  4581,
#  4116,
#  4203,
#  6406,
#  7472,
#  3188,
#  5354,
#  862,
#  4240,
#  6346,
#  3718,
#  7973,
#  5064,
#  7922,
#  4810,
#  1232,
#  1689,
#  3380,
#  5531,
#  2245,
#  5473,
#  1219,
#  7822,
#  5010,
#  4704,
#  4817,
#  2732,
#  238,
#  2200,
#  486,
#  2765,
#  5541,
#  2669,
#  5700,
#  1006,
#  4125,
#  5052,
#  2000,
#  3179,
#  3942,
#  3810,
#  4007,
#  3762,
#  7113,
#  4872,
#  6275,
#  722,
#  6567,
#  1060,
#  5822,
#  6066,
#  6009,
#  5776,
#  2361,
#  4130,
#  5135,
#  795,
#  796,
#  88,
#  3662,
#  6835,
#  2216,
#  7890,
#  2209,
#  475,
#  229,
#  2147,
#  7395,
#  7359,
#  981,
#  4722,
#  5165,
#  4019,
#  3986,
#  5200,
#  6623,
#  104,
#  6471,
#  4314,
#  4099,
#  3896,
#  7153,
#  3497,
#  1402,
#  3212,
#  7363,
#  566,
#  1676,
#  5759,
#  2161,
#  6441,
#  375,
#  7917,
#  3061,
#  5663,
#  2749,
#  3311,
#  898,
#  3732,
#  3317,
#  4496,
#  2518,
#  7469,
#  2611,
#  6048,
#  6295,
#  3543,
#  3796,
#  3862,
#  665,
#  6635,
#  3887,
#  7370,
#  5082,
#  2381,
#  1176,
#  7569,
#  7295,
#  5905,
#  6788,
#  1035,
#  912,
#  4214,
#  5070,
#  1573,
#  7879,
#  4930,
#  3870,
#  115,
#  4459,
#  5156,
#  6245,
#  4546,
#  2677,
#  4413,
#  290,
#  4998,
#  6647,
#  4022,
#  3456,
#  5926,
#  968,
#  6317,
#  2009,
#  1001,
#  6653,
#  1336,
#  4828,
#  4723,
#  2505,
#  1744,
#  6125,
#  5773,
#  3952,
#  5011,
#  2068,
#  3562,
#  5339,
#  1091,
#  1634,
#  5868,
#  4379,
#  6437,
#  527,
#  5290,
#  53,
#  5503,
#  1994,
#  2225,
#  2081,
#  3582,
#  5382,
#  3,
#  7703,
#  3634,
#  6394,
#  5802,
#  818,
#  216,
#  2523,
#  3597,
#  2995,
#  5336,
#  2424,
#  6134,
#  7496,
#  1845,
#  827,
#  7803,
#  3457,
#  2516,
#  6927,
#  4171,
#  6568,
#  5453,
#  2510,
#  4086,
#  5915,
#  7212,
#  5174,
#  6941,
#  3730,
#  7644,
#  2004,
#  7193,
#  5207,
#  602,
#  6721,
#  2665,
#  3063,
#  6133,
#  6862,
#  3741,
#  5158,
#  4132,
#  6183,
#  5417,
#  450,
#  5584,
#  417,
#  4320,
#  2976,
#  4143,
#  3450,
#  7909,
#  1662,
#  4357,
#  7756,
#  6280,
#  6283,
#  4512,
#  3532,
#  7539,
#  1183,
#  2736,
#  1682,
#  2258,
#  5779,
#  6669,
#  7911,
#  54,
#  5972,
#  7954,
#  4601,
#  1073,
#  1033,
#  7488,
#  7355,
#  2131,
#  1400,
#  1673,
#  3623,
#  5283,
#  4840,
#  6951,
#  7781,
#  6292,
#  5092,
#  1559,
#  1926,
#  3413,
#  6310,
#  336,
#  4087,
#  207,
#  3573,
#  4825,
#  203,
#  1935,
#  5117,
#  408,
#  4635,
#  7571,
#  4141,
#  4761,
#  2804,
#  6809,
#  652,
#  7029,
#  3183,
#  1221,
#  4164,
#  1376,
#  3245,
#  7655,
#  3434,
#  7476,
#  7870,
#  5144,
#  7230,
#  7724,
#  1415,
#  6914,
#  5862,
#  3000,
#  834,
#  4443,
#  923,
#  1820,
#  1545,
#  3654,
#  6454,
#  3905,
#  1599,
#  2896,
#  6268,
#  5326,
#  6981,
#  930,
#  2391,
#  3233,
#  3075,
#  6739,
#  2889,
#  986,
#  7275,
#  3651,
#  4137,
#  3268,
#  2487,
#  4414,
#  6445,
#  1429,
#  4436,
#  4437,
#  1594,
#  2723,
#  4475,
#  1727,
#  7340,
#  139,
#  1577,
#  5512,
#  7412,
#  944,
#  7918,
#  7041,
#  6303,
#  7848,
#  1536,
#  7335,
#  3598,
#  4115,
#  6419,
#  2932,
#  7244,
#  6959,
#  7941,
#  6211,
#  1693,
#  4032,
#  2542,
#  7883,
#  803,
#  4626,
#  633,
#  5873,
#  5459,
#  1324,
#  3074,
#  2629,
#  4215,
#  4617,
#  4557,
#  2935,
#  4999,
#  2488,
#  6054,
#  6450,
#  12,
#  1343,
#  3477,
#  6182,
#  7024,
#  7149,
#  6480,
#  3600,
#  2249,
#  4663,
#  2092,
#  7255,
#  925,
#  4396,
#  7094,
#  6398,
#  907,
#  1254,
#  4555,
#  2892,
#  5614,
#  3448,
#  775,
#  6477,
#  2026,
#  3384,
#  5556,
#  2449,
#  4639,
#  5236,
#  750,
#  7807,
#  841,
#  1,
#  6950,
#  7526,
#  5568,
#  6207,
#  7075,
#  524,
#  2522,
#  7013,
#  3863,
#  6004,
#  393,
#  5865,
#  3615,
#  7120,
#  3101,
#  5691,
#  5799,
#  2633,
#  783,
#  2802,
#  5952,
#  117,
#  938,
#  1821,
#  1220,
#  6720,
#  3587,
#  4613,
#  1549,
#  7399,
#  7635,
#  6101,
#  6672,
#  5671,
#  7508,
#  174,
#  4234,
#  6470,
#  2710,
#  2881,
#  6050,
#  6377,
#  2773,
#  2150,
#  4725,
#  3594,
#  7181,
#  703,
#  1174,
#  759,
#  1367,
#  6485,
#  7487,
#  493,
#  7098,
#  2404,
#  3427,
#  6604,
#  3210,
#  6576,
#  2110,
#  3213,
#  4500,
#  2307,
#  6638,
#  1703,
#  1077,
#  433,
#  3134,
#  ...]

# %%
top_sub = merged_df.iloc[sorted_indices[::]]

# %%
a=top_sub['file_content_chunks']

# %%
a[0]
# Out:
# 'film reel clacking robert englund movie always provided safe place face fear dark movie theater deal monster terrorizing u real life seeing defeated big screen horror film like dracula invisible man wolf man provided useful catharsis frightened populace movie gave audience place share collective fear even national trauma brought financial instability world war global tension followed financial fear wartime terror soon followed new threat screaming nation horrified thought nuclear destruction scientist going far wreaking havoc nature cold war soviet american threatened global destruction national fear nuclear annihilation communist infiltration even destructive global conflict world war ii resulted horror film science run amuck alien invasion sky extraterrestrial body snatcher right earth public ever drawn movie help confront anxiety film reel clacking click film reel clacking whirring indistinct conversation man drive movie take care everything courtship babysitting shelter marilyn monroe food drink hot delicious popcorn lot candy cold drink man showtime carpenter grew formative year moviegoer somebody loved movie time saw lot science fiction film giant monster movie lot radiation movie type thing went theater rochester new york saw came outer space opening movie big ol meteor come space come right screen screen audience blow face blew face jumped ran scream stopped thought greatest thing ever seen got go back see beginning oswalt well growing horror meant whatever monster movie saturday local station grew northern virginia wdca channel saturday afternoon monster movie never seen venom quantity know venom test tube find tarantula movie fan offered something beyond watching two adult talking two adult would talk kind crazy engineered creature somebody makeup costume would show bring mayhem hilarious monster scary giant mutated ant lizard man fish man coming swamp lagoon kill music swell growing know mind godzilla one half dozen monster monster island going know come tramping across northern virginia suburb wipe everyone'

# %%
cos_sim = util.cos_sim(Query[0], df['doc_vector_pretrained_bert'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 cos_sim = util.cos_sim(Query[0], df['doc_vector_pretrained_bert'])
#
# File ~\anaconda\lib\site-packages\sentence_transformers\util.py:41, in cos_sim(a, b)
#      38     a = torch.tensor(a)
#      40 if not isinstance(b, torch.Tensor):
# ---> 41     b = torch.tensor(b)
#      43 if len(a.shape) == 1:
#      44     a = a.unsqueeze(0)
#
# ValueError: could not determine the shape of object type 'Series'

# %%
merged_df.to_csv("Sub_Titles_with_32.csv",index=False)

# %%
df.to_csv("Sub_Titles_BERT.csv",index=False)

# %%
doc_vectors[0]
# Out:
# tensor([-7.8391e-02, -1.1347e-01, -4.5691e-03, -5.6716e-03, -2.3426e-02,
#          7.3255e-03, -5.6512e-03, -3.8667e-02, -3.6171e-02,  1.5680e-02,
#          3.6550e-02, -1.0670e-02, -5.7361e-02, -4.9183e-02, -4.1457e-02,
#         -2.9344e-02,  5.0526e-02,  3.5492e-02, -7.6502e-02,  4.5095e-02,
#          2.6481e-02, -5.0474e-03,  4.9960e-02, -3.9480e-02, -1.0351e-01,
#          4.6609e-02, -1.0493e-01, -6.3279e-04,  2.9298e-03, -3.3578e-02,
#         -1.1555e-02,  9.6098e-02,  2.5953e-02,  3.7583e-02,  2.7453e-02,
#          2.3105e-02, -1.8266e-02,  1.4465e-01,  3.6982e-02, -2.8531e-02,
#         -5.5603e-02, -7.3799e-02, -7.9451e-03,  5.1660e-02, -3.8241e-02,
#         -7.6856e-02, -3.3947e-02, -4.9130e-02,  4.0102e-02, -6.1319e-02,
#         -3.9372e-02, -1.3360e-02,  3.0897e-02,  3.8811e-02, -3.8338e-02,
#         -1.7315e-02,  3.6293e-04, -4.6049e-02, -3.7786e-02, -3.4589e-02,
#         -5.0555e-02,  1.7924e-02, -4.3591e-03,  1.4208e-03, -3.1716e-02,
#         -2.4761e-02, -1.1563e-02,  2.0041e-02,  4.5937e-02, -1.5636e-02,
#         -5.5453e-03, -6.6218e-03,  3.9937e-02,  9.3793e-02, -5.5274e-03,
#          8.5532e-02, -1.9154e-02, -1.0990e-01,  2.1632e-03,  2.8332e-02,
#         -1.9772e-03,  1.1943e-02, -1.2254e-02,  5.1214e-02, -7.2447e-02,
#          5.8491e-04, -5.5130e-02,  4.0228e-02, -1.5661e-02, -1.2386e-02,
#          7.9294e-03,  3.1172e-02, -4.2602e-02, -1.1095e-01,  7.0961e-02,
#         -5.4477e-02, -2.0768e-02,  5.7507e-02, -6.3070e-02,  3.5648e-02,
#         -1.3883e-02,  3.7174e-02,  1.2015e-02, -4.9544e-02,  1.6538e-02,
#         -3.6309e-02,  4.0891e-02, -8.3028e-03, -2.3067e-02,  2.3092e-02,
#          3.2567e-02, -3.9605e-02, -3.9981e-02, -7.2435e-02,  4.4591e-02,
#         -2.8219e-02,  4.5433e-02,  2.0642e-02,  1.7345e-02,  3.7713e-02,
#         -1.7211e-02,  3.7196e-02, -1.1908e-01,  1.2010e-02, -5.9303e-03,
#          9.4073e-02,  4.6166e-02,  3.4097e-32,  1.1122e-02,  1.1775e-01,
#         -8.5800e-02, -2.7037e-02,  1.4574e-02, -1.3422e-02, -3.6938e-02,
#          8.5024e-02, -2.7514e-02,  9.8802e-02,  5.4395e-02, -1.4824e-01,
#         -5.1844e-02, -2.9366e-02, -1.0712e-01,  1.9256e-02,  7.6741e-02,
#         -8.5034e-02, -9.9112e-02,  4.0460e-02,  4.1909e-02,  3.6910e-02,
#          2.2200e-02, -1.5349e-02, -2.9445e-03, -4.9403e-02, -5.9617e-02,
#         -5.4587e-03,  7.3416e-02, -9.5183e-03, -2.7608e-02, -2.8268e-02,
#         -8.2426e-03, -2.9014e-02, -9.1280e-03,  2.3512e-02,  1.2338e-01,
#         -3.3377e-02, -1.0776e-02, -4.8655e-02, -6.7276e-02,  2.6707e-02,
#         -2.1308e-02, -1.0648e-02,  5.4183e-02, -4.4849e-02, -3.7499e-02,
#          3.6293e-02, -1.0530e-02,  2.2215e-03,  3.6864e-02, -8.8069e-03,
#          2.0574e-03,  1.9362e-02, -2.8291e-02,  6.0402e-02, -5.6911e-02,
#         -3.5322e-03,  8.7562e-02,  8.2672e-02, -5.3788e-02, -3.1518e-02,
#         -1.8565e-02,  1.2283e-02,  6.2676e-02, -8.6534e-02,  1.4951e-02,
#         -7.6135e-02,  3.4944e-02,  3.4903e-02, -3.8918e-02, -6.5044e-02,
#          1.5500e-02,  1.9827e-02,  4.2177e-02,  7.4617e-02,  4.1469e-02,
#         -2.5572e-02,  3.2118e-02, -1.0926e-02,  5.7366e-02, -4.5356e-02,
#         -7.0235e-02,  4.5187e-02,  6.4633e-02, -2.2070e-02,  3.1730e-02,
#         -5.6404e-02, -1.0564e-01, -4.3532e-02,  5.1317e-02, -3.7662e-02,
#         -1.4308e-02, -9.2804e-02, -5.8798e-02, -3.2672e-32,  5.4325e-02,
#          2.7097e-02, -2.1946e-02,  1.5582e-02, -1.1365e-02, -2.4407e-02,
#         -1.0537e-01, -7.6433e-02,  1.2258e-01,  6.5210e-03,  6.9653e-03,
#         -2.5761e-02,  2.2182e-02, -3.1921e-02,  5.8834e-02, -3.2736e-02,
#         -6.7839e-02,  2.0001e-02, -9.1430e-03,  1.2642e-01, -8.7967e-02,
#          5.8765e-02, -8.1844e-02,  1.8232e-02,  2.6842e-02,  2.3369e-02,
#          2.3935e-02,  1.3643e-01, -1.3474e-02,  4.4618e-02, -1.3863e-01,
#         -3.2619e-02,  2.2516e-02,  3.3946e-02, -3.8615e-02,  4.4345e-02,
#          5.6859e-02, -8.0045e-03, -9.9468e-02, -5.8539e-03,  1.4053e-02,
#         -2.8951e-02, -8.5002e-02, -6.5030e-04, -6.9445e-02, -5.4517e-02,
#         -9.2570e-02,  8.1558e-02,  1.8922e-02,  1.5105e-03,  1.9206e-02,
#          1.3997e-02, -7.7972e-02,  7.8365e-03, -8.8853e-04, -2.6256e-02,
#          6.1062e-03, -8.8671e-02, -5.2365e-02, -5.9379e-02,  7.8036e-04,
#          7.3083e-02, -3.5712e-02,  4.3693e-02,  1.2167e-01, -1.5172e-01,
#         -7.8435e-02, -5.6188e-02, -9.9498e-02, -2.6869e-02, -4.5985e-03,
#         -1.2666e-02,  2.5688e-02, -2.0343e-02,  8.0911e-02,  6.3231e-02,
#          1.3846e-02, -7.9591e-02, -8.8764e-03,  2.0634e-02, -2.9256e-02,
#         -3.1039e-02, -1.3785e-02,  4.9767e-02,  5.0552e-02,  3.8557e-02,
#          1.4033e-02,  3.8525e-02, -6.0457e-03, -1.0472e-02,  2.5248e-02,
#         -3.9789e-02,  2.0265e-02, -1.2671e-02, -7.1126e-02, -8.6447e-08,
#          2.6555e-02,  5.0931e-02,  3.9776e-02,  1.6011e-03,  1.0448e-01,
#         -1.7579e-02,  2.8093e-04,  8.8490e-02,  1.0820e-02,  5.3531e-02,
#          2.8998e-02,  4.5405e-02,  2.8751e-02, -9.4594e-02,  7.4656e-03,
#          5.1316e-02, -4.4342e-02, -4.7658e-02, -9.7386e-02, -9.0511e-02,
#         -3.1200e-02, -3.6232e-02, -5.0168e-02,  3.6861e-02,  9.6383e-04,
#         -1.9780e-02, -7.8799e-02, -2.6987e-03, -4.3048e-02, -1.1395e-02,
#          1.2822e-02, -4.7087e-02,  5.3353e-02, -2.8051e-02,  7.0677e-02,
#         -7.2971e-03,  6.8442e-02, -1.7660e-03, -4.2289e-03, -3.5747e-03,
#         -6.2873e-02, -6.5041e-02, -3.5459e-02, -1.0277e-02, -6.3399e-02,
#         -4.2881e-02,  4.4676e-02, -7.8513e-03,  2.5714e-02, -8.2106e-02,
#          2.2229e-02, -1.2430e-02, -2.4588e-02, -3.3772e-02, -2.7161e-02,
#          3.0030e-02,  3.4171e-02,  7.8108e-02,  2.4163e-02,  4.7335e-03,
#          2.4404e-02,  4.4218e-02,  2.5390e-02, -8.0576e-02])

# %%
client = chromadb.PersistentClient(path="Search_engine")

# %%
client

# %%
 collection = client.create_collection(
        name="search",
        metadata={"hnsw:space": "cosine"} # l2 is the default
    )

# %%
for i, emb in enumerate(doc_vectors):
    embs=np.array(emb)
    collection.add(ids=f"chunks_{i}",
    embeddings=embs.tolist(),
                   documents=df.loc[i,"file_content_chunks"]
                  )
# Out:
# Add of existing embedding ID: chunks_0
# Insert of existing embedding ID: chunks_0
# Add of existing embedding ID: chunks_1
# Insert of existing embedding ID: chunks_1
# Add of existing embedding ID: chunks_2
# Insert of existing embedding ID: chunks_2
# Add of existing embedding ID: chunks_3
# Insert of existing embedding ID: chunks_3
# Add of existing embedding ID: chunks_4
# Insert of existing embedding ID: chunks_4
# Add of existing embedding ID: chunks_5
# Insert of existing embedding ID: chunks_5
# Add of existing embedding ID: chunks_6
# Insert of existing embedding ID: chunks_6
# Add of existing embedding ID: chunks_7
# Insert of existing embedding ID: chunks_7
# Add of existing embedding ID: chunks_8
# Insert of existing embedding ID: chunks_8
# Add of existing embedding ID: chunks_9
# Insert of existing embedding ID: chunks_9
# Add of existing embedding ID: chunks_10
# Insert of existing embedding ID: chunks_10
# Add of existing embedding ID: chunks_11
# Insert of existing embedding ID: chunks_11
# Add of existing embedding ID: chunks_12
# Insert of existing embedding ID: chunks_12
# Add of existing embedding ID: chunks_13
# Insert of existing embedding ID: chunks_13
# Add of existing embedding ID: chunks_14
# Insert of existing embedding ID: chunks_14
# Add of existing embedding ID: chunks_15
# Insert of existing embedding ID: chunks_15
# Add of existing embedding ID: chunks_16
# Insert of existing embedding ID: chunks_16
# Add of existing embedding ID: chunks_17
# Insert of existing embedding ID: chunks_17
# Add of existing embedding ID: chunks_18
# Insert of existing embedding ID: chunks_18
# Add of existing embedding ID: chunks_19
# Insert of existing embedding ID: chunks_19
# Add of existing embedding ID: chunks_20
# Insert of existing embedding ID: chunks_20
# Add of existing embedding ID: chunks_21
# Insert of existing embedding ID: chunks_21
# Add of existing embedding ID: chunks_22
# Insert of existing embedding ID: chunks_22
# Add of existing embedding ID: chunks_23
# Insert of existing embedding ID: chunks_23
# Add of existing embedding ID: chunks_24
# Insert of existing embedding ID: chunks_24
# Add of existing embedding ID: chunks_25
# Insert of existing embedding ID: chunks_25
# Add of existing embedding ID: chunks_26
# Insert of existing embedding ID: chunks_26
# Add of existing embedding ID: chunks_27
# Insert of existing embedding ID: chunks_27
# Add of existing embedding ID: chunks_28
# Insert of existing embedding ID: chunks_28
# Add of existing embedding ID: chunks_29
# Insert of existing embedding ID: chunks_29
# Add of existing embedding ID: chunks_30
# Insert of existing embedding ID: chunks_30
# Add of existing embedding ID: chunks_31
# Insert of existing embedding ID: chunks_31
# Add of existing embedding ID: chunks_32
# Insert of existing embedding ID: chunks_32
# Add of existing embedding ID: chunks_33
# Insert of existing embedding ID: chunks_33
# Add of existing embedding ID: chunks_34
# Insert of existing embedding ID: chunks_34
# Add of existing embedding ID: chunks_35
# Insert of existing embedding ID: chunks_35
# Add of existing embedding ID: chunks_36
# Insert of existing embedding ID: chunks_36
# Add of existing embedding ID: chunks_37
# Insert of existing embedding ID: chunks_37
# Add of existing embedding ID: chunks_38
# Insert of existing embedding ID: chunks_38
# Add of existing embedding ID: chunks_39
# Insert of existing embedding ID: chunks_39
# Add of existing embedding ID: chunks_40
# Insert of existing embedding ID: chunks_40
# Add of existing embedding ID: chunks_41
# Insert of existing embedding ID: chunks_41
# Add of existing embedding ID: chunks_42
# Insert of existing embedding ID: chunks_42
# Add of existing embedding ID: chunks_43
# Insert of existing embedding ID: chunks_43
# Add of existing embedding ID: chunks_44
# Insert of existing embedding ID: chunks_44
# Add of existing embedding ID: chunks_45
# Insert of existing embedding ID: chunks_45
# Add of existing embedding ID: chunks_46
# Insert of existing embedding ID: chunks_46
# Add of existing embedding ID: chunks_47
# Insert of existing embedding ID: chunks_47
# Add of existing embedding ID: chunks_48
# Insert of existing embedding ID: chunks_48
# Add of existing embedding ID: chunks_49
# Insert of existing embedding ID: chunks_49
# Add of existing embedding ID: chunks_50
# Insert of existing embedding ID: chunks_50
# Add of existing embedding ID: chunks_51
# Insert of existing embedding ID: chunks_51
# Add of existing embedding ID: chunks_52
# Insert of existing embedding ID: chunks_52
# Add of existing embedding ID: chunks_53
# Insert of existing embedding ID: chunks_53
# Add of existing embedding ID: chunks_54
# Insert of existing embedding ID: chunks_54
# Add of existing embedding ID: chunks_55
# Insert of existing embedding ID: chunks_55
# Add of existing embedding ID: chunks_56
# Insert of existing embedding ID: chunks_56
# Add of existing embedding ID: chunks_57
# Insert of existing embedding ID: chunks_57
# Add of existing embedding ID: chunks_58
# Insert of existing embedding ID: chunks_58
# Add of existing embedding ID: chunks_59
# Insert of existing embedding ID: chunks_59
# Add of existing embedding ID: chunks_60
# Insert of existing embedding ID: chunks_60
# Add of existing embedding ID: chunks_61
# Insert of existing embedding ID: chunks_61
# Add of existing embedding ID: chunks_62
# Insert of existing embedding ID: chunks_62
# Add of existing embedding ID: chunks_63
# Insert of existing embedding ID: chunks_63
# Add of existing embedding ID: chunks_64
# Insert of existing embedding ID: chunks_64
# Add of existing embedding ID: chunks_65
# Insert of existing embedding ID: chunks_65
# Add of existing embedding ID: chunks_66
# Insert of existing embedding ID: chunks_66
# Add of existing embedding ID: chunks_67
# Insert of existing embedding ID: chunks_67
# Add of existing embedding ID: chunks_68
# Insert of existing embedding ID: chunks_68
# Add of existing embedding ID: chunks_69
# Insert of existing embedding ID: chunks_69
# Add of existing embedding ID: chunks_70
# Insert of existing embedding ID: chunks_70
# Add of existing embedding ID: chunks_71
# Insert of existing embedding ID: chunks_71
# Add of existing embedding ID: chunks_72
# Insert of existing embedding ID: chunks_72
# Add of existing embedding ID: chunks_73
# Insert of existing embedding ID: chunks_73
# Add of existing embedding ID: chunks_74
# Insert of existing embedding ID: chunks_74
# Add of existing embedding ID: chunks_75
# Insert of existing embedding ID: chunks_75
# Add of existing embedding ID: chunks_76
# Insert of existing embedding ID: chunks_76
# Add of existing embedding ID: chunks_77
# Insert of existing embedding ID: chunks_77
# Add of existing embedding ID: chunks_78
# Insert of existing embedding ID: chunks_78
# Add of existing embedding ID: chunks_79
# Insert of existing embedding ID: chunks_79
# Add of existing embedding ID: chunks_80
# Insert of existing embedding ID: chunks_80
# Add of existing embedding ID: chunks_81
# Insert of existing embedding ID: chunks_81
# Add of existing embedding ID: chunks_82
# Insert of existing embedding ID: chunks_82
# Add of existing embedding ID: chunks_83
# Insert of existing embedding ID: chunks_83
# Add of existing embedding ID: chunks_84
# Insert of existing embedding ID: chunks_84
# Add of existing embedding ID: chunks_85
# Insert of existing embedding ID: chunks_85
# Add of existing embedding ID: chunks_86
# Insert of existing embedding ID: chunks_86
# Add of existing embedding ID: chunks_87
# Insert of existing embedding ID: chunks_87
# Add of existing embedding ID: chunks_88
# Insert of existing embedding ID: chunks_88
# Add of existing embedding ID: chunks_89
# Insert of existing embedding ID: chunks_89
# Add of existing embedding ID: chunks_90
# Insert of existing embedding ID: chunks_90
# Add of existing embedding ID: chunks_91
# Insert of existing embedding ID: chunks_91
# Add of existing embedding ID: chunks_92
# Insert of existing embedding ID: chunks_92
# Add of existing embedding ID: chunks_93
# Insert of existing embedding ID: chunks_93
# Add of existing embedding ID: chunks_94
# Insert of existing embedding ID: chunks_94
# Add of existing embedding ID: chunks_95
# Insert of existing embedding ID: chunks_95
# Add of existing embedding ID: chunks_96
# Insert of existing embedding ID: chunks_96
# Add of existing embedding ID: chunks_97
# Insert of existing embedding ID: chunks_97
# Add of existing embedding ID: chunks_98
# Insert of existing embedding ID: chunks_98
# Add of existing embedding ID: chunks_99
# Insert of existing embedding ID: chunks_99
# Add of existing embedding ID: chunks_100
# Insert of existing embedding ID: chunks_100
# Add of existing embedding ID: chunks_101
# Insert of existing embedding ID: chunks_101
# Add of existing embedding ID: chunks_102
# Insert of existing embedding ID: chunks_102
# Add of existing embedding ID: chunks_103
# Insert of existing embedding ID: chunks_103
# Add of existing embedding ID: chunks_104
# Insert of existing embedding ID: chunks_104
# Add of existing embedding ID: chunks_105
# Insert of existing embedding ID: chunks_105
# Add of existing embedding ID: chunks_106
# Insert of existing embedding ID: chunks_106
# Add of existing embedding ID: chunks_107
# Insert of existing embedding ID: chunks_107
# Add of existing embedding ID: chunks_108
# Insert of existing embedding ID: chunks_108
# Add of existing embedding ID: chunks_109
# Insert of existing embedding ID: chunks_109
# Add of existing embedding ID: chunks_110
# Insert of existing embedding ID: chunks_110
# Add of existing embedding ID: chunks_111
# Insert of existing embedding ID: chunks_111
# Add of existing embedding ID: chunks_112
# Insert of existing embedding ID: chunks_112
# Add of existing embedding ID: chunks_113
# Insert of existing embedding ID: chunks_113
# Add of existing embedding ID: chunks_114
# Insert of existing embedding ID: chunks_114
# Add of existing embedding ID: chunks_115
# Insert of existing embedding ID: chunks_115
# Add of existing embedding ID: chunks_116
# Insert of existing embedding ID: chunks_116
# Add of existing embedding ID: chunks_117
# Insert of existing embedding ID: chunks_117
# Add of existing embedding ID: chunks_118
# Insert of existing embedding ID: chunks_118
# Add of existing embedding ID: chunks_119
# Insert of existing embedding ID: chunks_119
# Add of existing embedding ID: chunks_120
# Insert of existing embedding ID: chunks_120
# Add of existing embedding ID: chunks_121
# Insert of existing embedding ID: chunks_121
# Add of existing embedding ID: chunks_122
# Insert of existing embedding ID: chunks_122
# Add of existing embedding ID: chunks_123
# Insert of existing embedding ID: chunks_123
# Add of existing embedding ID: chunks_124
# Insert of existing embedding ID: chunks_124
# Add of existing embedding ID: chunks_125
# Insert of existing embedding ID: chunks_125
# Add of existing embedding ID: chunks_126
# Insert of existing embedding ID: chunks_126
# Add of existing embedding ID: chunks_127
# Insert of existing embedding ID: chunks_127
# Add of existing embedding ID: chunks_128
# Insert of existing embedding ID: chunks_128
# Add of existing embedding ID: chunks_129
# Insert of existing embedding ID: chunks_129
# Add of existing embedding ID: chunks_130
# Insert of existing embedding ID: chunks_130
# Add of existing embedding ID: chunks_131
# Insert of existing embedding ID: chunks_131
# Add of existing embedding ID: chunks_132
# Insert of existing embedding ID: chunks_132
# Add of existing embedding ID: chunks_133
# Insert of existing embedding ID: chunks_133
# Add of existing embedding ID: chunks_134
# Insert of existing embedding ID: chunks_134
# Add of existing embedding ID: chunks_135
# Insert of existing embedding ID: chunks_135
# Add of existing embedding ID: chunks_136
# Insert of existing embedding ID: chunks_136
# Add of existing embedding ID: chunks_137
# Insert of existing embedding ID: chunks_137
# Add of existing embedding ID: chunks_138
# Insert of existing embedding ID: chunks_138
# Add of existing embedding ID: chunks_139
# Insert of existing embedding ID: chunks_139
# Add of existing embedding ID: chunks_140
# Insert of existing embedding ID: chunks_140
# Add of existing embedding ID: chunks_141
# Insert of existing embedding ID: chunks_141
# Add of existing embedding ID: chunks_142
# Insert of existing embedding ID: chunks_142
# Add of existing embedding ID: chunks_143
# Insert of existing embedding ID: chunks_143
# Add of existing embedding ID: chunks_144
# Insert of existing embedding ID: chunks_144
# Add of existing embedding ID: chunks_145
# Insert of existing embedding ID: chunks_145
# Add of existing embedding ID: chunks_146
# Insert of existing embedding ID: chunks_146
# Add of existing embedding ID: chunks_147
# Insert of existing embedding ID: chunks_147
# Add of existing embedding ID: chunks_148
# Insert of existing embedding ID: chunks_148
# Add of existing embedding ID: chunks_149
# Insert of existing embedding ID: chunks_149
# Add of existing embedding ID: chunks_150
# Insert of existing embedding ID: chunks_150
# Add of existing embedding ID: chunks_151
# Insert of existing embedding ID: chunks_151
# Add of existing embedding ID: chunks_152
# Insert of existing embedding ID: chunks_152
# Add of existing embedding ID: chunks_153
# Insert of existing embedding ID: chunks_153
# Add of existing embedding ID: chunks_154
# Insert of existing embedding ID: chunks_154
# Add of existing embedding ID: chunks_155
# Insert of existing embedding ID: chunks_155
# Add of existing embedding ID: chunks_156
# Insert of existing embedding ID: chunks_156
# Add of existing embedding ID: chunks_157
# Insert of existing embedding ID: chunks_157
# Add of existing embedding ID: chunks_158
# Insert of existing embedding ID: chunks_158
# Add of existing embedding ID: chunks_159
# Insert of existing embedding ID: chunks_159
# Add of existing embedding ID: chunks_160
# Insert of existing embedding ID: chunks_160
# Add of existing embedding ID: chunks_161
# Insert of existing embedding ID: chunks_161
# Add of existing embedding ID: chunks_162
# Insert of existing embedding ID: chunks_162
# Add of existing embedding ID: chunks_163
# Insert of existing embedding ID: chunks_163
# Add of existing embedding ID: chunks_164
# Insert of existing embedding ID: chunks_164
# Add of existing embedding ID: chunks_165
# Insert of existing embedding ID: chunks_165
# Add of existing embedding ID: chunks_166
# Insert of existing embedding ID: chunks_166
# Add of existing embedding ID: chunks_167
# Insert of existing embedding ID: chunks_167
# Add of existing embedding ID: chunks_168
# Insert of existing embedding ID: chunks_168
# Add of existing embedding ID: chunks_169
# Insert of existing embedding ID: chunks_169
# Add of existing embedding ID: chunks_170
# Insert of existing embedding ID: chunks_170
# Add of existing embedding ID: chunks_171
# Insert of existing embedding ID: chunks_171
# Add of existing embedding ID: chunks_172
# Insert of existing embedding ID: chunks_172
# Add of existing embedding ID: chunks_173
# Insert of existing embedding ID: chunks_173
# Add of existing embedding ID: chunks_174
# Insert of existing embedding ID: chunks_174
# Add of existing embedding ID: chunks_175
# Insert of existing embedding ID: chunks_175
# Add of existing embedding ID: chunks_176
# Insert of existing embedding ID: chunks_176
# Add of existing embedding ID: chunks_177
# Insert of existing embedding ID: chunks_177
# Add of existing embedding ID: chunks_178
# Insert of existing embedding ID: chunks_178
# Add of existing embedding ID: chunks_179
# Insert of existing embedding ID: chunks_179
# Add of existing embedding ID: chunks_180
# Insert of existing embedding ID: chunks_180
# Add of existing embedding ID: chunks_181
# Insert of existing embedding ID: chunks_181
# Add of existing embedding ID: chunks_182
# Insert of existing embedding ID: chunks_182
# Add of existing embedding ID: chunks_183
# Insert of existing embedding ID: chunks_183
# Add of existing embedding ID: chunks_184
# Insert of existing embedding ID: chunks_184
# Add of existing embedding ID: chunks_185
# Insert of existing embedding ID: chunks_185
# Add of existing embedding ID: chunks_186
# Insert of existing embedding ID: chunks_186
# Add of existing embedding ID: chunks_187
# Insert of existing embedding ID: chunks_187
# Add of existing embedding ID: chunks_188
# Insert of existing embedding ID: chunks_188
# Add of existing embedding ID: chunks_189
# Insert of existing embedding ID: chunks_189
# Add of existing embedding ID: chunks_190
# Insert of existing embedding ID: chunks_190
# Add of existing embedding ID: chunks_191
# Insert of existing embedding ID: chunks_191
# Add of existing embedding ID: chunks_192
# Insert of existing embedding ID: chunks_192
# Add of existing embedding ID: chunks_193
# Insert of existing embedding ID: chunks_193
# Add of existing embedding ID: chunks_194
# Insert of existing embedding ID: chunks_194
# Add of existing embedding ID: chunks_195
# Insert of existing embedding ID: chunks_195
# Add of existing embedding ID: chunks_196
# Insert of existing embedding ID: chunks_196
# Add of existing embedding ID: chunks_197
# Insert of existing embedding ID: chunks_197
# Add of existing embedding ID: chunks_198
# Insert of existing embedding ID: chunks_198
# Add of existing embedding ID: chunks_199
# Insert of existing embedding ID: chunks_199
# Add of existing embedding ID: chunks_200
# Insert of existing embedding ID: chunks_200
# Add of existing embedding ID: chunks_201
# Insert of existing embedding ID: chunks_201
# Add of existing embedding ID: chunks_202
# Insert of existing embedding ID: chunks_202
# Add of existing embedding ID: chunks_203
# Insert of existing embedding ID: chunks_203
# Add of existing embedding ID: chunks_204
# Insert of existing embedding ID: chunks_204
# Add of existing embedding ID: chunks_205
# Insert of existing embedding ID: chunks_205
# Add of existing embedding ID: chunks_206
# Insert of existing embedding ID: chunks_206
# Add of existing embedding ID: chunks_207
# Insert of existing embedding ID: chunks_207
# Add of existing embedding ID: chunks_208
# Insert of existing embedding ID: chunks_208
# Add of existing embedding ID: chunks_209
# Insert of existing embedding ID: chunks_209
# Add of existing embedding ID: chunks_210
# Insert of existing embedding ID: chunks_210
# Add of existing embedding ID: chunks_211
# Insert of existing embedding ID: chunks_211
# Add of existing embedding ID: chunks_212
# Insert of existing embedding ID: chunks_212
# Add of existing embedding ID: chunks_213
# Insert of existing embedding ID: chunks_213
# Add of existing embedding ID: chunks_214
# Insert of existing embedding ID: chunks_214
# Add of existing embedding ID: chunks_215
# Insert of existing embedding ID: chunks_215
# Add of existing embedding ID: chunks_216
# Insert of existing embedding ID: chunks_216
# Add of existing embedding ID: chunks_217
# Insert of existing embedding ID: chunks_217
# Add of existing embedding ID: chunks_218
# Insert of existing embedding ID: chunks_218
# Add of existing embedding ID: chunks_219
# Insert of existing embedding ID: chunks_219
# Add of existing embedding ID: chunks_220
# Insert of existing embedding ID: chunks_220
# Add of existing embedding ID: chunks_221
# Insert of existing embedding ID: chunks_221
# Add of existing embedding ID: chunks_222
# Insert of existing embedding ID: chunks_222
# Add of existing embedding ID: chunks_223
# Insert of existing embedding ID: chunks_223
# Add of existing embedding ID: chunks_224
# Insert of existing embedding ID: chunks_224
# Add of existing embedding ID: chunks_225
# Insert of existing embedding ID: chunks_225
# Add of existing embedding ID: chunks_226
# Insert of existing embedding ID: chunks_226
# Add of existing embedding ID: chunks_227
# Insert of existing embedding ID: chunks_227
# Add of existing embedding ID: chunks_228
# Insert of existing embedding ID: chunks_228
# Add of existing embedding ID: chunks_229
# Insert of existing embedding ID: chunks_229
# Add of existing embedding ID: chunks_230
# Insert of existing embedding ID: chunks_230
# Add of existing embedding ID: chunks_231
# Insert of existing embedding ID: chunks_231
# Add of existing embedding ID: chunks_232
# Insert of existing embedding ID: chunks_232
# Add of existing embedding ID: chunks_233
# Insert of existing embedding ID: chunks_233
# Add of existing embedding ID: chunks_234
# Insert of existing embedding ID: chunks_234
# Add of existing embedding ID: chunks_235
# Insert of existing embedding ID: chunks_235
# Add of existing embedding ID: chunks_236
# Insert of existing embedding ID: chunks_236
# Add of existing embedding ID: chunks_237
# Insert of existing embedding ID: chunks_237
# Add of existing embedding ID: chunks_238
# Insert of existing embedding ID: chunks_238
# Add of existing embedding ID: chunks_239
# Insert of existing embedding ID: chunks_239
# Add of existing embedding ID: chunks_240
# Insert of existing embedding ID: chunks_240
# Add of existing embedding ID: chunks_241
# Insert of existing embedding ID: chunks_241
# Add of existing embedding ID: chunks_242
# Insert of existing embedding ID: chunks_242
# Add of existing embedding ID: chunks_243
# Insert of existing embedding ID: chunks_243
# Add of existing embedding ID: chunks_244
# Insert of existing embedding ID: chunks_244
# Add of existing embedding ID: chunks_245
# Insert of existing embedding ID: chunks_245
# Add of existing embedding ID: chunks_246
# Insert of existing embedding ID: chunks_246
# Add of existing embedding ID: chunks_247
# Insert of existing embedding ID: chunks_247
# Add of existing embedding ID: chunks_248
# Insert of existing embedding ID: chunks_248
# Add of existing embedding ID: chunks_249
# Insert of existing embedding ID: chunks_249
# Add of existing embedding ID: chunks_250
# Insert of existing embedding ID: chunks_250
# Add of existing embedding ID: chunks_251
# Insert of existing embedding ID: chunks_251
# Add of existing embedding ID: chunks_252
# Insert of existing embedding ID: chunks_252
# Add of existing embedding ID: chunks_253
# Insert of existing embedding ID: chunks_253
# Add of existing embedding ID: chunks_254
# Insert of existing embedding ID: chunks_254
# Add of existing embedding ID: chunks_255
# Insert of existing embedding ID: chunks_255
# Add of existing embedding ID: chunks_256
# Insert of existing embedding ID: chunks_256
# Add of existing embedding ID: chunks_257
# Insert of existing embedding ID: chunks_257
# Add of existing embedding ID: chunks_258
# Insert of existing embedding ID: chunks_258
# Add of existing embedding ID: chunks_259
# Insert of existing embedding ID: chunks_259
# Add of existing embedding ID: chunks_260
# Insert of existing embedding ID: chunks_260
# Add of existing embedding ID: chunks_261
# Insert of existing embedding ID: chunks_261
# Add of existing embedding ID: chunks_262
# Insert of existing embedding ID: chunks_262
# Add of existing embedding ID: chunks_263
# Insert of existing embedding ID: chunks_263
# Add of existing embedding ID: chunks_264
# Insert of existing embedding ID: chunks_264
# Add of existing embedding ID: chunks_265
# Insert of existing embedding ID: chunks_265
# Add of existing embedding ID: chunks_266
# Insert of existing embedding ID: chunks_266
# Add of existing embedding ID: chunks_267
# Insert of existing embedding ID: chunks_267
# Add of existing embedding ID: chunks_268
# Insert of existing embedding ID: chunks_268
# Add of existing embedding ID: chunks_269
# Insert of existing embedding ID: chunks_269
# Add of existing embedding ID: chunks_270
# Insert of existing embedding ID: chunks_270
# Add of existing embedding ID: chunks_271
# Insert of existing embedding ID: chunks_271
# Add of existing embedding ID: chunks_272
# Insert of existing embedding ID: chunks_272
# Add of existing embedding ID: chunks_273
# Insert of existing embedding ID: chunks_273
# Add of existing embedding ID: chunks_274
# Insert of existing embedding ID: chunks_274
# Add of existing embedding ID: chunks_275
# Insert of existing embedding ID: chunks_275
# Add of existing embedding ID: chunks_276
# Insert of existing embedding ID: chunks_276
# Add of existing embedding ID: chunks_277
# Insert of existing embedding ID: chunks_277
# Add of existing embedding ID: chunks_278
# Insert of existing embedding ID: chunks_278
# Add of existing embedding ID: chunks_279
# Insert of existing embedding ID: chunks_279
# Add of existing embedding ID: chunks_280
# Insert of existing embedding ID: chunks_280
# Add of existing embedding ID: chunks_281
# Insert of existing embedding ID: chunks_281
# Add of existing embedding ID: chunks_282
# Insert of existing embedding ID: chunks_282
# Add of existing embedding ID: chunks_283
# Insert of existing embedding ID: chunks_283
# Add of existing embedding ID: chunks_284
# Insert of existing embedding ID: chunks_284
# Add of existing embedding ID: chunks_285
# Insert of existing embedding ID: chunks_285
# Add of existing embedding ID: chunks_286
# Insert of existing embedding ID: chunks_286
# Add of existing embedding ID: chunks_287
# Insert of existing embedding ID: chunks_287
# Add of existing embedding ID: chunks_288
# Insert of existing embedding ID: chunks_288
# Add of existing embedding ID: chunks_289
# Insert of existing embedding ID: chunks_289
# Add of existing embedding ID: chunks_290
# Insert of existing embedding ID: chunks_290
# Add of existing embedding ID: chunks_291
# Insert of existing embedding ID: chunks_291
# Add of existing embedding ID: chunks_292
# Insert of existing embedding ID: chunks_292
# Add of existing embedding ID: chunks_293
# Insert of existing embedding ID: chunks_293
# Add of existing embedding ID: chunks_294
# Insert of existing embedding ID: chunks_294
# Add of existing embedding ID: chunks_295
# Insert of existing embedding ID: chunks_295
# Add of existing embedding ID: chunks_296
# Insert of existing embedding ID: chunks_296
# Add of existing embedding ID: chunks_297
# Insert of existing embedding ID: chunks_297
# Add of existing embedding ID: chunks_298
# Insert of existing embedding ID: chunks_298
# Add of existing embedding ID: chunks_299
# Insert of existing embedding ID: chunks_299
# Add of existing embedding ID: chunks_300
# Insert of existing embedding ID: chunks_300
# Add of existing embedding ID: chunks_301
# Insert of existing embedding ID: chunks_301
# Add of existing embedding ID: chunks_302
# Insert of existing embedding ID: chunks_302
# Add of existing embedding ID: chunks_303
# Insert of existing embedding ID: chunks_303
# Add of existing embedding ID: chunks_304
# Insert of existing embedding ID: chunks_304
# Add of existing embedding ID: chunks_305
# Insert of existing embedding ID: chunks_305
# Add of existing embedding ID: chunks_306
# Insert of existing embedding ID: chunks_306
# Add of existing embedding ID: chunks_307
# Insert of existing embedding ID: chunks_307
# Add of existing embedding ID: chunks_308
# Insert of existing embedding ID: chunks_308
# Add of existing embedding ID: chunks_309
# Insert of existing embedding ID: chunks_309
# Add of existing embedding ID: chunks_310
# Insert of existing embedding ID: chunks_310
# Add of existing embedding ID: chunks_311
# Insert of existing embedding ID: chunks_311
# Add of existing embedding ID: chunks_312
# Insert of existing embedding ID: chunks_312
# Add of existing embedding ID: chunks_313
# Insert of existing embedding ID: chunks_313
# Add of existing embedding ID: chunks_314
# Insert of existing embedding ID: chunks_314
# Add of existing embedding ID: chunks_315
# Insert of existing embedding ID: chunks_315
# Add of existing embedding ID: chunks_316
# Insert of existing embedding ID: chunks_316
# Add of existing embedding ID: chunks_317
# Insert of existing embedding ID: chunks_317
# Add of existing embedding ID: chunks_318
# Insert of existing embedding ID: chunks_318
# Add of existing embedding ID: chunks_319
# Insert of existing embedding ID: chunks_319
# Add of existing embedding ID: chunks_320
# Insert of existing embedding ID: chunks_320
# Add of existing embedding ID: chunks_321
# Insert of existing embedding ID: chunks_321
# Add of existing embedding ID: chunks_322
# Insert of existing embedding ID: chunks_322
# Add of existing embedding ID: chunks_323
# Insert of existing embedding ID: chunks_323
# Add of existing embedding ID: chunks_324
# Insert of existing embedding ID: chunks_324
# Add of existing embedding ID: chunks_325
# Insert of existing embedding ID: chunks_325
# Add of existing embedding ID: chunks_326
# Insert of existing embedding ID: chunks_326
# Add of existing embedding ID: chunks_327
# Insert of existing embedding ID: chunks_327
# Add of existing embedding ID: chunks_328
# Insert of existing embedding ID: chunks_328
# Add of existing embedding ID: chunks_329
# Insert of existing embedding ID: chunks_329
# Add of existing embedding ID: chunks_330
# Insert of existing embedding ID: chunks_330
# Add of existing embedding ID: chunks_331
# Insert of existing embedding ID: chunks_331
# Add of existing embedding ID: chunks_332
# Insert of existing embedding ID: chunks_332
# Add of existing embedding ID: chunks_333
# Insert of existing embedding ID: chunks_333
# Add of existing embedding ID: chunks_334
# Insert of existing embedding ID: chunks_334
# Add of existing embedding ID: chunks_335
# Insert of existing embedding ID: chunks_335
# Add of existing embedding ID: chunks_336
# Insert of existing embedding ID: chunks_336
# Add of existing embedding ID: chunks_337
# Insert of existing embedding ID: chunks_337
# Add of existing embedding ID: chunks_338
# Insert of existing embedding ID: chunks_338
# Add of existing embedding ID: chunks_339
# Insert of existing embedding ID: chunks_339
# Add of existing embedding ID: chunks_340
# Insert of existing embedding ID: chunks_340
# Add of existing embedding ID: chunks_341
# Insert of existing embedding ID: chunks_341
# Add of existing embedding ID: chunks_342
# Insert of existing embedding ID: chunks_342
# Add of existing embedding ID: chunks_343
# Insert of existing embedding ID: chunks_343
# Add of existing embedding ID: chunks_344
# Insert of existing embedding ID: chunks_344
# Add of existing embedding ID: chunks_345
# Insert of existing embedding ID: chunks_345
# Add of existing embedding ID: chunks_346
# Insert of existing embedding ID: chunks_346
# Add of existing embedding ID: chunks_347
# Insert of existing embedding ID: chunks_347
# Add of existing embedding ID: chunks_348
# Insert of existing embedding ID: chunks_348
# Add of existing embedding ID: chunks_349
# Insert of existing embedding ID: chunks_349
# Add of existing embedding ID: chunks_350
# Insert of existing embedding ID: chunks_350
# Add of existing embedding ID: chunks_351
# Insert of existing embedding ID: chunks_351
# Add of existing embedding ID: chunks_352
# Insert of existing embedding ID: chunks_352
# Add of existing embedding ID: chunks_353
# Insert of existing embedding ID: chunks_353
# Add of existing embedding ID: chunks_354
# Insert of existing embedding ID: chunks_354
# Add of existing embedding ID: chunks_355
# Insert of existing embedding ID: chunks_355
# Add of existing embedding ID: chunks_356
# Insert of existing embedding ID: chunks_356
# Add of existing embedding ID: chunks_357
# Insert of existing embedding ID: chunks_357
# Add of existing embedding ID: chunks_358
# Insert of existing embedding ID: chunks_358
# Add of existing embedding ID: chunks_359
# Insert of existing embedding ID: chunks_359
# Add of existing embedding ID: chunks_360
# Insert of existing embedding ID: chunks_360
# Add of existing embedding ID: chunks_361
# Insert of existing embedding ID: chunks_361
# Add of existing embedding ID: chunks_362
# Insert of existing embedding ID: chunks_362
# Add of existing embedding ID: chunks_363
# Insert of existing embedding ID: chunks_363
# Add of existing embedding ID: chunks_364
# Insert of existing embedding ID: chunks_364
# Add of existing embedding ID: chunks_365
# Insert of existing embedding ID: chunks_365
# Add of existing embedding ID: chunks_366
# Insert of existing embedding ID: chunks_366
# Add of existing embedding ID: chunks_367
# Insert of existing embedding ID: chunks_367
# Add of existing embedding ID: chunks_368
# Insert of existing embedding ID: chunks_368
# Add of existing embedding ID: chunks_369
# Insert of existing embedding ID: chunks_369
# Add of existing embedding ID: chunks_370
# Insert of existing embedding ID: chunks_370
# Add of existing embedding ID: chunks_371
# Insert of existing embedding ID: chunks_371
# Add of existing embedding ID: chunks_372
# Insert of existing embedding ID: chunks_372
# Add of existing embedding ID: chunks_373
# Insert of existing embedding ID: chunks_373
# Add of existing embedding ID: chunks_374
# Insert of existing embedding ID: chunks_374
# Add of existing embedding ID: chunks_375
# Insert of existing embedding ID: chunks_375
# Add of existing embedding ID: chunks_376
# Insert of existing embedding ID: chunks_376
# Add of existing embedding ID: chunks_377
# Insert of existing embedding ID: chunks_377
# Add of existing embedding ID: chunks_378
# Insert of existing embedding ID: chunks_378
# Add of existing embedding ID: chunks_379
# Insert of existing embedding ID: chunks_379
# Add of existing embedding ID: chunks_380
# Insert of existing embedding ID: chunks_380
# Add of existing embedding ID: chunks_381
# Insert of existing embedding ID: chunks_381
# Add of existing embedding ID: chunks_382
# Insert of existing embedding ID: chunks_382
# Add of existing embedding ID: chunks_383
# Insert of existing embedding ID: chunks_383
# Add of existing embedding ID: chunks_384
# Insert of existing embedding ID: chunks_384
# Add of existing embedding ID: chunks_385
# Insert of existing embedding ID: chunks_385
# Add of existing embedding ID: chunks_386
# Insert of existing embedding ID: chunks_386
# Add of existing embedding ID: chunks_387
# Insert of existing embedding ID: chunks_387
# Add of existing embedding ID: chunks_388
# Insert of existing embedding ID: chunks_388
# Add of existing embedding ID: chunks_389
# Insert of existing embedding ID: chunks_389
# Add of existing embedding ID: chunks_390
# Insert of existing embedding ID: chunks_390
# Add of existing embedding ID: chunks_391
# Insert of existing embedding ID: chunks_391
# Add of existing embedding ID: chunks_392
# Insert of existing embedding ID: chunks_392
# Add of existing embedding ID: chunks_393
# Insert of existing embedding ID: chunks_393
# Add of existing embedding ID: chunks_394
# Insert of existing embedding ID: chunks_394
# Add of existing embedding ID: chunks_395
# Insert of existing embedding ID: chunks_395
# Add of existing embedding ID: chunks_396
# Insert of existing embedding ID: chunks_396
# Add of existing embedding ID: chunks_397
# Insert of existing embedding ID: chunks_397
# Add of existing embedding ID: chunks_398
# Insert of existing embedding ID: chunks_398
# Add of existing embedding ID: chunks_399
# Insert of existing embedding ID: chunks_399
# Add of existing embedding ID: chunks_400
# Insert of existing embedding ID: chunks_400
# Add of existing embedding ID: chunks_401
# Insert of existing embedding ID: chunks_401
# Add of existing embedding ID: chunks_402
# Insert of existing embedding ID: chunks_402
# Add of existing embedding ID: chunks_403
# Insert of existing embedding ID: chunks_403
# Add of existing embedding ID: chunks_404
# Insert of existing embedding ID: chunks_404
# Add of existing embedding ID: chunks_405
# Insert of existing embedding ID: chunks_405
# Add of existing embedding ID: chunks_406
# Insert of existing embedding ID: chunks_406
# Add of existing embedding ID: chunks_407
# Insert of existing embedding ID: chunks_407
# Add of existing embedding ID: chunks_408
# Insert of existing embedding ID: chunks_408
# Add of existing embedding ID: chunks_409
# Insert of existing embedding ID: chunks_409
# Add of existing embedding ID: chunks_410
# Insert of existing embedding ID: chunks_410
# Add of existing embedding ID: chunks_411
# Insert of existing embedding ID: chunks_411
# Add of existing embedding ID: chunks_412
# Insert of existing embedding ID: chunks_412
# Add of existing embedding ID: chunks_413
# Insert of existing embedding ID: chunks_413
# Add of existing embedding ID: chunks_414
# Insert of existing embedding ID: chunks_414
# Add of existing embedding ID: chunks_415
# Insert of existing embedding ID: chunks_415
# Add of existing embedding ID: chunks_416
# Insert of existing embedding ID: chunks_416
# Add of existing embedding ID: chunks_417
# Insert of existing embedding ID: chunks_417
# Add of existing embedding ID: chunks_418
# Insert of existing embedding ID: chunks_418
# Add of existing embedding ID: chunks_419
# Insert of existing embedding ID: chunks_419
# Add of existing embedding ID: chunks_420
# Insert of existing embedding ID: chunks_420
# Add of existing embedding ID: chunks_421
# Insert of existing embedding ID: chunks_421
# Add of existing embedding ID: chunks_422
# Insert of existing embedding ID: chunks_422
# Add of existing embedding ID: chunks_423
# Insert of existing embedding ID: chunks_423
# Add of existing embedding ID: chunks_424
# Insert of existing embedding ID: chunks_424
# Add of existing embedding ID: chunks_425
# Insert of existing embedding ID: chunks_425
# Add of existing embedding ID: chunks_426
# Insert of existing embedding ID: chunks_426
# Add of existing embedding ID: chunks_427
# Insert of existing embedding ID: chunks_427
# Add of existing embedding ID: chunks_428
# Insert of existing embedding ID: chunks_428
# Add of existing embedding ID: chunks_429
# Insert of existing embedding ID: chunks_429
# Add of existing embedding ID: chunks_430
# Insert of existing embedding ID: chunks_430
# Add of existing embedding ID: chunks_431
# Insert of existing embedding ID: chunks_431
# Add of existing embedding ID: chunks_432
# Insert of existing embedding ID: chunks_432
# Add of existing embedding ID: chunks_433
# Insert of existing embedding ID: chunks_433
# Add of existing embedding ID: chunks_434
# Insert of existing embedding ID: chunks_434
# Add of existing embedding ID: chunks_435
# Insert of existing embedding ID: chunks_435
# Add of existing embedding ID: chunks_436
# Insert of existing embedding ID: chunks_436
# Add of existing embedding ID: chunks_437
# Insert of existing embedding ID: chunks_437
# Add of existing embedding ID: chunks_438
# Insert of existing embedding ID: chunks_438
# Add of existing embedding ID: chunks_439
# Insert of existing embedding ID: chunks_439
# Add of existing embedding ID: chunks_440
# Insert of existing embedding ID: chunks_440
# Add of existing embedding ID: chunks_441
# Insert of existing embedding ID: chunks_441
# Add of existing embedding ID: chunks_442
# Insert of existing embedding ID: chunks_442
# Add of existing embedding ID: chunks_443
# Insert of existing embedding ID: chunks_443
# Add of existing embedding ID: chunks_444
# Insert of existing embedding ID: chunks_444
# Add of existing embedding ID: chunks_445
# Insert of existing embedding ID: chunks_445
# Add of existing embedding ID: chunks_446
# Insert of existing embedding ID: chunks_446
# Add of existing embedding ID: chunks_447
# Insert of existing embedding ID: chunks_447
# Add of existing embedding ID: chunks_448
# Insert of existing embedding ID: chunks_448
# Add of existing embedding ID: chunks_449
# Insert of existing embedding ID: chunks_449
# Add of existing embedding ID: chunks_450
# Insert of existing embedding ID: chunks_450
# Add of existing embedding ID: chunks_451
# Insert of existing embedding ID: chunks_451
# Add of existing embedding ID: chunks_452
# Insert of existing embedding ID: chunks_452
# Add of existing embedding ID: chunks_453
# Insert of existing embedding ID: chunks_453
# Add of existing embedding ID: chunks_454
# Insert of existing embedding ID: chunks_454
# Add of existing embedding ID: chunks_455
# Insert of existing embedding ID: chunks_455
# Add of existing embedding ID: chunks_456
# Insert of existing embedding ID: chunks_456
# Add of existing embedding ID: chunks_457
# Insert of existing embedding ID: chunks_457
# Add of existing embedding ID: chunks_458
# Insert of existing embedding ID: chunks_458
# Add of existing embedding ID: chunks_459
# Insert of existing embedding ID: chunks_459
# Add of existing embedding ID: chunks_460
# Insert of existing embedding ID: chunks_460
# Add of existing embedding ID: chunks_461
# Insert of existing embedding ID: chunks_461
# Add of existing embedding ID: chunks_462
# Insert of existing embedding ID: chunks_462
# Add of existing embedding ID: chunks_463
# Insert of existing embedding ID: chunks_463
# Add of existing embedding ID: chunks_464
# Insert of existing embedding ID: chunks_464
# Add of existing embedding ID: chunks_465
# Insert of existing embedding ID: chunks_465
# Add of existing embedding ID: chunks_466
# Insert of existing embedding ID: chunks_466
# Add of existing embedding ID: chunks_467
# Insert of existing embedding ID: chunks_467
# Add of existing embedding ID: chunks_468
# Insert of existing embedding ID: chunks_468
# Add of existing embedding ID: chunks_469
# Insert of existing embedding ID: chunks_469
# Add of existing embedding ID: chunks_470
# Insert of existing embedding ID: chunks_470
# Add of existing embedding ID: chunks_471
# Insert of existing embedding ID: chunks_471
# Add of existing embedding ID: chunks_472
# Insert of existing embedding ID: chunks_472
# Add of existing embedding ID: chunks_473
# Insert of existing embedding ID: chunks_473
# Add of existing embedding ID: chunks_474
# Insert of existing embedding ID: chunks_474
# Add of existing embedding ID: chunks_475
# Insert of existing embedding ID: chunks_475
# Add of existing embedding ID: chunks_476
# Insert of existing embedding ID: chunks_476
# Add of existing embedding ID: chunks_477
# Insert of existing embedding ID: chunks_477
# Add of existing embedding ID: chunks_478
# Insert of existing embedding ID: chunks_478
# Add of existing embedding ID: chunks_479
# Insert of existing embedding ID: chunks_479
# Add of existing embedding ID: chunks_480
# Insert of existing embedding ID: chunks_480
# Add of existing embedding ID: chunks_481
# Insert of existing embedding ID: chunks_481
# Add of existing embedding ID: chunks_482
# Insert of existing embedding ID: chunks_482
# Add of existing embedding ID: chunks_483
# Insert of existing embedding ID: chunks_483
# Add of existing embedding ID: chunks_484
# Insert of existing embedding ID: chunks_484
# Add of existing embedding ID: chunks_485
# Insert of existing embedding ID: chunks_485
# Add of existing embedding ID: chunks_486
# Insert of existing embedding ID: chunks_486
# Add of existing embedding ID: chunks_487
# Insert of existing embedding ID: chunks_487
# Add of existing embedding ID: chunks_488
# Insert of existing embedding ID: chunks_488
# Add of existing embedding ID: chunks_489
# Insert of existing embedding ID: chunks_489
# Add of existing embedding ID: chunks_490
# Insert of existing embedding ID: chunks_490
# Add of existing embedding ID: chunks_491
# Insert of existing embedding ID: chunks_491
# Add of existing embedding ID: chunks_492
# Insert of existing embedding ID: chunks_492
# Add of existing embedding ID: chunks_493
# Insert of existing embedding ID: chunks_493
# Add of existing embedding ID: chunks_494
# Insert of existing embedding ID: chunks_494
# Add of existing embedding ID: chunks_495
# Insert of existing embedding ID: chunks_495
# Add of existing embedding ID: chunks_496
# Insert of existing embedding ID: chunks_496
# Add of existing embedding ID: chunks_497
# Insert of existing embedding ID: chunks_497
# Add of existing embedding ID: chunks_498
# Insert of existing embedding ID: chunks_498
# Add of existing embedding ID: chunks_499
# Insert of existing embedding ID: chunks_499
# Add of existing embedding ID: chunks_500
# Insert of existing embedding ID: chunks_500
# Add of existing embedding ID: chunks_501
# Insert of existing embedding ID: chunks_501
# Add of existing embedding ID: chunks_502
# Insert of existing embedding ID: chunks_502
# Add of existing embedding ID: chunks_503
# Insert of existing embedding ID: chunks_503
# Add of existing embedding ID: chunks_504
# Insert of existing embedding ID: chunks_504
# Add of existing embedding ID: chunks_505
# Insert of existing embedding ID: chunks_505
# Add of existing embedding ID: chunks_506
# Insert of existing embedding ID: chunks_506
# Add of existing embedding ID: chunks_507
# Insert of existing embedding ID: chunks_507
# Add of existing embedding ID: chunks_508
# Insert of existing embedding ID: chunks_508
# Add of existing embedding ID: chunks_509
# Insert of existing embedding ID: chunks_509
# Add of existing embedding ID: chunks_510
# Insert of existing embedding ID: chunks_510
# Add of existing embedding ID: chunks_511
# Insert of existing embedding ID: chunks_511
# Add of existing embedding ID: chunks_512
# Insert of existing embedding ID: chunks_512
# Add of existing embedding ID: chunks_513
# Insert of existing embedding ID: chunks_513
# Add of existing embedding ID: chunks_514
# Insert of existing embedding ID: chunks_514
# Add of existing embedding ID: chunks_515
# Insert of existing embedding ID: chunks_515
# Add of existing embedding ID: chunks_516
# Insert of existing embedding ID: chunks_516
# Add of existing embedding ID: chunks_517
# Insert of existing embedding ID: chunks_517
# Add of existing embedding ID: chunks_518
# Insert of existing embedding ID: chunks_518
# Add of existing embedding ID: chunks_519
# Insert of existing embedding ID: chunks_519
# Add of existing embedding ID: chunks_520
# Insert of existing embedding ID: chunks_520
# Add of existing embedding ID: chunks_521
# Insert of existing embedding ID: chunks_521
# Add of existing embedding ID: chunks_522
# Insert of existing embedding ID: chunks_522
# Add of existing embedding ID: chunks_523
# Insert of existing embedding ID: chunks_523
# Add of existing embedding ID: chunks_524
# Insert of existing embedding ID: chunks_524
# Add of existing embedding ID: chunks_525
# Insert of existing embedding ID: chunks_525
# Add of existing embedding ID: chunks_526
# Insert of existing embedding ID: chunks_526
# Add of existing embedding ID: chunks_527
# Insert of existing embedding ID: chunks_527
# Add of existing embedding ID: chunks_528
# Insert of existing embedding ID: chunks_528
# Add of existing embedding ID: chunks_529
# Insert of existing embedding ID: chunks_529
# Add of existing embedding ID: chunks_530
# Insert of existing embedding ID: chunks_530
# Add of existing embedding ID: chunks_531
# Insert of existing embedding ID: chunks_531
# Add of existing embedding ID: chunks_532
# Insert of existing embedding ID: chunks_532
# Add of existing embedding ID: chunks_533
# Insert of existing embedding ID: chunks_533
# Add of existing embedding ID: chunks_534
# Insert of existing embedding ID: chunks_534
# Add of existing embedding ID: chunks_535
# Insert of existing embedding ID: chunks_535
# Add of existing embedding ID: chunks_536
# Insert of existing embedding ID: chunks_536
# Add of existing embedding ID: chunks_537
# Insert of existing embedding ID: chunks_537
# Add of existing embedding ID: chunks_538
# Insert of existing embedding ID: chunks_538
# Add of existing embedding ID: chunks_539
# Insert of existing embedding ID: chunks_539
# Add of existing embedding ID: chunks_540
# Insert of existing embedding ID: chunks_540
# Add of existing embedding ID: chunks_541
# Insert of existing embedding ID: chunks_541
# Add of existing embedding ID: chunks_542
# Insert of existing embedding ID: chunks_542
# Add of existing embedding ID: chunks_543
# Insert of existing embedding ID: chunks_543
# Add of existing embedding ID: chunks_544
# Insert of existing embedding ID: chunks_544
# Add of existing embedding ID: chunks_545
# Insert of existing embedding ID: chunks_545
# Add of existing embedding ID: chunks_546
# Insert of existing embedding ID: chunks_546
# Add of existing embedding ID: chunks_547
# Insert of existing embedding ID: chunks_547
# Add of existing embedding ID: chunks_548
# Insert of existing embedding ID: chunks_548
# Add of existing embedding ID: chunks_549
# Insert of existing embedding ID: chunks_549
# Add of existing embedding ID: chunks_550
# Insert of existing embedding ID: chunks_550
# Add of existing embedding ID: chunks_551
# Insert of existing embedding ID: chunks_551
# Add of existing embedding ID: chunks_552
# Insert of existing embedding ID: chunks_552
# Add of existing embedding ID: chunks_553
# Insert of existing embedding ID: chunks_553
# Add of existing embedding ID: chunks_554
# Insert of existing embedding ID: chunks_554
# Add of existing embedding ID: chunks_555
# Insert of existing embedding ID: chunks_555
# Add of existing embedding ID: chunks_556
# Insert of existing embedding ID: chunks_556
# Add of existing embedding ID: chunks_557
# Insert of existing embedding ID: chunks_557
# Add of existing embedding ID: chunks_558
# Insert of existing embedding ID: chunks_558
# Add of existing embedding ID: chunks_559
# Insert of existing embedding ID: chunks_559
# Add of existing embedding ID: chunks_560
# Insert of existing embedding ID: chunks_560
# Add of existing embedding ID: chunks_561
# Insert of existing embedding ID: chunks_561
# Add of existing embedding ID: chunks_562
# Insert of existing embedding ID: chunks_562
# Add of existing embedding ID: chunks_563
# Insert of existing embedding ID: chunks_563
# Add of existing embedding ID: chunks_564
# Insert of existing embedding ID: chunks_564
# Add of existing embedding ID: chunks_565
# Insert of existing embedding ID: chunks_565
# Add of existing embedding ID: chunks_566
# Insert of existing embedding ID: chunks_566
# ...
# Insert of existing embedding ID: chunks_7816
# Add of existing embedding ID: chunks_7817
# Insert of existing embedding ID: chunks_7817
# Add of existing embedding ID: chunks_7818
# Insert of existing embedding ID: chunks_7818
# Add of existing embedding ID: chunks_7819
# Insert of existing embedding ID: chunks_7819
# Add of existing embedding ID: chunks_7820
# Insert of existing embedding ID: chunks_7820
# Add of existing embedding ID: chunks_7821
# Insert of existing embedding ID: chunks_7821
# Add of existing embedding ID: chunks_7822
# Insert of existing embedding ID: chunks_7822
# Add of existing embedding ID: chunks_7823
# Insert of existing embedding ID: chunks_7823
# Add of existing embedding ID: chunks_7824
# Insert of existing embedding ID: chunks_7824
# Add of existing embedding ID: chunks_7825
# Insert of existing embedding ID: chunks_7825
# Add of existing embedding ID: chunks_7826
# Insert of existing embedding ID: chunks_7826
# Add of existing embedding ID: chunks_7827
# Insert of existing embedding ID: chunks_7827
# Add of existing embedding ID: chunks_7828
# Insert of existing embedding ID: chunks_7828
# Add of existing embedding ID: chunks_7829
# Insert of existing embedding ID: chunks_7829
# Add of existing embedding ID: chunks_7830
# Insert of existing embedding ID: chunks_7830
# Add of existing embedding ID: chunks_7831
# Insert of existing embedding ID: chunks_7831
# Add of existing embedding ID: chunks_7832
# Insert of existing embedding ID: chunks_7832
# Add of existing embedding ID: chunks_7833
# Insert of existing embedding ID: chunks_7833
# Add of existing embedding ID: chunks_7834
# Insert of existing embedding ID: chunks_7834
# Add of existing embedding ID: chunks_7835
# Insert of existing embedding ID: chunks_7835
# Add of existing embedding ID: chunks_7836
# Insert of existing embedding ID: chunks_7836
# Add of existing embedding ID: chunks_7837
# Insert of existing embedding ID: chunks_7837
# Add of existing embedding ID: chunks_7838
# Insert of existing embedding ID: chunks_7838
# Add of existing embedding ID: chunks_7839
# Insert of existing embedding ID: chunks_7839
# Add of existing embedding ID: chunks_7840
# Insert of existing embedding ID: chunks_7840
# Add of existing embedding ID: chunks_7841
# Insert of existing embedding ID: chunks_7841
# Add of existing embedding ID: chunks_7842
# Insert of existing embedding ID: chunks_7842
# Add of existing embedding ID: chunks_7843
# Insert of existing embedding ID: chunks_7843
# Add of existing embedding ID: chunks_7844
# Insert of existing embedding ID: chunks_7844
# Add of existing embedding ID: chunks_7845
# Insert of existing embedding ID: chunks_7845
# Add of existing embedding ID: chunks_7846
# Insert of existing embedding ID: chunks_7846
# Add of existing embedding ID: chunks_7847
# Insert of existing embedding ID: chunks_7847
# Add of existing embedding ID: chunks_7848
# Insert of existing embedding ID: chunks_7848
# Add of existing embedding ID: chunks_7849
# Insert of existing embedding ID: chunks_7849
# Add of existing embedding ID: chunks_7850
# Insert of existing embedding ID: chunks_7850
# Add of existing embedding ID: chunks_7851
# Insert of existing embedding ID: chunks_7851
# Add of existing embedding ID: chunks_7852
# Insert of existing embedding ID: chunks_7852
# Add of existing embedding ID: chunks_7853
# Insert of existing embedding ID: chunks_7853
# Add of existing embedding ID: chunks_7854
# Insert of existing embedding ID: chunks_7854
# Add of existing embedding ID: chunks_7855
# Insert of existing embedding ID: chunks_7855
# Add of existing embedding ID: chunks_7856
# Insert of existing embedding ID: chunks_7856
# Add of existing embedding ID: chunks_7857
# Insert of existing embedding ID: chunks_7857
# Add of existing embedding ID: chunks_7858
# Insert of existing embedding ID: chunks_7858
# Add of existing embedding ID: chunks_7859
# Insert of existing embedding ID: chunks_7859
# Add of existing embedding ID: chunks_7860
# Insert of existing embedding ID: chunks_7860
# Add of existing embedding ID: chunks_7861
# Insert of existing embedding ID: chunks_7861
# Add of existing embedding ID: chunks_7862
# Insert of existing embedding ID: chunks_7862
# Add of existing embedding ID: chunks_7863
# Insert of existing embedding ID: chunks_7863
# Add of existing embedding ID: chunks_7864
# Insert of existing embedding ID: chunks_7864
# Add of existing embedding ID: chunks_7865
# Insert of existing embedding ID: chunks_7865
# Add of existing embedding ID: chunks_7866
# Insert of existing embedding ID: chunks_7866
# Add of existing embedding ID: chunks_7867
# Insert of existing embedding ID: chunks_7867
# Add of existing embedding ID: chunks_7868
# Insert of existing embedding ID: chunks_7868
# Add of existing embedding ID: chunks_7869
# Insert of existing embedding ID: chunks_7869
# Add of existing embedding ID: chunks_7870
# Insert of existing embedding ID: chunks_7870
# Add of existing embedding ID: chunks_7871
# Insert of existing embedding ID: chunks_7871
# Add of existing embedding ID: chunks_7872
# Insert of existing embedding ID: chunks_7872
# Add of existing embedding ID: chunks_7873
# Insert of existing embedding ID: chunks_7873
# Add of existing embedding ID: chunks_7874
# Insert of existing embedding ID: chunks_7874
# Add of existing embedding ID: chunks_7875
# Insert of existing embedding ID: chunks_7875
# Add of existing embedding ID: chunks_7876
# Insert of existing embedding ID: chunks_7876
# Add of existing embedding ID: chunks_7877
# Insert of existing embedding ID: chunks_7877
# Add of existing embedding ID: chunks_7878
# Insert of existing embedding ID: chunks_7878
# Add of existing embedding ID: chunks_7879
# Insert of existing embedding ID: chunks_7879
# Add of existing embedding ID: chunks_7880
# Insert of existing embedding ID: chunks_7880
# Add of existing embedding ID: chunks_7881
# Insert of existing embedding ID: chunks_7881
# Add of existing embedding ID: chunks_7882
# Insert of existing embedding ID: chunks_7882
# Add of existing embedding ID: chunks_7883
# Insert of existing embedding ID: chunks_7883
# Add of existing embedding ID: chunks_7884
# Insert of existing embedding ID: chunks_7884
# Add of existing embedding ID: chunks_7885
# Insert of existing embedding ID: chunks_7885
# Add of existing embedding ID: chunks_7886
# Insert of existing embedding ID: chunks_7886
# Add of existing embedding ID: chunks_7887
# Insert of existing embedding ID: chunks_7887
# Add of existing embedding ID: chunks_7888
# Insert of existing embedding ID: chunks_7888
# Add of existing embedding ID: chunks_7889
# Insert of existing embedding ID: chunks_7889
# Add of existing embedding ID: chunks_7890
# Insert of existing embedding ID: chunks_7890
# Add of existing embedding ID: chunks_7891
# Insert of existing embedding ID: chunks_7891
# Add of existing embedding ID: chunks_7892
# Insert of existing embedding ID: chunks_7892
# Add of existing embedding ID: chunks_7893
# Insert of existing embedding ID: chunks_7893
# Add of existing embedding ID: chunks_7894
# Insert of existing embedding ID: chunks_7894
# Add of existing embedding ID: chunks_7895
# Insert of existing embedding ID: chunks_7895
# Add of existing embedding ID: chunks_7896
# Insert of existing embedding ID: chunks_7896
# Add of existing embedding ID: chunks_7897
# Insert of existing embedding ID: chunks_7897
# Add of existing embedding ID: chunks_7898
# Insert of existing embedding ID: chunks_7898
# Add of existing embedding ID: chunks_7899
# Insert of existing embedding ID: chunks_7899
# Add of existing embedding ID: chunks_7900
# Insert of existing embedding ID: chunks_7900
# Add of existing embedding ID: chunks_7901
# Insert of existing embedding ID: chunks_7901
# Add of existing embedding ID: chunks_7902
# Insert of existing embedding ID: chunks_7902
# Add of existing embedding ID: chunks_7903
# Insert of existing embedding ID: chunks_7903
# Add of existing embedding ID: chunks_7904
# Insert of existing embedding ID: chunks_7904
# Add of existing embedding ID: chunks_7905
# Insert of existing embedding ID: chunks_7905
# Add of existing embedding ID: chunks_7906
# Insert of existing embedding ID: chunks_7906
# Add of existing embedding ID: chunks_7907
# Insert of existing embedding ID: chunks_7907
# Add of existing embedding ID: chunks_7908
# Insert of existing embedding ID: chunks_7908
# Add of existing embedding ID: chunks_7909
# Insert of existing embedding ID: chunks_7909
# Add of existing embedding ID: chunks_7910
# Insert of existing embedding ID: chunks_7910
# Add of existing embedding ID: chunks_7911
# Insert of existing embedding ID: chunks_7911
# Add of existing embedding ID: chunks_7912
# Insert of existing embedding ID: chunks_7912
# Add of existing embedding ID: chunks_7913
# Insert of existing embedding ID: chunks_7913
# Add of existing embedding ID: chunks_7914
# Insert of existing embedding ID: chunks_7914
# Add of existing embedding ID: chunks_7915
# Insert of existing embedding ID: chunks_7915
# Add of existing embedding ID: chunks_7916
# Insert of existing embedding ID: chunks_7916
# Add of existing embedding ID: chunks_7917
# Insert of existing embedding ID: chunks_7917
# Add of existing embedding ID: chunks_7918
# Insert of existing embedding ID: chunks_7918
# Add of existing embedding ID: chunks_7919
# Insert of existing embedding ID: chunks_7919
# Add of existing embedding ID: chunks_7920
# Insert of existing embedding ID: chunks_7920
# Add of existing embedding ID: chunks_7921
# Insert of existing embedding ID: chunks_7921
# Add of existing embedding ID: chunks_7922
# Insert of existing embedding ID: chunks_7922
# Add of existing embedding ID: chunks_7923
# Insert of existing embedding ID: chunks_7923
# Add of existing embedding ID: chunks_7924
# Insert of existing embedding ID: chunks_7924
# Add of existing embedding ID: chunks_7925
# Insert of existing embedding ID: chunks_7925
# Add of existing embedding ID: chunks_7926
# Insert of existing embedding ID: chunks_7926
# Add of existing embedding ID: chunks_7927
# Insert of existing embedding ID: chunks_7927
# Add of existing embedding ID: chunks_7928
# Insert of existing embedding ID: chunks_7928
# Add of existing embedding ID: chunks_7929
# Insert of existing embedding ID: chunks_7929
# Add of existing embedding ID: chunks_7930
# Insert of existing embedding ID: chunks_7930
# Add of existing embedding ID: chunks_7931
# Insert of existing embedding ID: chunks_7931
# Add of existing embedding ID: chunks_7932
# Insert of existing embedding ID: chunks_7932
# Add of existing embedding ID: chunks_7933
# Insert of existing embedding ID: chunks_7933
# Add of existing embedding ID: chunks_7934
# Insert of existing embedding ID: chunks_7934
# Add of existing embedding ID: chunks_7935
# Insert of existing embedding ID: chunks_7935
# Add of existing embedding ID: chunks_7936
# Insert of existing embedding ID: chunks_7936
# Add of existing embedding ID: chunks_7937
# Insert of existing embedding ID: chunks_7937
# Add of existing embedding ID: chunks_7938
# Insert of existing embedding ID: chunks_7938
# Add of existing embedding ID: chunks_7939
# Insert of existing embedding ID: chunks_7939
# Add of existing embedding ID: chunks_7940
# Insert of existing embedding ID: chunks_7940
# Add of existing embedding ID: chunks_7941
# Insert of existing embedding ID: chunks_7941
# Add of existing embedding ID: chunks_7942
# Insert of existing embedding ID: chunks_7942
# Add of existing embedding ID: chunks_7943
# Insert of existing embedding ID: chunks_7943
# Add of existing embedding ID: chunks_7944
# Insert of existing embedding ID: chunks_7944
# Add of existing embedding ID: chunks_7945
# Insert of existing embedding ID: chunks_7945
# Add of existing embedding ID: chunks_7946
# Insert of existing embedding ID: chunks_7946
# Add of existing embedding ID: chunks_7947
# Insert of existing embedding ID: chunks_7947
# Add of existing embedding ID: chunks_7948
# Insert of existing embedding ID: chunks_7948
# Add of existing embedding ID: chunks_7949
# Insert of existing embedding ID: chunks_7949
# Add of existing embedding ID: chunks_7950
# Insert of existing embedding ID: chunks_7950
# Add of existing embedding ID: chunks_7951
# Insert of existing embedding ID: chunks_7951
# Add of existing embedding ID: chunks_7952
# Insert of existing embedding ID: chunks_7952
# Add of existing embedding ID: chunks_7953
# Insert of existing embedding ID: chunks_7953
# Add of existing embedding ID: chunks_7954
# Insert of existing embedding ID: chunks_7954
# Add of existing embedding ID: chunks_7955
# Insert of existing embedding ID: chunks_7955
# Add of existing embedding ID: chunks_7956
# Insert of existing embedding ID: chunks_7956
# Add of existing embedding ID: chunks_7957
# Insert of existing embedding ID: chunks_7957
# Add of existing embedding ID: chunks_7958
# Insert of existing embedding ID: chunks_7958
# Add of existing embedding ID: chunks_7959
# Insert of existing embedding ID: chunks_7959
# Add of existing embedding ID: chunks_7960
# Insert of existing embedding ID: chunks_7960
# Add of existing embedding ID: chunks_7961
# Insert of existing embedding ID: chunks_7961
# Add of existing embedding ID: chunks_7962
# Insert of existing embedding ID: chunks_7962
# Add of existing embedding ID: chunks_7963
# Insert of existing embedding ID: chunks_7963
# Add of existing embedding ID: chunks_7964
# Insert of existing embedding ID: chunks_7964
# Add of existing embedding ID: chunks_7965
# Insert of existing embedding ID: chunks_7965
# Add of existing embedding ID: chunks_7966
# Insert of existing embedding ID: chunks_7966
# Add of existing embedding ID: chunks_7967
# Insert of existing embedding ID: chunks_7967
# Add of existing embedding ID: chunks_7968
# Insert of existing embedding ID: chunks_7968
# Add of existing embedding ID: chunks_7969
# Insert of existing embedding ID: chunks_7969
# Add of existing embedding ID: chunks_7970
# Insert of existing embedding ID: chunks_7970
# Add of existing embedding ID: chunks_7971
# Insert of existing embedding ID: chunks_7971
# Add of existing embedding ID: chunks_7972
# Insert of existing embedding ID: chunks_7972
# Add of existing embedding ID: chunks_7973
# Insert of existing embedding ID: chunks_7973
# Add of existing embedding ID: chunks_7974
# Insert of existing embedding ID: chunks_7974
# Add of existing embedding ID: chunks_7975
# Insert of existing embedding ID: chunks_7975
# Add of existing embedding ID: chunks_7976
# Insert of existing embedding ID: chunks_7976
# Add of existing embedding ID: chunks_7977
# Insert of existing embedding ID: chunks_7977
# Add of existing embedding ID: chunks_7978
# Insert of existing embedding ID: chunks_7978
# Add of existing embedding ID: chunks_7979
# Insert of existing embedding ID: chunks_7979
# Add of existing embedding ID: chunks_7980
# Insert of existing embedding ID: chunks_7980
# Add of existing embedding ID: chunks_7981
# Insert of existing embedding ID: chunks_7981
# Add of existing embedding ID: chunks_7982
# Insert of existing embedding ID: chunks_7982
# Add of existing embedding ID: chunks_7983
# Insert of existing embedding ID: chunks_7983
# Add of existing embedding ID: chunks_7984
# Insert of existing embedding ID: chunks_7984
# Add of existing embedding ID: chunks_7985
# Insert of existing embedding ID: chunks_7985
# Add of existing embedding ID: chunks_7986
# Insert of existing embedding ID: chunks_7986
# Add of existing embedding ID: chunks_7987
# Insert of existing embedding ID: chunks_7987
# Add of existing embedding ID: chunks_7988
# Insert of existing embedding ID: chunks_7988
# Add of existing embedding ID: chunks_7989
# Insert of existing embedding ID: chunks_7989
# Add of existing embedding ID: chunks_7990
# Insert of existing embedding ID: chunks_7990
# Add of existing embedding ID: chunks_7991
# Insert of existing embedding ID: chunks_7991
# Add of existing embedding ID: chunks_7992
# Insert of existing embedding ID: chunks_7992
# Add of existing embedding ID: chunks_7993
# Insert of existing embedding ID: chunks_7993
# Add of existing embedding ID: chunks_7994
# Insert of existing embedding ID: chunks_7994
# Add of existing embedding ID: chunks_7995
# Insert of existing embedding ID: chunks_7995
# Add of existing embedding ID: chunks_7996
# Insert of existing embedding ID: chunks_7996
# Add of existing embedding ID: chunks_7997
# Insert of existing embedding ID: chunks_7997
# Add of existing embedding ID: chunks_7998
# Insert of existing embedding ID: chunks_7998
# Add of existing embedding ID: chunks_7999
# Insert of existing embedding ID: chunks_7999

# %%
collection.get(include=["documents"])
# Out:
# {'ids': ['chunk_0',
#   'chunk_1',
#   'chunk_10',
#   'chunk_100',
#   'chunk_1000',
#   'chunk_1001',
#   'chunk_1002',
#   'chunk_1003',
#   'chunk_1004',
#   'chunk_1005',
#   'chunk_1006',
#   'chunk_1007',
#   'chunk_1008',
#   'chunk_1009',
#   'chunk_101',
#   'chunk_1010',
#   'chunk_1011',
#   'chunk_1012',
#   'chunk_1013',
#   'chunk_1014',
#   'chunk_1015',
#   'chunk_1016',
#   'chunk_1017',
#   'chunk_1018',
#   'chunk_1019',
#   'chunk_102',
#   'chunk_1020',
#   'chunk_1021',
#   'chunk_1022',
#   'chunk_1023',
#   'chunk_1024',
#   'chunk_1025',
#   'chunk_1026',
#   'chunk_1027',
#   'chunk_1028',
#   'chunk_1029',
#   'chunk_103',
#   'chunk_1030',
#   'chunk_1031',
#   'chunk_1032',
#   'chunk_1033',
#   'chunk_1034',
#   'chunk_1035',
#   'chunk_1036',
#   'chunk_1037',
#   'chunk_1038',
#   'chunk_1039',
#   'chunk_104',
#   'chunk_1040',
#   'chunk_1041',
#   'chunk_1042',
#   'chunk_1043',
#   'chunk_1044',
#   'chunk_1045',
#   'chunk_1046',
#   'chunk_1047',
#   'chunk_1048',
#   'chunk_1049',
#   'chunk_105',
#   'chunk_1050',
#   'chunk_1051',
#   'chunk_1052',
#   'chunk_1053',
#   'chunk_1054',
#   'chunk_1055',
#   'chunk_1056',
#   'chunk_1057',
#   'chunk_1058',
#   'chunk_1059',
#   'chunk_106',
#   'chunk_1060',
#   'chunk_1061',
#   'chunk_1062',
#   'chunk_1063',
#   'chunk_1064',
#   'chunk_1065',
#   'chunk_1066',
#   'chunk_1067',
#   'chunk_1068',
#   'chunk_1069',
#   'chunk_107',
#   'chunk_1070',
#   'chunk_1071',
#   'chunk_1072',
#   'chunk_1073',
#   'chunk_1074',
#   'chunk_1075',
#   'chunk_1076',
#   'chunk_1077',
#   'chunk_1078',
#   'chunk_1079',
#   'chunk_108',
#   'chunk_1080',
#   'chunk_1081',
#   'chunk_1082',
#   'chunk_1083',
#   'chunk_1084',
#   'chunk_1085',
#   'chunk_1086',
#   'chunk_1087',
#   'chunk_1088',
#   'chunk_1089',
#   'chunk_109',
#   'chunk_1090',
#   'chunk_1091',
#   'chunk_1092',
#   'chunk_1093',
#   'chunk_1094',
#   'chunk_1095',
#   'chunk_1096',
#   'chunk_1097',
#   'chunk_1098',
#   'chunk_1099',
#   'chunk_11',
#   'chunk_110',
#   'chunk_1100',
#   'chunk_1101',
#   'chunk_1102',
#   'chunk_1103',
#   'chunk_1104',
#   'chunk_1105',
#   'chunk_1106',
#   'chunk_1107',
#   'chunk_1108',
#   'chunk_1109',
#   'chunk_111',
#   'chunk_1110',
#   'chunk_1111',
#   'chunk_1112',
#   'chunk_1113',
#   'chunk_1114',
#   'chunk_1115',
#   'chunk_1116',
#   'chunk_1117',
#   'chunk_1118',
#   'chunk_1119',
#   'chunk_112',
#   'chunk_1120',
#   'chunk_1121',
#   'chunk_1122',
#   'chunk_1123',
#   'chunk_1124',
#   'chunk_1125',
#   'chunk_1126',
#   'chunk_1127',
#   'chunk_1128',
#   'chunk_1129',
#   'chunk_113',
#   'chunk_1130',
#   'chunk_1131',
#   'chunk_1132',
#   'chunk_1133',
#   'chunk_1134',
#   'chunk_1135',
#   'chunk_1136',
#   'chunk_1137',
#   'chunk_1138',
#   'chunk_1139',
#   'chunk_114',
#   'chunk_1140',
#   'chunk_1141',
#   'chunk_1142',
#   'chunk_1143',
#   'chunk_1144',
#   'chunk_1145',
#   'chunk_1146',
#   'chunk_1147',
#   'chunk_1148',
#   'chunk_1149',
#   'chunk_115',
#   'chunk_1150',
#   'chunk_1151',
#   'chunk_1152',
#   'chunk_1153',
#   'chunk_1154',
#   'chunk_1155',
#   'chunk_1156',
#   'chunk_1157',
#   'chunk_1158',
#   'chunk_1159',
#   'chunk_116',
#   'chunk_1160',
#   'chunk_1161',
#   'chunk_1162',
#   'chunk_1163',
#   'chunk_1164',
#   'chunk_1165',
#   'chunk_1166',
#   'chunk_1167',
#   'chunk_1168',
#   'chunk_1169',
#   'chunk_117',
#   'chunk_1170',
#   'chunk_1171',
#   'chunk_1172',
#   'chunk_1173',
#   'chunk_1174',
#   'chunk_1175',
#   'chunk_1176',
#   'chunk_1177',
#   'chunk_1178',
#   'chunk_1179',
#   'chunk_118',
#   'chunk_1180',
#   'chunk_1181',
#   'chunk_1182',
#   'chunk_1183',
#   'chunk_1184',
#   'chunk_1185',
#   'chunk_1186',
#   'chunk_1187',
#   'chunk_1188',
#   'chunk_1189',
#   'chunk_119',
#   'chunk_1190',
#   'chunk_1191',
#   'chunk_1192',
#   'chunk_1193',
#   'chunk_1194',
#   'chunk_1195',
#   'chunk_1196',
#   'chunk_1197',
#   'chunk_1198',
#   'chunk_1199',
#   'chunk_12',
#   'chunk_120',
#   'chunk_1200',
#   'chunk_1201',
#   'chunk_1202',
#   'chunk_1203',
#   'chunk_1204',
#   'chunk_1205',
#   'chunk_1206',
#   'chunk_1207',
#   'chunk_1208',
#   'chunk_1209',
#   'chunk_121',
#   'chunk_1210',
#   'chunk_1211',
#   'chunk_1212',
#   'chunk_1213',
#   'chunk_1214',
#   'chunk_1215',
#   'chunk_1216',
#   'chunk_1217',
#   'chunk_1218',
#   'chunk_1219',
#   'chunk_122',
#   'chunk_1220',
#   'chunk_1221',
#   'chunk_1222',
#   'chunk_1223',
#   'chunk_1224',
#   'chunk_1225',
#   'chunk_1226',
#   'chunk_1227',
#   'chunk_1228',
#   'chunk_1229',
#   'chunk_123',
#   'chunk_1230',
#   'chunk_1231',
#   'chunk_1232',
#   'chunk_1233',
#   'chunk_1234',
#   'chunk_1235',
#   'chunk_1236',
#   'chunk_1237',
#   'chunk_1238',
#   'chunk_1239',
#   'chunk_124',
#   'chunk_1240',
#   'chunk_1241',
#   'chunk_1242',
#   'chunk_1243',
#   'chunk_1244',
#   'chunk_1245',
#   'chunk_1246',
#   'chunk_1247',
#   'chunk_1248',
#   'chunk_1249',
#   'chunk_125',
#   'chunk_1250',
#   'chunk_1251',
#   'chunk_1252',
#   'chunk_1253',
#   'chunk_1254',
#   'chunk_1255',
#   'chunk_1256',
#   'chunk_1257',
#   'chunk_1258',
#   'chunk_1259',
#   'chunk_126',
#   'chunk_1260',
#   'chunk_1261',
#   'chunk_1262',
#   'chunk_1263',
#   'chunk_1264',
#   'chunk_1265',
#   'chunk_1266',
#   'chunk_1267',
#   'chunk_1268',
#   'chunk_1269',
#   'chunk_127',
#   'chunk_1270',
#   'chunk_1271',
#   'chunk_1272',
#   'chunk_1273',
#   'chunk_1274',
#   'chunk_1275',
#   'chunk_1276',
#   'chunk_1277',
#   'chunk_1278',
#   'chunk_1279',
#   'chunk_128',
#   'chunk_1280',
#   'chunk_1281',
#   'chunk_1282',
#   'chunk_1283',
#   'chunk_1284',
#   'chunk_1285',
#   'chunk_1286',
#   'chunk_1287',
#   'chunk_1288',
#   'chunk_1289',
#   'chunk_129',
#   'chunk_1290',
#   'chunk_1291',
#   'chunk_1292',
#   'chunk_1293',
#   'chunk_1294',
#   'chunk_1295',
#   'chunk_1296',
#   'chunk_1297',
#   'chunk_1298',
#   'chunk_1299',
#   'chunk_13',
#   'chunk_130',
#   'chunk_1300',
#   'chunk_1301',
#   'chunk_1302',
#   'chunk_1303',
#   'chunk_1304',
#   'chunk_1305',
#   'chunk_1306',
#   'chunk_1307',
#   'chunk_1308',
#   'chunk_1309',
#   'chunk_131',
#   'chunk_1310',
#   'chunk_1311',
#   'chunk_1312',
#   'chunk_1313',
#   'chunk_1314',
#   'chunk_1315',
#   'chunk_1316',
#   'chunk_1317',
#   'chunk_1318',
#   'chunk_1319',
#   'chunk_132',
#   'chunk_1320',
#   'chunk_1321',
#   'chunk_1322',
#   'chunk_1323',
#   'chunk_1324',
#   'chunk_1325',
#   'chunk_1326',
#   'chunk_1327',
#   'chunk_1328',
#   'chunk_1329',
#   'chunk_133',
#   'chunk_1330',
#   'chunk_1331',
#   'chunk_1332',
#   'chunk_1333',
#   'chunk_1334',
#   'chunk_1335',
#   'chunk_1336',
#   'chunk_1337',
#   'chunk_1338',
#   'chunk_1339',
#   'chunk_134',
#   'chunk_1340',
#   'chunk_1341',
#   'chunk_1342',
#   'chunk_1343',
#   'chunk_1344',
#   'chunk_1345',
#   'chunk_1346',
#   'chunk_1347',
#   'chunk_1348',
#   'chunk_1349',
#   'chunk_135',
#   'chunk_1350',
#   'chunk_1351',
#   'chunk_1352',
#   'chunk_1353',
#   'chunk_1354',
#   'chunk_1355',
#   'chunk_1356',
#   'chunk_1357',
#   'chunk_1358',
#   'chunk_1359',
#   'chunk_136',
#   'chunk_1360',
#   'chunk_1361',
#   'chunk_1362',
#   'chunk_1363',
#   'chunk_1364',
#   'chunk_1365',
#   'chunk_1366',
#   'chunk_1367',
#   'chunk_1368',
#   'chunk_1369',
#   'chunk_137',
#   'chunk_1370',
#   'chunk_1371',
#   'chunk_1372',
#   'chunk_1373',
#   'chunk_1374',
#   'chunk_1375',
#   'chunk_1376',
#   'chunk_1377',
#   'chunk_1378',
#   'chunk_1379',
#   'chunk_138',
#   'chunk_1380',
#   'chunk_1381',
#   'chunk_1382',
#   'chunk_1383',
#   'chunk_1384',
#   'chunk_1385',
#   'chunk_1386',
#   'chunk_1387',
#   'chunk_1388',
#   'chunk_1389',
#   'chunk_139',
#   'chunk_1390',
#   'chunk_1391',
#   'chunk_1392',
#   'chunk_1393',
#   'chunk_1394',
#   'chunk_1395',
#   'chunk_1396',
#   'chunk_1397',
#   'chunk_1398',
#   'chunk_1399',
#   'chunk_14',
#   'chunk_140',
#   'chunk_1400',
#   'chunk_1401',
#   'chunk_1402',
#   'chunk_1403',
#   'chunk_1404',
#   'chunk_1405',
#   'chunk_1406',
#   'chunk_1407',
#   'chunk_1408',
#   'chunk_1409',
#   'chunk_141',
#   'chunk_1410',
#   'chunk_1411',
#   'chunk_1412',
#   'chunk_1413',
#   'chunk_1414',
#   'chunk_1415',
#   'chunk_1416',
#   'chunk_1417',
#   'chunk_1418',
#   'chunk_1419',
#   'chunk_142',
#   'chunk_1420',
#   'chunk_1421',
#   'chunk_1422',
#   'chunk_1423',
#   'chunk_1424',
#   'chunk_1425',
#   'chunk_1426',
#   'chunk_1427',
#   'chunk_1428',
#   'chunk_1429',
#   'chunk_143',
#   'chunk_1430',
#   'chunk_1431',
#   'chunk_1432',
#   'chunk_1433',
#   'chunk_1434',
#   'chunk_1435',
#   'chunk_1436',
#   'chunk_1437',
#   'chunk_1438',
#   'chunk_1439',
#   'chunk_144',
#   'chunk_1440',
#   'chunk_1441',
#   'chunk_1442',
#   'chunk_1443',
#   'chunk_1444',
#   'chunk_1445',
#   'chunk_1446',
#   'chunk_1447',
#   'chunk_1448',
#   'chunk_1449',
#   'chunk_145',
#   'chunk_1450',
#   'chunk_1451',
#   'chunk_1452',
#   'chunk_1453',
#   'chunk_1454',
#   'chunk_1455',
#   'chunk_1456',
#   'chunk_1457',
#   'chunk_1458',
#   'chunk_1459',
#   'chunk_146',
#   'chunk_1460',
#   'chunk_1461',
#   'chunk_1462',
#   'chunk_1463',
#   'chunk_1464',
#   'chunk_1465',
#   'chunk_1466',
#   'chunk_1467',
#   'chunk_1468',
#   'chunk_1469',
#   'chunk_147',
#   'chunk_1470',
#   'chunk_1471',
#   'chunk_1472',
#   'chunk_1473',
#   'chunk_1474',
#   'chunk_1475',
#   'chunk_1476',
#   'chunk_1477',
#   'chunk_1478',
#   'chunk_1479',
#   'chunk_148',
#   'chunk_1480',
#   'chunk_1481',
#   'chunk_1482',
#   'chunk_1483',
#   'chunk_1484',
#   'chunk_1485',
#   'chunk_1486',
#   'chunk_1487',
#   'chunk_1488',
#   'chunk_1489',
#   'chunk_149',
#   'chunk_1490',
#   'chunk_1491',
#   'chunk_1492',
#   'chunk_1493',
#   'chunk_1494',
#   'chunk_1495',
#   'chunk_1496',
#   'chunk_1497',
#   'chunk_1498',
#   'chunk_1499',
#   'chunk_15',
#   'chunk_150',
#   'chunk_1500',
#   'chunk_1501',
#   'chunk_1502',
#   'chunk_1503',
#   'chunk_1504',
#   'chunk_1505',
#   'chunk_1506',
#   'chunk_1507',
#   'chunk_1508',
#   'chunk_1509',
#   'chunk_151',
#   'chunk_1510',
#   'chunk_1511',
#   'chunk_1512',
#   'chunk_1513',
#   'chunk_1514',
#   'chunk_1515',
#   'chunk_1516',
#   'chunk_1517',
#   'chunk_1518',
#   'chunk_1519',
#   'chunk_152',
#   'chunk_1520',
#   'chunk_1521',
#   'chunk_1522',
#   'chunk_1523',
#   'chunk_1524',
#   'chunk_1525',
#   'chunk_1526',
#   'chunk_1527',
#   'chunk_1528',
#   'chunk_1529',
#   'chunk_153',
#   'chunk_1530',
#   'chunk_1531',
#   'chunk_1532',
#   'chunk_1533',
#   'chunk_1534',
#   'chunk_1535',
#   'chunk_1536',
#   'chunk_1537',
#   'chunk_1538',
#   'chunk_1539',
#   'chunk_154',
#   'chunk_1540',
#   'chunk_1541',
#   'chunk_1542',
#   'chunk_1543',
#   'chunk_1544',
#   'chunk_1545',
#   'chunk_1546',
#   'chunk_1547',
#   'chunk_1548',
#   'chunk_1549',
#   'chunk_155',
#   'chunk_1550',
#   'chunk_1551',
#   'chunk_1552',
#   'chunk_1553',
#   'chunk_1554',
#   'chunk_1555',
#   'chunk_1556',
#   'chunk_1557',
#   'chunk_1558',
#   'chunk_1559',
#   'chunk_156',
#   'chunk_1560',
#   'chunk_1561',
#   'chunk_1562',
#   'chunk_1563',
#   'chunk_1564',
#   'chunk_1565',
#   'chunk_1566',
#   'chunk_1567',
#   'chunk_1568',
#   'chunk_1569',
#   'chunk_157',
#   'chunk_1570',
#   'chunk_1571',
#   'chunk_1572',
#   'chunk_1573',
#   'chunk_1574',
#   'chunk_1575',
#   'chunk_1576',
#   'chunk_1577',
#   'chunk_1578',
#   'chunk_1579',
#   'chunk_158',
#   'chunk_1580',
#   'chunk_1581',
#   'chunk_1582',
#   'chunk_1583',
#   'chunk_1584',
#   'chunk_1585',
#   'chunk_1586',
#   'chunk_1587',
#   'chunk_1588',
#   'chunk_1589',
#   'chunk_159',
#   'chunk_1590',
#   'chunk_1591',
#   'chunk_1592',
#   'chunk_1593',
#   'chunk_1594',
#   'chunk_1595',
#   'chunk_1596',
#   'chunk_1597',
#   'chunk_1598',
#   'chunk_1599',
#   'chunk_16',
#   'chunk_160',
#   'chunk_1600',
#   'chunk_1601',
#   'chunk_1602',
#   'chunk_1603',
#   'chunk_1604',
#   'chunk_1605',
#   'chunk_1606',
#   'chunk_1607',
#   'chunk_1608',
#   'chunk_1609',
#   'chunk_161',
#   'chunk_1610',
#   'chunk_1611',
#   'chunk_1612',
#   'chunk_1613',
#   'chunk_1614',
#   'chunk_1615',
#   'chunk_1616',
#   'chunk_1617',
#   'chunk_1618',
#   'chunk_1619',
#   'chunk_162',
#   'chunk_1620',
#   'chunk_1621',
#   'chunk_1622',
#   'chunk_1623',
#   'chunk_1624',
#   'chunk_1625',
#   'chunk_1626',
#   'chunk_1627',
#   'chunk_1628',
#   'chunk_1629',
#   'chunk_163',
#   'chunk_1630',
#   'chunk_1631',
#   'chunk_1632',
#   'chunk_1633',
#   'chunk_1634',
#   'chunk_1635',
#   'chunk_1636',
#   'chunk_1637',
#   'chunk_1638',
#   'chunk_1639',
#   'chunk_164',
#   'chunk_1640',
#   'chunk_1641',
#   'chunk_1642',
#   'chunk_1643',
#   'chunk_1644',
#   'chunk_1645',
#   'chunk_1646',
#   'chunk_1647',
#   'chunk_1648',
#   'chunk_1649',
#   'chunk_165',
#   'chunk_1650',
#   'chunk_1651',
#   'chunk_1652',
#   'chunk_1653',
#   'chunk_1654',
#   'chunk_1655',
#   'chunk_1656',
#   'chunk_1657',
#   'chunk_1658',
#   'chunk_1659',
#   'chunk_166',
#   'chunk_1660',
#   'chunk_1661',
#   'chunk_1662',
#   'chunk_1663',
#   'chunk_1664',
#   'chunk_1665',
#   'chunk_1666',
#   'chunk_1667',
#   'chunk_1668',
#   'chunk_1669',
#   'chunk_167',
#   'chunk_1670',
#   'chunk_1671',
#   'chunk_1672',
#   'chunk_1673',
#   'chunk_1674',
#   'chunk_1675',
#   'chunk_1676',
#   'chunk_1677',
#   'chunk_1678',
#   'chunk_1679',
#   'chunk_168',
#   'chunk_1680',
#   'chunk_1681',
#   'chunk_1682',
#   'chunk_1683',
#   'chunk_1684',
#   'chunk_1685',
#   'chunk_1686',
#   'chunk_1687',
#   'chunk_1688',
#   'chunk_1689',
#   'chunk_169',
#   'chunk_1690',
#   'chunk_1691',
#   'chunk_1692',
#   'chunk_1693',
#   'chunk_1694',
#   'chunk_1695',
#   'chunk_1696',
#   'chunk_1697',
#   'chunk_1698',
#   'chunk_1699',
#   'chunk_17',
#   'chunk_170',
#   'chunk_1700',
#   'chunk_1701',
#   'chunk_1702',
#   'chunk_1703',
#   'chunk_1704',
#   'chunk_1705',
#   'chunk_1706',
#   'chunk_1707',
#   'chunk_1708',
#   'chunk_1709',
#   'chunk_171',
#   'chunk_1710',
#   'chunk_1711',
#   'chunk_1712',
#   'chunk_1713',
#   'chunk_1714',
#   'chunk_1715',
#   'chunk_1716',
#   'chunk_1717',
#   'chunk_1718',
#   'chunk_1719',
#   'chunk_172',
#   'chunk_1720',
#   'chunk_1721',
#   'chunk_1722',
#   'chunk_1723',
#   'chunk_1724',
#   'chunk_1725',
#   'chunk_1726',
#   'chunk_1727',
#   'chunk_1728',
#   'chunk_1729',
#   'chunk_173',
#   'chunk_1730',
#   'chunk_1731',
#   'chunk_1732',
#   'chunk_1733',
#   'chunk_1734',
#   'chunk_1735',
#   'chunk_1736',
#   'chunk_1737',
#   'chunk_1738',
#   'chunk_1739',
#   'chunk_174',
#   'chunk_1740',
#   'chunk_1741',
#   'chunk_1742',
#   'chunk_1743',
#   'chunk_1744',
#   'chunk_1745',
#   'chunk_1746',
#   'chunk_1747',
#   'chunk_1748',
#   'chunk_1749',
#   'chunk_175',
#   'chunk_1750',
#   'chunk_1751',
#   'chunk_1752',
#   'chunk_1753',
#   'chunk_1754',
#   'chunk_1755',
#   'chunk_1756',
#   'chunk_1757',
#   'chunk_1758',
#   'chunk_1759',
#   'chunk_176',
#   'chunk_1760',
#   'chunk_1761',
#   'chunk_1762',
#   'chunk_1763',
#   'chunk_1764',
#   'chunk_1765',
#   'chunk_1766',
#   'chunk_1767',
#   'chunk_1768',
#   'chunk_1769',
#   'chunk_177',
#   'chunk_1770',
#   'chunk_1771',
#   'chunk_1772',
#   'chunk_1773',
#   'chunk_1774',
#   'chunk_1775',
#   'chunk_1776',
#   'chunk_1777',
#   'chunk_1778',
#   'chunk_1779',
#   'chunk_178',
#   'chunk_1780',
#   'chunk_1781',
#   'chunk_1782',
#   'chunk_1783',
#   'chunk_1784',
#   'chunk_1785',
#   'chunk_1786',
#   'chunk_1787',
#   'chunk_1788',
#   'chunk_1789',
#   'chunk_179',
#   'chunk_1790',
#   'chunk_1791',
#   'chunk_1792',
#   'chunk_1793',
#   'chunk_1794',
#   'chunk_1795',
#   'chunk_1796',
#   'chunk_1797',
#   'chunk_1798',
#   'chunk_1799',
#   'chunk_18',
#   'chunk_180',
#   'chunk_1800',
#   'chunk_1801',
#   'chunk_1802',
#   'chunk_1803',
#   'chunk_1804',
#   'chunk_1805',
#   'chunk_1806',
#   'chunk_1807',
#   'chunk_1808',
#   'chunk_1809',
#   'chunk_181',
#   'chunk_1810',
#   'chunk_1811',
#   'chunk_1812',
#   'chunk_1813',
#   'chunk_1814',
#   'chunk_1815',
#   'chunk_1816',
#   'chunk_1817',
#   'chunk_1818',
#   'chunk_1819',
#   'chunk_182',
#   'chunk_1820',
#   'chunk_1821',
#   'chunk_1822',
#   'chunk_1823',
#   'chunk_1824',
#   'chunk_1825',
#   'chunk_1826',
#   'chunk_1827',
#   'chunk_1828',
#   'chunk_1829',
#   'chunk_183',
#   'chunk_1830',
#   'chunk_1831',
#   'chunk_1832',
#   'chunk_1833',
#   'chunk_1834',
#   'chunk_1835',
#   'chunk_1836',
#   'chunk_1837',
#   'chunk_1838',
#   'chunk_1839',
#   'chunk_184',
#   'chunk_1840',
#   'chunk_1841',
#   'chunk_1842',
#   'chunk_1843',
#   'chunk_1844',
#   'chunk_1845',
#   'chunk_1846',
#   'chunk_1847',
#   'chunk_1848',
#   'chunk_1849',
#   'chunk_185',
#   'chunk_1850',
#   'chunk_1851',
#   'chunk_1852',
#   'chunk_1853',
#   'chunk_1854',
#   'chunk_1855',
#   'chunk_1856',
#   'chunk_1857',
#   'chunk_1858',
#   'chunk_1859',
#   'chunk_186',
#   'chunk_1860',
#   'chunk_1861',
#   'chunk_1862',
#   'chunk_1863',
#   'chunk_1864',
#   'chunk_1865',
#   'chunk_1866',
#   'chunk_1867',
#   'chunk_1868',
#   'chunk_1869',
#   'chunk_187',
#   'chunk_1870',
#   'chunk_1871',
#   'chunk_1872',
#   'chunk_1873',
#   'chunk_1874',
#   'chunk_1875',
#   'chunk_1876',
#   'chunk_1877',
#   'chunk_1878',
#   'chunk_1879',
#   'chunk_188',
#   'chunk_1880',
#   'chunk_1881',
#   'chunk_1882',
#   'chunk_1883',
#   'chunk_1884',
#   'chunk_1885',
#   'chunk_1886',
#   'chunk_1887',
#   'chunk_1888',
#   'chunk_1889',
#   'chunk_189',
#   'chunk_1890',
#   'chunk_1891',
#   'chunk_1892',
#   'chunk_1893',
#   'chunk_1894',
#   'chunk_1895',
#   'chunk_1896',
#   'chunk_1897',
#   'chunk_1898',
#   ...],
#  'embeddings': None,
#  'metadatas': None,
#  'documents': [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   ...],
#  'uris': None,
#  'data': None}

# %%
emb
# Out:
# tensor([-5.2582e-02, -1.0668e-03,  4.8248e-02,  2.6223e-02, -7.6096e-02,
#         -1.6457e-02,  2.4056e-02, -2.4001e-02, -9.2438e-02, -4.0610e-02,
#          1.8642e-02, -4.5642e-02,  3.7613e-02, -8.2195e-02, -9.2998e-03,
#          5.8245e-03,  9.1322e-02,  2.4334e-02, -9.3703e-02, -6.6399e-02,
#         -5.2487e-02, -1.3367e-02, -7.5282e-02, -7.6823e-03, -5.9076e-02,
#          1.9567e-02, -8.2752e-02, -6.7609e-02,  7.0743e-03, -1.5550e-02,
#          4.5352e-02,  8.9172e-02,  3.7166e-02,  1.9877e-02, -5.1579e-02,
#          4.7629e-02,  1.4343e-02,  1.3528e-01,  2.1686e-02, -9.4448e-02,
#         -5.3571e-02, -9.2216e-02, -7.1292e-02, -1.0110e-01,  3.8090e-02,
#         -1.1791e-01,  1.2045e-02, -6.6349e-02,  1.6309e-02, -1.1391e-01,
#         -6.0563e-02, -5.2546e-02,  1.2145e-01, -3.8253e-03, -5.1457e-02,
#         -4.2768e-02,  2.5652e-02,  1.9279e-02, -1.8188e-02, -1.3724e-02,
#         -9.3102e-02,  9.4775e-03,  2.8720e-03, -5.5901e-03,  3.2523e-02,
#          4.4477e-03, -2.6833e-02,  1.0527e-02, -3.2616e-02,  7.0753e-02,
#         -5.7125e-03, -1.1124e-02,  4.3996e-02,  4.3867e-02, -7.2554e-03,
#          1.4061e-02,  1.4971e-02, -5.9081e-02, -2.6976e-02, -1.3705e-02,
#         -1.1747e-02, -9.6416e-03, -1.0456e-02, -4.1182e-02, -7.9133e-02,
#         -2.7434e-02, -2.4096e-02, -1.8410e-02,  2.4559e-02, -8.5981e-02,
#         -1.6605e-02,  2.2439e-02, -2.2801e-02, -1.6463e-02,  5.2571e-02,
#         -1.1110e-01,  2.6969e-02, -2.3129e-02, -1.0857e-01,  5.5891e-02,
#         -1.9984e-02,  6.0666e-02, -3.0109e-03, -4.0548e-03,  3.2042e-04,
#         -8.2182e-02,  1.4624e-02,  2.2466e-02,  1.9759e-02, -1.0178e-02,
#          2.3329e-02,  3.1791e-02, -2.3900e-02, -4.1261e-02, -6.5674e-02,
#         -3.6691e-02, -3.6247e-02, -1.0492e-02, -2.6324e-02,  2.6648e-02,
#         -8.8512e-02,  6.9154e-02, -6.0152e-02,  3.2521e-02,  3.7424e-02,
#         -4.2082e-02, -2.2721e-02,  3.7108e-32, -3.9859e-02,  6.2998e-02,
#          7.9595e-02, -2.5898e-03, -3.8598e-02, -5.3043e-03, -2.5491e-02,
#          8.1645e-03,  2.7092e-02, -4.0420e-02,  1.4061e-01, -9.0592e-02,
#         -4.6047e-02,  1.1225e-02, -7.2963e-02, -2.0109e-02, -7.4975e-02,
#         -7.8153e-02, -5.9773e-02, -7.1880e-03,  4.1204e-04,  1.1269e-02,
#          4.2933e-02, -5.3629e-02,  3.8400e-02, -3.5376e-02,  5.4739e-02,
#         -1.6182e-02,  1.0736e-01,  4.8842e-02,  4.2846e-02, -2.7164e-02,
#         -2.2358e-02, -7.2400e-02, -1.0621e-01, -3.5956e-02,  4.4897e-02,
#         -6.6581e-02, -4.2555e-02, -1.2765e-01, -4.2241e-02, -3.2806e-03,
#          1.0850e-02, -3.2232e-02, -4.3751e-02,  5.6426e-02,  9.3518e-02,
#          6.2388e-02, -5.3864e-02,  4.3217e-02, -3.1783e-03,  5.7538e-02,
#          4.9277e-03, -3.6015e-02, -3.5781e-02, -6.2703e-02, -1.8485e-02,
#          1.6056e-02,  1.9634e-02,  1.2018e-03, -3.4751e-02, -4.9979e-02,
#         -6.4901e-02, -3.2669e-03,  5.2463e-03, -8.0333e-03,  2.1468e-02,
#         -1.6221e-02, -2.3687e-02,  9.2057e-02,  5.6833e-03, -6.0126e-03,
#         -5.8803e-02,  4.2075e-02,  3.6254e-02,  3.4936e-02,  9.1657e-02,
#         -5.2759e-02,  1.2151e-02,  9.0485e-03,  3.4752e-02, -1.2141e-02,
#         -3.4184e-02, -1.4902e-02,  1.0211e-01,  5.2088e-02, -9.4714e-03,
#         -5.6058e-02, -4.7266e-03,  1.8063e-02,  2.6989e-02, -3.5329e-02,
#          3.1235e-02,  5.4516e-03, -8.6279e-02, -3.6556e-32, -2.7769e-03,
#          1.8620e-02,  2.6093e-02,  9.3954e-02,  6.4631e-02, -1.0992e-02,
#         -7.5187e-02, -5.7940e-02,  9.1807e-02,  1.1372e-01, -6.0227e-02,
#          2.6007e-02,  1.8149e-02, -6.9772e-03,  1.3373e-02, -9.0275e-02,
#          2.9986e-02,  4.8299e-02, -3.0080e-02,  8.5151e-02,  3.5376e-02,
#          8.3551e-02, -9.2759e-02,  6.9408e-02, -3.5944e-02,  5.3253e-02,
#         -5.3938e-02,  9.3626e-02, -3.3888e-02, -1.5991e-02, -4.9015e-02,
#         -2.3520e-02, -6.4938e-02, -8.9361e-02, -4.8765e-02,  4.3231e-04,
#         -5.5233e-02, -5.3738e-03, -6.6046e-02,  5.3454e-02, -1.0610e-01,
#         -3.3843e-02, -3.1878e-02, -5.9428e-02, -7.3870e-02, -1.3661e-01,
#         -4.1844e-02, -1.0288e-02, -2.6978e-02,  3.4717e-02,  4.6781e-02,
#          2.7174e-02,  4.4114e-03,  2.3112e-02,  4.6361e-02, -3.6216e-03,
#          2.3654e-03, -2.1344e-02, -3.3210e-02,  1.3728e-02, -4.7292e-02,
#         -1.9527e-03,  3.1486e-02,  5.5292e-02,  3.4346e-02, -9.9515e-02,
#          2.3959e-02, -2.4092e-02, -3.4100e-04, -4.9766e-02,  5.3717e-02,
#         -2.4581e-02, -3.5802e-02, -2.7319e-02,  2.6635e-02,  9.3713e-02,
#          5.2532e-02, -3.1337e-02,  3.1513e-02, -6.0970e-02,  4.7867e-02,
#         -1.0869e-01,  7.6666e-02, -6.0161e-02,  1.0058e-02, -1.2025e-02,
#         -4.1231e-02, -9.1367e-03,  6.0240e-02,  8.6812e-02,  4.8865e-02,
#          2.5235e-03,  2.0606e-02,  4.1716e-02,  4.2942e-02, -9.4958e-08,
#          1.9511e-02, -6.6141e-02,  1.5930e-02,  1.3035e-02,  6.3721e-02,
#         -3.7244e-02, -1.3263e-03,  6.4661e-02, -2.7562e-02,  1.7648e-02,
#          8.2252e-03, -1.5220e-02,  2.4990e-02, -5.1615e-02,  5.8876e-02,
#         -1.5246e-02,  1.8166e-02, -4.8261e-02, -1.0260e-01, -6.0583e-02,
#          3.8341e-02, -6.5797e-02, -7.7260e-03,  2.4944e-02, -1.8550e-02,
#         -4.4418e-02, -2.7782e-02, -2.6942e-02, -4.4784e-02, -3.3433e-02,
#          6.2647e-03,  9.9554e-03, -2.4993e-02, -6.6341e-02,  5.6290e-02,
#          4.2212e-02,  1.4510e-02, -7.2958e-03, -1.2915e-02,  7.4398e-02,
#          1.4418e-02,  4.6635e-03,  9.4876e-02,  6.1334e-02, -6.9110e-02,
#          2.9164e-03, -8.2879e-02,  3.6115e-02, -1.1402e-02, -1.2295e-01,
#          3.8268e-03, -3.9265e-02,  2.9093e-02, -2.7512e-02, -2.3811e-02,
#          3.5001e-02, -3.3130e-02,  7.2326e-02,  3.5070e-02, -1.9978e-02,
#          1.5418e-01, -2.5999e-02, -3.0741e-03, -3.7156e-02])

# %%
a=doc_vectors

# %%
emb = [doc_vec for i.toli]
# Out:
# [-0.07839059829711914,
#  -0.11347431689500809,
#  -0.004569102078676224,
#  -0.005671562626957893,
#  -0.023426087573170662,
#  0.007325473241508007,
#  -0.005651227664202452,
#  -0.038666628301143646,
#  -0.036171428859233856,
#  0.015680037438869476,
#  0.0365501306951046,
#  -0.010670101270079613,
#  -0.05736149847507477,
#  -0.049183186143636703,
#  -0.04145707190036774,
#  -0.029344050213694572,
#  0.05052560567855835,
#  0.03549210727214813,
#  -0.07650180160999298,
#  0.045095499604940414,
#  0.02648083120584488,
#  -0.005047412123531103,
#  0.04996003210544586,
#  -0.03948022425174713,
#  -0.10350827127695084,
#  0.046609066426754,
#  -0.10492847859859467,
#  -0.0006327894516289234,
#  0.0029297659639269114,
#  -0.033578258007764816,
#  -0.011554839089512825,
#  0.09609846770763397,
#  0.02595331147313118,
#  0.03758307173848152,
#  0.027452649548649788,
#  0.02310495637357235,
#  -0.01826608180999756,
#  0.1446506381034851,
#  0.03698216751217842,
#  -0.02853136695921421,
#  -0.0556027926504612,
#  -0.07379885762929916,
#  -0.007945134304463863,
#  0.05165977030992508,
#  -0.03824140504002571,
#  -0.07685624808073044,
#  -0.03394726663827896,
#  -0.049130428582429886,
#  0.0401015505194664,
#  -0.061318930238485336,
#  -0.03937232494354248,
#  -0.013360460288822651,
#  0.030897146090865135,
#  0.03881107643246651,
#  -0.038337692618370056,
#  -0.017315255478024483,
#  0.0003629251441452652,
#  -0.04604914411902428,
#  -0.0377860888838768,
#  -0.03458946943283081,
#  -0.0505550391972065,
#  0.01792353391647339,
#  -0.004359147977083921,
#  0.0014207768253982067,
#  -0.03171602264046669,
#  -0.02476084791123867,
#  -0.01156284473836422,
#  0.02004105970263481,
#  0.045937150716781616,
#  -0.01563575305044651,
#  -0.005545333493500948,
#  -0.00662177475169301,
#  0.03993723541498184,
#  0.09379319101572037,
#  -0.005527375265955925,
#  0.08553161472082138,
#  -0.019154269248247147,
#  -0.10990286618471146,
#  0.002163165947422385,
#  0.028331993147730827,
#  -0.0019772485829889774,
#  0.011943478137254715,
#  -0.012254207395017147,
#  0.05121360719203949,
#  -0.07244707643985748,
#  0.0005849071312695742,
#  -0.05513044446706772,
#  0.040227558463811874,
#  -0.01566082239151001,
#  -0.012385930866003036,
#  0.007929446175694466,
#  0.031172364950180054,
#  -0.04260249808430672,
#  -0.11095058917999268,
#  0.07096076756715775,
#  -0.05447657033801079,
#  -0.020768051967024803,
#  0.05750694498419762,
#  -0.0630701407790184,
#  0.03564793989062309,
#  -0.013882545754313469,
#  0.03717358410358429,
#  0.012014725245535374,
#  -0.04954370856285095,
#  0.016538040712475777,
#  -0.036309000104665756,
#  0.04089120402932167,
#  -0.0083028394728899,
#  -0.023066993802785873,
#  0.023092254996299744,
#  0.032566893845796585,
#  -0.039605386555194855,
#  -0.03998103365302086,
#  -0.07243459671735764,
#  0.04459148645401001,
#  -0.02821916900575161,
#  0.04543336480855942,
#  0.02064220979809761,
#  0.017345286905765533,
#  0.037712667137384415,
#  -0.017211250960826874,
#  0.03719649836421013,
#  -0.1190810352563858,
#  0.012009982950985432,
#  -0.005930345971137285,
#  0.09407279640436172,
#  0.04616584628820419,
#  3.4097006274485453e-32,
#  0.011121929623186588,
#  0.11774501204490662,
#  -0.08580030500888824,
#  -0.027037272229790688,
#  0.01457385066896677,
#  -0.013422360643744469,
#  -0.03693836182355881,
#  0.08502420037984848,
#  -0.027514025568962097,
#  0.09880204498767853,
#  0.054394952952861786,
#  -0.14824159443378448,
#  -0.05184449627995491,
#  -0.02936638705432415,
#  -0.10711967945098877,
#  0.019255559891462326,
#  0.07674054801464081,
#  -0.08503381907939911,
#  -0.09911196678876877,
#  0.04046030715107918,
#  0.04190929979085922,
#  0.03691013529896736,
#  0.022200405597686768,
#  -0.01534892525523901,
#  -0.0029445430263876915,
#  -0.049402955919504166,
#  -0.059617433696985245,
#  -0.005458735395222902,
#  0.07341600209474564,
#  -0.009518294595181942,
#  -0.027608029544353485,
#  -0.028267713263630867,
#  -0.008242628537118435,
#  -0.02901391312479973,
#  -0.009128039702773094,
#  0.02351156808435917,
#  0.12337815016508102,
#  -0.033376891165971756,
#  -0.010775639675557613,
#  -0.048654597252607346,
#  -0.06727617233991623,
#  0.026706811040639877,
#  -0.021307924762368202,
#  -0.010647532530128956,
#  0.054182615131139755,
#  -0.04484938830137253,
#  -0.03749906271696091,
#  0.03629324957728386,
#  -0.010530375875532627,
#  0.002221514005213976,
#  0.03686390444636345,
#  -0.008806935511529446,
#  0.002057403791695833,
#  0.019362470135092735,
#  -0.028290880843997,
#  0.06040237098932266,
#  -0.0569109246134758,
#  -0.0035322068724781275,
#  0.08756177127361298,
#  0.08267192542552948,
#  -0.05378831923007965,
#  -0.031517911702394485,
#  -0.018565060570836067,
#  0.012283239513635635,
#  0.06267557293176651,
#  -0.0865335613489151,
#  0.014950871467590332,
#  -0.0761345773935318,
#  0.034944087266922,
#  0.034902606159448624,
#  -0.038917891681194305,
#  -0.06504445523023605,
#  0.015500468201935291,
#  0.019827384501695633,
#  0.04217701032757759,
#  0.07461651414632797,
#  0.04146931692957878,
#  -0.02557200938463211,
#  0.03211817145347595,
#  -0.010926145128905773,
#  0.05736616998910904,
#  -0.04535588249564171,
#  -0.07023540139198303,
#  0.045187488198280334,
#  0.06463267654180527,
#  -0.022069556638598442,
#  0.03172997385263443,
#  -0.05640445277094841,
#  -0.10564098507165909,
#  -0.04353150725364685,
#  0.05131683498620987,
#  -0.03766169026494026,
#  -0.014308289624750614,
#  -0.09280426055192947,
#  -0.058797650039196014,
#  -3.267240703830866e-32,
#  0.05432475358247757,
#  0.02709694392979145,
#  -0.021946098655462265,
#  0.015581678599119186,
#  -0.011365067213773727,
#  -0.02440710924565792,
#  -0.10537299513816833,
#  -0.07643264532089233,
#  0.12258372455835342,
#  0.006521016359329224,
#  0.0069653247483074665,
#  -0.025760596618056297,
#  0.022182006388902664,
#  -0.0319211483001709,
#  0.05883428081870079,
#  -0.03273596987128258,
#  -0.06783933937549591,
#  0.02000056393444538,
#  -0.009142989292740822,
#  0.1264181137084961,
#  -0.08796670287847519,
#  0.05876493081450462,
#  -0.08184440433979034,
#  0.01823212392628193,
#  0.026841560378670692,
#  0.023369256407022476,
#  0.023935338482260704,
#  0.13643448054790497,
#  -0.013474175706505775,
#  0.0446176715195179,
#  -0.13863158226013184,
#  -0.03261909261345863,
#  0.022516418248414993,
#  0.03394552320241928,
#  -0.03861473873257637,
#  0.044345445930957794,
#  0.056859053671360016,
#  -0.008004473522305489,
#  -0.09946843236684799,
#  -0.005853928625583649,
#  0.01405345182865858,
#  -0.02895144373178482,
#  -0.08500176668167114,
#  -0.0006502990727312863,
#  -0.0694446712732315,
#  -0.054517488926649094,
#  -0.09256986528635025,
#  0.08155824989080429,
#  0.018922409042716026,
#  0.001510531292296946,
#  0.019205598160624504,
#  0.013996629975736141,
#  -0.07797174900770187,
#  0.007836524397134781,
#  -0.0008885268471203744,
#  -0.026256363838911057,
#  0.006106204818934202,
#  -0.08867062628269196,
#  -0.05236528813838959,
#  -0.059379491955041885,
#  0.0007803626940585673,
#  0.07308344542980194,
#  -0.03571165353059769,
#  0.04369250684976578,
#  0.12166918814182281,
#  -0.15171702206134796,
#  -0.07843511551618576,
#  -0.056187596172094345,
#  -0.09949804842472076,
#  -0.02686896175146103,
#  -0.004598513711243868,
#  -0.012666122056543827,
#  0.025687769055366516,
#  -0.020343486219644547,
#  0.08091087639331818,
#  0.06323065608739853,
#  0.01384569052606821,
#  -0.07959107309579849,
#  -0.008876403793692589,
#  0.020633863285183907,
#  -0.029255812987685204,
#  -0.03103860281407833,
#  -0.013785305432975292,
#  0.04976661130785942,
#  0.05055224522948265,
#  0.03855748102068901,
#  0.0140327587723732,
#  0.03852452337741852,
#  -0.006045741960406303,
#  -0.010471724905073643,
#  0.025247950106859207,
#  -0.03978901728987694,
#  0.020264534279704094,
#  -0.01267124805599451,
#  -0.07112587988376617,
#  -8.644664006851599e-08,
#  0.026555240154266357,
#  0.05093090236186981,
#  0.03977557644248009,
#  0.0016010613180696964,
#  0.10447735339403152,
#  -0.017578931525349617,
#  0.0002809313591569662,
#  0.08849022537469864,
#  0.010820494964718819,
#  0.053530819714069366,
#  0.028997700661420822,
#  0.045405063778162,
#  0.028751244768500328,
#  -0.09459400177001953,
#  0.007465554866939783,
#  0.05131618306040764,
#  -0.0443422757089138,
#  -0.04765753075480461,
#  -0.09738636016845703,
#  -0.09051147103309631,
#  -0.031200332567095757,
#  -0.036232106387615204,
#  -0.05016770958900452,
#  0.03686061128973961,
#  0.0009638303308747709,
#  -0.019779978320002556,
#  -0.07879886031150818,
#  -0.002698686206713319,
#  -0.043047621846199036,
#  -0.011394968256354332,
#  0.01282206829637289,
#  -0.047087062150239944,
#  0.05335306003689766,
#  -0.02805052511394024,
#  0.07067739218473434,
#  -0.00729714147746563,
#  0.06844233721494675,
#  -0.001765999710187316,
#  -0.004228926729410887,
#  -0.0035746567882597446,
#  -0.06287316232919693,
#  -0.06504135578870773,
#  -0.03545919060707092,
#  -0.010276666842401028,
#  -0.0633990615606308,
#  -0.04288100823760033,
#  0.04467622563242912,
#  -0.007851277478039265,
#  0.025714073330163956,
#  -0.08210622519254684,
#  0.022228652611374855,
#  -0.012429844588041306,
#  -0.02458801120519638,
#  -0.03377216309309006,
#  -0.02716127783060074,
#  0.030029550194740295,
#  0.034171201288700104,
#  0.078107550740242,
#  0.024162834510207176,
#  0.004733486566692591,
#  0.024403750896453857,
#  0.04421768710017204,
#  0.02538968063890934,
#  -0.08057563751935959]

# %%
df = df.reset_index()

# %%
df
# Out:
#       index      num                                               name  \
# 0     19461  9192535                        mommy.issues.(2021).eng.1cd
# 1     29590  9199194          empire.s03.e04.cupid.kills.(2016).eng.1cd
# 2     70465  9221632        this.is.us.s05.e15.jerry.2.0.(2021).eng.1cd
# 3     50661  9209861   red.rose.s01.e04.manchester.innit.(2022).eng.1cd
# 4     50587  9209767       fruits.basket.s03.e11.goodbye.(2021).eng.1cd
# ...     ...      ...                                                ...
# 7995  50344  9209734  fruits.basket.s02.e03.shall.we.go.and.get.you....
# 7996  22868  9194963  american.horror.stories.s02.e03.drive.(2022).e...
# 7997  36814  9202976                      doctor.of.doom.(1963).eng.1cd
# 7998  40276  9204652   the.deuce.s02.e06.were.all.beasts.(2018).eng.1cd
# 7999  22930  9194972  the.orville.s03.e10.future.unknown.(2022).eng.1cd
#
#                                     file_content_chunks  \
# 0     place start door open good morning easy say sp...
# 1     direct result willful preventable malpractice ...
# 2     narrator previously beauty beast something gem...
# 3     mother hajara married bayo refused osage offer...
# 4     dialogue dialogue unknown po head thing right ...
# ...                                                 ...
# 7995  working gotta go spent lot money least open ba...
# 7996  deeper ever seen black side town white side to...
# 7997  tell july revolution remember date french revo...
# 7998  kidding oh oh woe life empty without joy oh go...
# 7999  along relieving hurry thanks mr sabharwal maki...
#
#                              doc_vector_pretrained_bert
# 0     [-0.0783905983, -0.113474317, -0.00456910208, ...
# 1     [-0.0845821798, 0.00884224102, 0.0826942697, 0...
# 2     [-0.070148088, -0.065490745, -0.00389705948, 0...
# 3     [-0.0184880402, 0.0330960639, -0.0440507084, -...
# 4     [0.0288344882, -0.0404044986, -0.00503935665, ...
# ...                                                 ...
# 7995  [-0.102519907, -0.0888609216, 0.0308625363, -0...
# 7996  [-0.000806297641, -0.0405393466, -0.0631514415...
# 7997  [-0.0169950146, -0.0723221526, 0.00906122755, ...
# 7998  [-0.0259164125, -0.0884233713, 0.0332689956, -...
# 7999  [-0.0525815785, -0.00106680032, 0.0482483134, ...
#
# [8000 rows x 5 columns]
